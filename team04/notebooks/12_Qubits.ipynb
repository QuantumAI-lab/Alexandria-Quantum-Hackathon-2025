# %% [markdown]
# ## Ideal Simulation

# %%
# Install (uncomment if you need to install or upgrade in notebook)
# !pip install qiskit qiskit-aer qiskit-optimization qiskit_algorithms

import time
import itertools
import math
import sys
import numpy as np

# Qiskit optimization primitives
from qiskit_optimization import QuadraticProgram
from qiskit_optimization.converters import QuadraticProgramToQubo
from qiskit_optimization.algorithms import MinimumEigenOptimizer
# QAOA from qiskit_optimization
from qiskit_optimization.minimum_eigensolvers import QAOA

# Try SamplerV2 (aer) and AerSimulator with multiple constructor signatures (robust)
SamplerV2 = None
try:
    from qiskit_aer.primitives import SamplerV2 as _SamplerV2
    SamplerV2 = _SamplerV2
except Exception:
    try:
        # alternate packaging
        from qiskit.primitives import Sampler as _SamplerV2
        SamplerV2 = _SamplerV2
    except Exception:
        SamplerV2 = None

from qiskit_aer import AerSimulator  

# Try optimizers: SPSA preferred for noisy quantum, else COBYLA, else SciPy wrapper
optimizer = None
try:
    from qiskit.algorithms.optimizers import SPSA
    # keep low iterations for quick runs; tune later
    optimizer = SPSA(maxiter=50)
    print("Using SPSA optimizer from qiskit.algorithms.optimizers")
except Exception:
    try:
        from qiskit.algorithms.optimizers import COBYLA
        optimizer = COBYLA(maxiter=200)
        print("Using COBYLA optimizer from qiskit.algorithms.optimizers")
    except Exception:
        # SciPy fallback wrapper with minimize interface (for QAOA constructor compatibility)
        from scipy.optimize import minimize as scipy_minimize
        class SciPyOptimizerWrapper:
            def __init__(self, method='COBYLA', options=None):
                self.method = method
                self.options = options or {"maxiter":200}
            def optimize(self, num_vars, objective, initial_point=None):
                def obj_for_scipy(x):
                    val = objective(x)
                    return float(val) if not isinstance(val, (tuple,list)) else float(val[0])
                x0 = initial_point if initial_point is not None else [0.0]*num_vars
                res = scipy_minimize(obj_for_scipy, x0, method=self.method, options=self.options)
                return res.x, float(res.fun), getattr(res, "nfev", None)
            def minimize(self, fun, x0, **kwargs):
                method = kwargs.pop("method", self.method)
                options = kwargs.pop("options", self.options)
                res = scipy_minimize(fun, x0, method=method, options=options, **kwargs)
                return res
        optimizer = SciPyOptimizerWrapper(method='COBYLA', options={"maxiter":200})
        print("Using SciPy-based optimizer wrapper")

# Prepare a robust SamplerV2/AerSimulator instance (tries multiple constructor signatures)
sampler = None
sampler_errors = []
constructors = []
if SamplerV2 is not None:
    constructors = [
        lambda: SamplerV2(mode=AerSimulator()),
        lambda: SamplerV2(backend=AerSimulator()),
        lambda: SamplerV2(),
    ]
else:
    constructors = [lambda: AerSimulator()]

for ctor in constructors:
    try:
        sampler = ctor()
        print("Sampler created with constructor:", ctor)
        break
    except Exception as e:
        sampler_errors.append(e)

if sampler is None:
    print("Sampler constructors tried and failed. Errors:")
    for i, e in enumerate(sampler_errors, 1):
        print(f"[{i}] {type(e).__name__}: {e}")
    raise RuntimeError("Unable to instantiate Sampler/AerSimulator. Ensure qiskit-aer and primitives are installed.")

# ---- Problem data ----
distance_matrix = np.array(
      [[ 0.   ,  8.628, 11.496,  9.445, 10.852,  9.672], # H
       [14.194,  0.   ,  2.361, 10.922,  9.238,  9.43 ], # P1 (DT)
       [17.785,  7.745,  0.   , 11.808, 10.124, 10.478], # P2 (GR)
       [11.864, 19.672, 15.661,  0.   , 11.572, 11.538], # P3 (R2)
       [ 7.343, 12.172, 10.053,  4.071,  0.   ,  5.931], # P4 (R3_2)
       [ 9.269,  9.398, 12.266,  7.318,  8.725,  0.   ]]  # P5 (IT)
)
locations = ['H', 'DT', 'GR', 'R2', 'R3_2', 'IT']
patient_indices = [1,2,3,4,5]
penalty = 1000

# Helper: build TSP QuadraticProgram for a local subproblem (nodes = hospital + chosen patients)
def build_tsp_quadratic_program(dist_local, penalty=penalty):
    n = dist_local.shape[0]
    qp = QuadraticProgram(name="TSP_local")
    # binary vars x_i_j (i != j)  using local indices 0..n-1
    for i in range(n):
        for j in range(n):
            if i == j: continue
            qp.binary_var(name=f"x_{i}_{j}")
    # linear objective
    linear = {f"x_{i}_{j}": float(dist_local[i,j]) for i in range(n) for j in range(n) if i!=j}
    qp.minimize(linear=linear)
    # constraints: arrive and depart exactly once
    for i in range(n):
        arrive = {f"x_{j}_{i}": 1 for j in range(n) if j!=i}
        qp.linear_constraint(linear=arrive, sense="==", rhs=1, name=f"arrive_{i}")
        depart = {f"x_{i}_{j}": 1 for j in range(n) if j!=i}
        qp.linear_constraint(linear=depart, sense="==", rhs=1, name=f"depart_{i}")
    # convert to QUBO
    qubo = QuadraticProgramToQubo(penalty=penalty).convert(qp)
    return qp, qubo

# Helper: reconstruct tour from result.variables_dict (local indices)
def reconstruct_tour_from_solution(variables_dict):
    path_dict = {}
    for varname, val in variables_dict.items():
        try:
            if float(val) > 0.5:
                parts = varname.split('_')
                # expecting "x_i_j"
                if len(parts) >= 3:
                    si = int(parts[1]); sj = int(parts[2])
                    path_dict[si] = sj
        except Exception:
            continue
    # walk from 0
    path = [0]
    cur = 0
    while True:
        nxt = path_dict.get(cur, None)
        if nxt is None: break
        if nxt in path:
            # avoid loops
            break
        path.append(nxt)
        cur = nxt
        if len(path) > 50: break
    # optionally append return to start
    if len(path) >= 1 and path[-1] != 0 and len(path) == len(path_dict)+1:
        path.append(0)
    return path

# Top-level hybrid search: enumerate all combinations of 3 patients for Trip A
best = {
    "distance": float('inf'),
    "trip_A_group": None,
    "trip_B_group": None,
    "trip_A_route": None,
    "trip_B_route": None,
    "trip_A_dist": None,
    "trip_B_dist": None,
    "qaoa_params": None
}

print("Starting hybrid search: Trip A quantum (QAOA) on 3 patients, Trip B classical (2 patients).")
for idx, group_A in enumerate(itertools.combinations(patient_indices, 3), start=1):
    print(f"\n--- Combination {idx}/10: Trip A patients = {[locations[i] for i in group_A]} ---")
    group_B = tuple(p for p in patient_indices if p not in group_A)

    # Build local distance matrix for Trip A (hospital + the 3 chosen patients)
    trip_A_nodes = (0,) + group_A  # local mapping -> global indices
    dist_A_local = distance_matrix[np.ix_(trip_A_nodes, trip_A_nodes)]
    n_local = dist_A_local.shape[0]
    print(f"Local problem size n_local={n_local} nodes -> expected qubits m = n_local*(n_local-1) = {n_local*(n_local-1)}")

    # Build quadratic program and QUBO
    qp_local, qubo_local = build_tsp_quadratic_program(dist_A_local, penalty=penalty)

    # Instantiate QAOA with sampler + optimizer (try some constructor orders like in your working code)
    qaoa = None
    qaoa_errors = []
    attempts = [
        {"sampler": sampler, "optimizer": optimizer, "reps": 2},
        {"optimizer": optimizer, "sampler": sampler, "reps": 2},
        {"sampler": sampler, "reps": 2, "optimizer": optimizer},
    ]
    for kwargs in attempts:
        try:
            qaoa = QAOA(**kwargs)
            print("QAOA instantiated with args:", {k:v for k,v in kwargs.items() if k!='sampler'})
            break
        except Exception as e:
            qaoa_errors.append((kwargs, e))

    if qaoa is None:
        print("QAOA instantiation attempts failed. Details:")
        for kw, err in qaoa_errors:
            print("Attempt:", {k: (v if k!='sampler' else "<sampler>") for k,v in kw.items()})
            print(" ->", type(err).__name__, err)
        raise RuntimeError("QAOA could not be instantiated in this environment. No fallback (quantum required).")

    # Wrap in MinimumEigenOptimizer (try both calling conventions)
    try:
        meo = MinimumEigenOptimizer(min_eigen_solver=qaoa)
    except TypeError:
        meo = MinimumEigenOptimizer(qaoa)

    # Solve using quantum QAOA
    print("Running MinimumEigenOptimizer (QAOA) on QUBO (this will call the sampler)...")
    t0 = time.time()
    result = meo.solve(qubo_local)
    t1 = time.time()
    print(f"QAOA solve finished in {t1-t0:.3f} s. Status: {result.status if hasattr(result,'status') else 'unknown'}")
    print(f"Raw QUBO objective (result.fval): {result.fval:.6f}")

    # Reconstruct local tour and convert to global node labels
    path_local = reconstruct_tour_from_solution(result.variables_dict)
    # Ensure path_local includes all nodes; if not, still convert what we have but warn
    if len(path_local) < n_local:
        print("Warning: extracted path is incomplete (may be due to QAOA approximation). Extracted local path:", path_local)
    path_global = [trip_A_nodes[i] for i in path_local]

    # Compute trip A distance (use brute force to compute true route cost of chosen permutation)
    # If the solution contains full ordering (excluding final return 0), evaluate it; otherwise recompute best permutation among selected nodes
    tripA_dist = None
    if len(path_local) == n_local and path_local[0] == 0:
        # full order found
        # ensure return to 0 at end
        tour = path_local + ([0] if path_local[-1] != 0 else [])
        # compute cost
        tripA_dist = 0.0
        for a,b in zip(tour[:-1], tour[1:]):
            tripA_dist += float(dist_A_local[a,b])
    else:
        # fallback: interpret variables' selected edges to derive the set of visited patients and brute-force the best order among them
        # Build set of selected patient local indices (exclude 0)
        selected = sorted([j for j in range(1,n_local) if any((f"x_{i}_{j}" in result.variables_dict and result.variables_dict[f"x_{i}_{j}"]>0.5) for i in range(n_local) if i!=j)])
        if not selected:
            raise RuntimeError("QAOA returned no selected patient edges; aborting.")
        # brute-force best order among selected patients
        best_perm = None; best_perm_cost = math.inf
        for perm in itertools.permutations(selected):
            tour = [0] + list(perm) + [0]
            cost = sum(float(dist_A_local[a,b]) for a,b in zip(tour[:-1], tour[1:]))
            if cost < best_perm_cost:
                best_perm_cost = cost; best_perm = perm
        tripA_dist = best_perm_cost
        # set path_global accordingly
        path_global = [trip_A_nodes[i] for i in ([0] + list(best_perm) + [0])]
        print("QAOA didn't give a clean Hamiltonian cycle; selected patients:", [trip_A_nodes[i] for i in selected])
        print("Using brute-force best permutation among selected patients:", best_perm, "cost:", best_perm_cost)

    # --- Trip B (2 patients) solved classically exactly ---
    p1, p2 = group_B
    # two possible routes: H->p1->p2->H or H->p2->p1->H (global indexing)
    dist_B_option1 = distance_matrix[0,p1] + distance_matrix[p1,p2] + distance_matrix[p2,0]
    dist_B_option2 = distance_matrix[0,p2] + distance_matrix[p2,p1] + distance_matrix[p1,0]
    if dist_B_option1 <= dist_B_option2:
        tripB_dist = float(dist_B_option1)
        pathB_global = [0, p1, p2, 0]
    else:
        tripB_dist = float(dist_B_option2)
        pathB_global = [0, p2, p1, 0]

    total = float(tripA_dist) + float(tripB_dist)
    print(f"Trip A distance (evaluated): {tripA_dist:.6f}, Trip B distance: {tripB_dist:.6f}, Total: {total:.6f}")

    # Update best if improved
    if total < best["distance"]:
        best.update({
            "distance": total,
            "trip_A_group": [locations[i] for i in group_A],
            "trip_B_group": [locations[i] for i in group_B],
            "trip_A_route": [locations[i] for i in path_global],
            "trip_B_route": [locations[i] for i in pathB_global],
            "trip_A_dist": tripA_dist,
            "trip_B_dist": tripB_dist,
            "qaoa_time": t1-t0,
            "qaoa_sampler_constructor": type(sampler).__name__
        })
        print(">> New best solution recorded.")

# Final printout
print("\n" + "="*50)
print("FINAL BEST SOLUTION (quantum Trip A):")
print("Total optimal distance (hybrid): {:.6f}".format(best["distance"]))
print("Trip A (3 patients):", best["trip_A_group"], "Route:", " -> ".join(best["trip_A_route"]), f"Distance: {best['trip_A_dist']:.6f}")
print("Trip B (2 patients):", best["trip_B_group"], "Route:", " -> ".join(best["trip_B_route"]), f"Distance: {best['trip_B_dist']:.6f}")
print("QAOA sampler:", best.get("qaoa_sampler_constructor"), "QAOA time (s):", best.get("qaoa_time"))
print("="*50)
# Out:
# Collecting qiskit
#   Downloading qiskit-2.1.2-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (12 kB)
# Collecting qiskit-aer
#   Downloading qiskit_aer-0.17.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (8.3 kB)
# Collecting qiskit-optimization
#   Downloading qiskit_optimization-0.7.0-py3-none-any.whl.metadata (9.4 kB)
# Collecting qiskit_algorithms
#   Downloading qiskit_algorithms-0.4.0-py3-none-any.whl.metadata (4.7 kB)
# Collecting rustworkx>=0.15.0 (from qiskit)
#   Downloading rustworkx-0.17.1-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (10 kB)
# Requirement already satisfied: numpy<3,>=1.17 in /usr/local/lib/python3.12/dist-packages (from qiskit) (2.0.2)
# Requirement already satisfied: scipy>=1.5 in /usr/local/lib/python3.12/dist-packages (from qiskit) (1.16.1)
# Requirement already satisfied: dill>=0.3 in /usr/local/lib/python3.12/dist-packages (from qiskit) (0.3.8)
# Collecting stevedore>=3.0.0 (from qiskit)
#   Downloading stevedore-5.5.0-py3-none-any.whl.metadata (2.2 kB)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.12/dist-packages (from qiskit) (4.15.0)
# Requirement already satisfied: psutil>=5 in /usr/local/lib/python3.12/dist-packages (from qiskit-aer) (5.9.5)
# Requirement already satisfied: python-dateutil>=2.8.0 in /usr/local/lib/python3.12/dist-packages (from qiskit-aer) (2.9.0.post0)
# Collecting docplex!=2.24.231,>=2.21.207 (from qiskit-optimization)
#   Downloading docplex-2.30.251.tar.gz (646 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 646.5/646.5 kB 9.7 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: setuptools>=40.1.0 in /usr/local/lib/python3.12/dist-packages (from qiskit-optimization) (75.2.0)
# Requirement already satisfied: networkx>=2.6.3 in /usr/local/lib/python3.12/dist-packages (from qiskit-optimization) (3.5)
# Requirement already satisfied: six in /usr/local/lib/python3.12/dist-packages (from docplex!=2.24.231,>=2.21.207->qiskit-optimization) (1.17.0)
# Downloading qiskit-2.1.2-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.4/7.4 MB 89.0 MB/s eta 0:00:00
# Downloading qiskit_aer-0.17.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (12.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.4/12.4 MB 113.0 MB/s eta 0:00:00
# Downloading qiskit_optimization-0.7.0-py3-none-any.whl (237 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 237.1/237.1 kB 18.0 MB/s eta 0:00:00
# Downloading qiskit_algorithms-0.4.0-py3-none-any.whl (327 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 327.8/327.8 kB 28.3 MB/s eta 0:00:00
# Downloading rustworkx-0.17.1-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 93.7 MB/s eta 0:00:00
# Downloading stevedore-5.5.0-py3-none-any.whl (49 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.5/49.5 kB 4.7 MB/s eta 0:00:00
# Building wheels for collected packages: docplex
#   Building wheel for docplex (pyproject.toml) ... done
#   Created wheel for docplex: filename=docplex-2.30.251-py3-none-any.whl size=685954 sha256=767e8284391da35b2965d23fab2e9f1e7a911271eb05d543d3299e9999df96d1
#   Stored in directory: /root/.cache/pip/wheels/c1/d9/5c/1d919b1e441ebbaff244513a13d09c3c0378401601d4184bb0
# Successfully built docplex
# Installing collected packages: stevedore, rustworkx, docplex, qiskit, qiskit-optimization, qiskit_algorithms, qiskit-aer
# Successfully installed docplex-2.30.251 qiskit-2.1.2 qiskit-aer-0.17.1 qiskit-optimization-0.7.0 qiskit_algorithms-0.4.0 rustworkx-0.17.1 stevedore-5.5.0
# Using SciPy-based optimizer wrapper
# Sampler created with constructor: <function <lambda> at 0x7f069fb67240>
# Starting hybrid search: Trip A quantum (QAOA) on 3 patients, Trip B classical (2 patients).
#
# --- Combination 1/10: Trip A patients = ['DT', 'GR', 'R2'] ---
# Local problem size n_local=4 nodes -> expected qubits m = n_local*(n_local-1) = 12
# QAOA instantiated with args: {'optimizer': <__main__.SciPyOptimizerWrapper object at 0x7f06c9fd56a0>, 'reps': 2}
# Running MinimumEigenOptimizer (QAOA) on QUBO (this will call the sampler)...
# /usr/local/lib/python3.12/dist-packages/qiskit_optimization/minimum_eigensolvers/qaoa.py:122: UserWarning: Using Sampler V2 (other than StatevectorSampler) without a pass_manager may result in an error. Consider providing a pass_manager for proper circuit transpilation.
#   super().__init__(
# QAOA solve finished in 2.125 s. Status: OptimizationResultStatus.SUCCESS
# Raw QUBO objective (result.fval): 47.045000
# Trip A distance (evaluated): 47.045000, Trip B distance: 25.740000, Total: 72.785000
# >> New best solution recorded.
#
# --- Combination 2/10: Trip A patients = ['DT', 'GR', 'R3_2'] ---
# Local problem size n_local=4 nodes -> expected qubits m = n_local*(n_local-1) = 12
# QAOA instantiated with args: {'optimizer': <__main__.SciPyOptimizerWrapper object at 0x7f06c9fd56a0>, 'reps': 2}
# Running MinimumEigenOptimizer (QAOA) on QUBO (this will call the sampler)...
# /usr/local/lib/python3.12/dist-packages/qiskit_optimization/minimum_eigensolvers/qaoa.py:122: UserWarning: Using Sampler V2 (other than StatevectorSampler) without a pass_manager may result in an error. Consider providing a pass_manager for proper circuit transpilation.
#   super().__init__(
# QAOA solve finished in 3.437 s. Status: OptimizationResultStatus.SUCCESS
# Raw QUBO objective (result.fval): 43.170000
# Trip A distance (evaluated): 43.170000, Trip B distance: 28.854000, Total: 72.024000
# >> New best solution recorded.
#
# --- Combination 3/10: Trip A patients = ['DT', 'GR', 'IT'] ---
# Local problem size n_local=4 nodes -> expected qubits m = n_local*(n_local-1) = 12
# QAOA instantiated with args: {'optimizer': <__main__.SciPyOptimizerWrapper object at 0x7f06c9fd56a0>, 'reps': 2}
# Running MinimumEigenOptimizer (QAOA) on QUBO (this will call the sampler)...
# /usr/local/lib/python3.12/dist-packages/qiskit_optimization/minimum_eigensolvers/qaoa.py:122: UserWarning: Using Sampler V2 (other than StatevectorSampler) without a pass_manager may result in an error. Consider providing a pass_manager for proper circuit transpilation.
#   super().__init__(
# QAOA solve finished in 1.899 s. Status: OptimizationResultStatus.SUCCESS
# Raw QUBO objective (result.fval): 43.877000
# Trip A distance (evaluated): 43.877000, Trip B distance: 26.787000, Total: 70.664000
# >> New best solution recorded.
#
# --- Combination 4/10: Trip A patients = ['DT', 'R2', 'R3_2'] ---
# Local problem size n_local=4 nodes -> expected qubits m = n_local*(n_local-1) = 12
# QAOA instantiated with args: {'optimizer': <__main__.SciPyOptimizerWrapper object at 0x7f06c9fd56a0>, 'reps': 2}
# Running MinimumEigenOptimizer (QAOA) on QUBO (this will call the sampler)...
# /usr/local/lib/python3.12/dist-packages/qiskit_optimization/minimum_eigensolvers/qaoa.py:122: UserWarning: Using Sampler V2 (other than StatevectorSampler) without a pass_manager may result in an error. Consider providing a pass_manager for proper circuit transpilation.
#   super().__init__(
# QAOA solve finished in 1.468 s. Status: OptimizationResultStatus.SUCCESS
# Raw QUBO objective (result.fval): 45.810000
# Trip A distance (evaluated): 45.810000, Trip B distance: 31.243000, Total: 77.053000
#
# --- Combination 5/10: Trip A patients = ['DT', 'R2', 'IT'] ---
# Local problem size n_local=4 nodes -> expected qubits m = n_local*(n_local-1) = 12
# QAOA instantiated with args: {'optimizer': <__main__.SciPyOptimizerWrapper object at 0x7f06c9fd56a0>, 'reps': 2}
# Running MinimumEigenOptimizer (QAOA) on QUBO (this will call the sampler)...
# /usr/local/lib/python3.12/dist-packages/qiskit_optimization/minimum_eigensolvers/qaoa.py:122: UserWarning: Using Sampler V2 (other than StatevectorSampler) without a pass_manager may result in an error. Consider providing a pass_manager for proper circuit transpilation.
#   super().__init__(
# QAOA solve finished in 1.454 s. Status: OptimizationResultStatus.SUCCESS
# Raw QUBO objective (result.fval): 37.240000
# Trip A distance (evaluated): 37.240000, Trip B distance: 28.963000, Total: 66.203000
# >> New best solution recorded.
#
# --- Combination 6/10: Trip A patients = ['DT', 'R3_2', 'IT'] ---
# Local problem size n_local=4 nodes -> expected qubits m = n_local*(n_local-1) = 12
# QAOA instantiated with args: {'optimizer': <__main__.SciPyOptimizerWrapper object at 0x7f06c9fd56a0>, 'reps': 2}
# Running MinimumEigenOptimizer (QAOA) on QUBO (this will call the sampler)...
# /usr/local/lib/python3.12/dist-packages/qiskit_optimization/minimum_eigensolvers/qaoa.py:122: UserWarning: Using Sampler V2 (other than StatevectorSampler) without a pass_manager may result in an error. Consider providing a pass_manager for proper circuit transpilation.
#   super().__init__(
# QAOA solve finished in 1.786 s. Status: OptimizationResultStatus.SUCCESS
# Raw QUBO objective (result.fval): 44.763000
# Trip A distance (evaluated): 44.763000, Trip B distance: 35.168000, Total: 79.931000
#
# --- Combination 7/10: Trip A patients = ['GR', 'R2', 'R3_2'] ---
# Local problem size n_local=4 nodes -> expected qubits m = n_local*(n_local-1) = 12
# QAOA instantiated with args: {'optimizer': <__main__.SciPyOptimizerWrapper object at 0x7f06c9fd56a0>, 'reps': 2}
# Running MinimumEigenOptimizer (QAOA) on QUBO (this will call the sampler)...
# /usr/local/lib/python3.12/dist-packages/qiskit_optimization/minimum_eigensolvers/qaoa.py:122: UserWarning: Using Sampler V2 (other than StatevectorSampler) without a pass_manager may result in an error. Consider providing a pass_manager for proper circuit transpilation.
#   super().__init__(
# QAOA solve finished in 1.815 s. Status: OptimizationResultStatus.SUCCESS
# Raw QUBO objective (result.fval): 41.486000
# Warning: extracted path is incomplete (may be due to QAOA approximation). Extracted local path: [0, 2]
# QAOA didn't give a clean Hamiltonian cycle; selected patients: [2, 3, 4]
# Using brute-force best permutation among selected patients: (1, 3, 2) cost: 37.555
# Trip A distance (evaluated): 37.555000, Trip B distance: 27.327000, Total: 64.882000
# >> New best solution recorded.
#
# --- Combination 8/10: Trip A patients = ['GR', 'R2', 'IT'] ---
# Local problem size n_local=4 nodes -> expected qubits m = n_local*(n_local-1) = 12
# QAOA instantiated with args: {'optimizer': <__main__.SciPyOptimizerWrapper object at 0x7f06c9fd56a0>, 'reps': 2}
# Running MinimumEigenOptimizer (QAOA) on QUBO (this will call the sampler)...
# /usr/local/lib/python3.12/dist-packages/qiskit_optimization/minimum_eigensolvers/qaoa.py:122: UserWarning: Using Sampler V2 (other than StatevectorSampler) without a pass_manager may result in an error. Consider providing a pass_manager for proper circuit transpilation.
#   super().__init__(
# QAOA solve finished in 3.231 s. Status: OptimizationResultStatus.SUCCESS
# Raw QUBO objective (result.fval): 48.137000
# Warning: extracted path is incomplete (may be due to QAOA approximation). Extracted local path: [0, 1]
# QAOA didn't give a clean Hamiltonian cycle; selected patients: [2, 3, 5]
# Using brute-force best permutation among selected patients: (1, 3, 2) cost: 41.156
# Trip A distance (evaluated): 41.156000, Trip B distance: 25.209000, Total: 66.365000
#
# --- Combination 9/10: Trip A patients = ['GR', 'R3_2', 'IT'] ---
# Local problem size n_local=4 nodes -> expected qubits m = n_local*(n_local-1) = 12
# QAOA instantiated with args: {'optimizer': <__main__.SciPyOptimizerWrapper object at 0x7f06c9fd56a0>, 'reps': 2}
# Running MinimumEigenOptimizer (QAOA) on QUBO (this will call the sampler)...
# /usr/local/lib/python3.12/dist-packages/qiskit_optimization/minimum_eigensolvers/qaoa.py:122: UserWarning: Using Sampler V2 (other than StatevectorSampler) without a pass_manager may result in an error. Consider providing a pass_manager for proper circuit transpilation.
#   super().__init__(
# QAOA solve finished in 1.585 s. Status: OptimizationResultStatus.SUCCESS
# Raw QUBO objective (result.fval): 43.937000
# Warning: extracted path is incomplete (may be due to QAOA approximation). Extracted local path: [0, 1]
# QAOA didn't give a clean Hamiltonian cycle; selected patients: [2, 4, 5]
# Using brute-force best permutation among selected patients: (1, 2, 3) cost: 36.82
# Trip A distance (evaluated): 36.820000, Trip B distance: 31.414000, Total: 68.234000
#
# --- Combination 10/10: Trip A patients = ['R2', 'R3_2', 'IT'] ---
# Local problem size n_local=4 nodes -> expected qubits m = n_local*(n_local-1) = 12
# QAOA instantiated with args: {'optimizer': <__main__.SciPyOptimizerWrapper object at 0x7f06c9fd56a0>, 'reps': 2}
# Running MinimumEigenOptimizer (QAOA) on QUBO (this will call the sampler)...
# /usr/local/lib/python3.12/dist-packages/qiskit_optimization/minimum_eigensolvers/qaoa.py:122: UserWarning: Using Sampler V2 (other than StatevectorSampler) without a pass_manager may result in an error. Consider providing a pass_manager for proper circuit transpilation.
#   super().__init__(
# QAOA solve finished in 1.609 s. Status: OptimizationResultStatus.SUCCESS
# Raw QUBO objective (result.fval): 35.965000
# Trip A distance (evaluated): 35.965000, Trip B distance: 28.774000, Total: 64.739000
# >> New best solution recorded.
#
# ==================================================
# FINAL BEST SOLUTION (quantum Trip A):
# Total optimal distance (hybrid): 64.739000
# Trip A (3 patients): ['R2', 'R3_2', 'IT'] Route: H -> R3_2 -> IT -> R2 Distance: 35.965000
# Trip B (2 patients): ['DT', 'GR'] Route: H -> DT -> GR -> H Distance: 28.774000
# QAOA sampler: SamplerV2 QAOA time (s): 1.6086161136627197
# ==================================================

# %% [markdown]
# ## Ideal Simulation (more logging)

# %%
# REVISED hybrid QAOA + classical hybrid search with energy logging


# !pip install qiskit qiskit-aer qiskit-optimization qiskit_algorithms

import time, itertools, math, sys, traceback
import numpy as np

from qiskit_optimization import QuadraticProgram
from qiskit_optimization.converters import QuadraticProgramToQubo
from qiskit_optimization.algorithms import MinimumEigenOptimizer
from qiskit_optimization.minimum_eigensolvers import QAOA

# Try robust sampler imports
SamplerV2 = None
try:
    from qiskit_aer.primitives import SamplerV2 as _SamplerV2
    SamplerV2 = _SamplerV2
except Exception:
    try:
        from qiskit.primitives import Sampler as _SamplerV2
        SamplerV2 = _SamplerV2
    except Exception:
        SamplerV2 = None

from qiskit_aer import AerSimulator

# optimizer selection (SPSA preferred)
optimizer = None
try:
    from qiskit.algorithms.optimizers import SPSA
    optimizer = SPSA(maxiter=50)
    print("Using SPSA optimizer")
except Exception:
    try:
        from qiskit.algorithms.optimizers import COBYLA
        optimizer = COBYLA(maxiter=200)
        print("Using COBYLA optimizer")
    except Exception:
        from scipy.optimize import minimize as scipy_minimize
        class SciPyOptimizerWrapper:
            def __init__(self, method='COBYLA', options=None):
                self.method = method
                self.options = options or {"maxiter":200}
            def optimize(self, num_vars, objective, initial_point=None):
                def obj_for_scipy(x):
                    val = objective(x)
                    return float(val) if not isinstance(val, (tuple,list)) else float(val[0])
                x0 = initial_point if initial_point is not None else [0.0]*num_vars
                res = scipy_minimize(obj_for_scipy, x0, method=self.method, options=self.options)
                return res.x, float(res.fun), getattr(res, "nfev", None)
            def minimize(self, fun, x0, **kwargs):
                method = kwargs.pop("method", self.method)
                options = kwargs.pop("options", self.options)
                res = scipy_minimize(fun, x0, method=method, options=options, **kwargs)
                return res
        optimizer = SciPyOptimizerWrapper(method='COBYLA', options={"maxiter":200})
        print("Using SciPy-based optimizer wrapper")

# reproducible seeds (helps debugging)
SEED = 1234

# Create sampler / simulator instance robustly
sampler = None
sampler_errors = []
constructors = []
if SamplerV2 is not None:
    # prefer specifying a seeded AerSimulator where possible
    constructors = [
        lambda: SamplerV2(mode=AerSimulator(seed_simulator=SEED, seed_transpiler=SEED)),
        lambda: SamplerV2(backend=AerSimulator(seed_simulator=SEED, seed_transpiler=SEED)),
        lambda: SamplerV2()
    ]
else:
    constructors = [lambda: AerSimulator(seed_simulator=SEED, seed_transpiler=SEED)]

for ctor in constructors:
    try:
        sampler = ctor()
        print("Sampler created with constructor:", ctor)
        break
    except Exception as e:
        sampler_errors.append(e)

if sampler is None:
    print("Sampler constructors tried and failed. Errors:")
    for i, e in enumerate(sampler_errors, 1):
        print(f"[{i}] {type(e).__name__}: {e}")
    raise RuntimeError("Unable to instantiate Sampler/AerSimulator. Ensure qiskit-aer and primitives are installed.")

# ---- Problem data ----
distance_matrix = np.array(
      [[ 0.   ,  8.628, 11.496,  9.445, 10.852,  9.672], # H
       [14.194,  0.   ,  2.361, 10.922,  9.238,  9.43 ], # P1 (DT)
       [17.785,  7.745,  0.   , 11.808, 10.124, 10.478], # P2 (GR)
       [11.864, 19.672, 15.661,  0.   , 11.572, 11.538], # P3 (R2)
       [ 7.343, 12.172, 10.053,  4.071,  0.   ,  5.931], # P4 (R3_2)
       [ 9.269,  9.398, 12.266,  7.318,  8.725,  0.   ]]  # P5 (IT)
)
locations = ['H', 'DT', 'GR', 'R2', 'R3_2', 'IT']
patient_indices = [1,2,3,4,5]
penalty = 1000

# Helper: build TSP QuadraticProgram for a local subproblem (nodes = hospital + chosen patients)
def build_tsp_quadratic_program(dist_local, penalty=penalty):
    n = dist_local.shape[0]
    qp = QuadraticProgram(name="TSP_local")
    for i in range(n):
        for j in range(n):
            if i == j: continue
            qp.binary_var(name=f"x_{i}_{j}")
    linear = {f"x_{i}_{j}": float(dist_local[i,j]) for i in range(n) for j in range(n) if i!=j}
    qp.minimize(linear=linear)
    for i in range(n):
        arrive = {f"x_{j}_{i}": 1 for j in range(n) if j!=i}
        qp.linear_constraint(linear=arrive, sense="==", rhs=1, name=f"arrive_{i}")
        depart = {f"x_{i}_{j}": 1 for j in range(n) if j!=i}
        qp.linear_constraint(linear=depart, sense="==", rhs=1, name=f"depart_{i}")
    qubo = QuadraticProgramToQubo(penalty=penalty).convert(qp)
    return qp, qubo

def reconstruct_tour_from_solution(variables_dict):
    path_dict = {}
    for varname, val in variables_dict.items():
        try:
            if float(val) > 0.5:
                parts = varname.split('_')
                if len(parts) >= 3:
                    si = int(parts[1]); sj = int(parts[2])
                    path_dict[si] = sj
        except Exception:
            continue
    path = [0]
    cur = 0
    while True:
        nxt = path_dict.get(cur, None)
        if nxt is None: break
        if nxt in path:
            break
        path.append(nxt)
        cur = nxt
        if len(path) > 50: break
    if len(path) >= 1 and path[-1] != 0 and len(path) == len(path_dict)+1:
        path.append(0)
    return path

# energy logging structures
loss_history = []
def qaoa_callback(eval_count, parameters, mean, std):
    # This callback matches the qiskit callback signature used in some QAOA wrappers:
    loss_history.append(mean)
    print(f"[QAOA] Iter {eval_count:3d}  Energy (mean) = {mean:.8f}  std = {std if std is not None else 'N/A'}")

# Top-level hybrid search
best = {"distance": float('inf')}
print("Starting hybrid search: Trip A quantum (QAOA) on 3 patients, Trip B classical (2 patients).")

for idx, group_A in enumerate(itertools.combinations(patient_indices, 3), start=1):
    print(f"\n--- Combination {idx}/10: Trip A patients = {[locations[i] for i in group_A]} ---")
    group_B = tuple(p for p in patient_indices if p not in group_A)

    trip_A_nodes = (0,) + group_A
    dist_A_local = distance_matrix[np.ix_(trip_A_nodes, trip_A_nodes)]
    n_local = dist_A_local.shape[0]
    expected_qubits = n_local * (n_local - 1)
    print(f"Local n_local={n_local}, expected binary variables (qubits) = {expected_qubits}")

    qp_local, qubo_local = build_tsp_quadratic_program(dist_A_local, penalty=penalty)

    # instantiate QAOA robustly, include callback and optimizer
    qaoa = None
    qaoa_errors = []
    attempts = [
        {"sampler": sampler, "optimizer": optimizer, "reps": 2, "callback": qaoa_callback},
        {"optimizer": optimizer, "sampler": sampler, "reps": 2, "callback": qaoa_callback},
        {"sampler": sampler, "reps": 2, "optimizer": optimizer, "callback": qaoa_callback},
        {"sampler": sampler, "reps": 2},  # fallback without callback if not supported
    ]
    for kwargs in attempts:
        try:
            qaoa = QAOA(**kwargs)
            print("QAOA instantiated with args:", {k:v for k,v in kwargs.items() if k!='sampler' and k!='callback'})
            break
        except Exception as e:
            qaoa_errors.append((kwargs, e))
    if qaoa is None:
        print("QAOA instantiation failed. Details:")
        for kw, err in qaoa_errors:
            print("Attempt:", {k: (v if k!='sampler' else "<sampler>") for k,v in kw.items()})
            print(" ->", type(err).__name__, err)
        raise RuntimeError("QAOA could not be instantiated in this environment.")

    # Wrap in MinimumEigenOptimizer (some versions accept keyword; handle TypeError)
    try:
        meo = MinimumEigenOptimizer(min_eigen_solver=qaoa)
    except TypeError:
        meo = MinimumEigenOptimizer(qaoa)

    # Run the solver and time it
    print("Running MinimumEigenOptimizer (QAOA) on QUBO...")
    t0 = time.time()
    try:
        result = meo.solve(qubo_local)
    except Exception as e:
        print("Solver failed with exception:")
        traceback.print_exc()
        raise
    t1 = time.time()
    elapsed = t1 - t0
    print(f"QAOA solve finished in {elapsed:.3f} s. result.fval = {getattr(result,'fval', 'N/A')}")

    # Attempt to extract solver diagnostics (robustly)
    print("\n--- QAOA / solver diagnostics ---")
    solver_result = getattr(result, "min_eigen_solver_result", None)
    if solver_result is None:
        # some versions store solver result under 'raw_results' or 'aux_operators_evaluated' - print full object
        print("No min_eigen_solver_result attribute on result. Dumping available attributes:")
        for k in dir(result):
            if not k.startswith('_'):
                try:
                    print(" result.", k, "=", getattr(result, k))
                except Exception:
                    pass
    else:
        # many qiskit minimum_eigensolver results expose eigenvalue, optimal_parameters, aux_operators_evaluated
        try:
            eig = getattr(solver_result, "eigenvalue", None)
            print("Eigenvalue (solver_result.eigenvalue):", eig)
        except Exception:
            pass
        # try common fields
        for field in ("optimal_parameters", "optimal_point", "optimal_parameters_list", "eigenstate", "aux_operators_evaluated"):
            if hasattr(solver_result, field):
                print(f"solver_result.{field}:", getattr(solver_result, field))

    # also print the optimization trace we recorded via callback
    if loss_history:
        print("\nQAOA loss_history (last 10):", loss_history[-10:])
    else:
        print("No loss_history recorded via callback (callback may not have been called).")

    # Reconstruct route from result and evaluate trip A distance
    path_local = reconstruct_tour_from_solution(result.variables_dict)
    if len(path_local) < n_local:
        print("Warning: extracted path is incomplete (may be due to QAOA approximation). Extracted local path:", path_local)

    # compute trip A distance either from path_local or brute-force among selected
    tripA_dist = None
    if len(path_local) == n_local and path_local[0] == 0:
        tour = path_local + ([0] if path_local[-1] != 0 else [])
        tripA_dist = 0.0
        for a,b in zip(tour[:-1], tour[1:]):
            tripA_dist += float(dist_A_local[a,b])
    else:
        # fallback: brute-force best order among selected patients indicated by selected edges
        selected = sorted([j for j in range(1,n_local) if any((f"x_{i}_{j}" in result.variables_dict and result.variables_dict[f"x_{i}_{j}"]>0.5) for i in range(n_local) if i!=j)])
        if not selected:
            raise RuntimeError("QAOA returned no selected patient edges; aborting.")
        best_perm = None; best_perm_cost = math.inf
        for perm in itertools.permutations(selected):
            tour = [0] + list(perm) + [0]
            cost = sum(float(dist_A_local[a,b]) for a,b in zip(tour[:-1], tour[1:]))
            if cost < best_perm_cost:
                best_perm_cost = cost; best_perm = perm
        tripA_dist = best_perm_cost
        path_global = [trip_A_nodes[i] for i in ([0] + list(best_perm) + [0])]
        print("QAOA didn't give a clean Hamiltonian cycle; selected patients:", [trip_A_nodes[i] for i in selected])
        print("Using brute-force best permutation among selected patients:", best_perm, "cost:", best_perm_cost)
    # If earlier we had a full path_local, convert to global
    if len(path_local) == n_local:
        path_global = [trip_A_nodes[i] for i in path_local]
        if path_global[-1] != 0:
            path_global = path_global + [0]

    # --- Trip B classical exact (2 patients) ---
    p1, p2 = group_B
    dist_B_option1 = distance_matrix[0,p1] + distance_matrix[p1,p2] + distance_matrix[p2,0]
    dist_B_option2 = distance_matrix[0,p2] + distance_matrix[p2,p1] + distance_matrix[p1,0]
    if dist_B_option1 <= dist_B_option2:
        tripB_dist = float(dist_B_option1)
        pathB_global = [0, p1, p2, 0]
    else:
        tripB_dist = float(dist_B_option2)
        pathB_global = [0, p2, p1, 0]

    total = float(tripA_dist) + float(tripB_dist)
    print(f"Trip A distance (evaluated): {tripA_dist:.6f}, Trip B distance: {tripB_dist:.6f}, Total: {total:.6f}")

    if total < best["distance"]:
        best.update({
            "distance": total,
            "trip_A_group": [locations[i] for i in group_A],
            "trip_B_group": [locations[i] for i in group_B],
            "trip_A_route": [locations[i] for i in path_global],
            "trip_B_route": [locations[i] for i in pathB_global],
            "trip_A_dist": tripA_dist,
            "trip_B_dist": tripB_dist,
            "qaoa_time": elapsed,
            "qaoa_sampler_constructor": type(sampler).__name__,
            "loss_history_snapshot": loss_history[-20:]
        })
        print(">> New best solution recorded.")

# Final output
print("\n" + "="*50)
print("FINAL BEST SOLUTION (quantum Trip A):")
print("Total optimal distance (hybrid): {:.6f}".format(best["distance"]))
print("Trip A (3 patients):", best["trip_A_group"], "Route:", " -> ".join(best["trip_A_route"]), f"Distance: {best['trip_A_dist']:.6f}")
print("Trip B (2 patients):", best["trip_B_group"], "Route:", " -> ".join(best["trip_B_route"]), f"Distance: {best['trip_B_dist']:.6f}")
print("QAOA sampler:", best.get("qaoa_sampler_constructor"), "QAOA time (s):", best.get("qaoa_time"))
print("="*50)
# Out:
# Requirement already satisfied: qiskit in /usr/local/lib/python3.12/dist-packages (2.1.2)
# Requirement already satisfied: qiskit-aer in /usr/local/lib/python3.12/dist-packages (0.17.1)
# Requirement already satisfied: qiskit-optimization in /usr/local/lib/python3.12/dist-packages (0.7.0)
# Requirement already satisfied: qiskit_algorithms in /usr/local/lib/python3.12/dist-packages (0.4.0)
# Requirement already satisfied: rustworkx>=0.15.0 in /usr/local/lib/python3.12/dist-packages (from qiskit) (0.17.1)
# Requirement already satisfied: numpy<3,>=1.17 in /usr/local/lib/python3.12/dist-packages (from qiskit) (2.0.2)
# Requirement already satisfied: scipy>=1.5 in /usr/local/lib/python3.12/dist-packages (from qiskit) (1.16.1)
# Requirement already satisfied: dill>=0.3 in /usr/local/lib/python3.12/dist-packages (from qiskit) (0.3.8)
# Requirement already satisfied: stevedore>=3.0.0 in /usr/local/lib/python3.12/dist-packages (from qiskit) (5.5.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.12/dist-packages (from qiskit) (4.15.0)
# Requirement already satisfied: psutil>=5 in /usr/local/lib/python3.12/dist-packages (from qiskit-aer) (5.9.5)
# Requirement already satisfied: python-dateutil>=2.8.0 in /usr/local/lib/python3.12/dist-packages (from qiskit-aer) (2.9.0.post0)
# Requirement already satisfied: docplex!=2.24.231,>=2.21.207 in /usr/local/lib/python3.12/dist-packages (from qiskit-optimization) (2.30.251)
# Requirement already satisfied: setuptools>=40.1.0 in /usr/local/lib/python3.12/dist-packages (from qiskit-optimization) (75.2.0)
# Requirement already satisfied: networkx>=2.6.3 in /usr/local/lib/python3.12/dist-packages (from qiskit-optimization) (3.5)
# Requirement already satisfied: six in /usr/local/lib/python3.12/dist-packages (from docplex!=2.24.231,>=2.21.207->qiskit-optimization) (1.17.0)
# Using SciPy-based optimizer wrapper
# Sampler created with constructor: <function <lambda> at 0x7f069d113060>
# Starting hybrid search: Trip A quantum (QAOA) on 3 patients, Trip B classical (2 patients).
#
# --- Combination 1/10: Trip A patients = ['DT', 'GR', 'R2'] ---
# Local n_local=4, expected binary variables (qubits) = 12
# QAOA instantiated with args: {'optimizer': <__main__.SciPyOptimizerWrapper object at 0x7f06a3453800>, 'reps': 2}
# Running MinimumEigenOptimizer (QAOA) on QUBO...
# [QAOA] Iter   1  Energy (mean) = 186.68607422+0.00000000j  std = {'shots': 1024, 'circuit_metadata': {}, 'simulator_metadata': {'time_taken_parameter_binding': 0.00013207, 'time_taken_execute': 0.006660458, 'omp_enabled': True, 'max_gpu_memory_mb': 0, 'max_memory_mb': 12977, 'parallel_experiments': 1}}
# [QAOA] Iter   2  Energy (mean) = 519.41172266+0.00000000j  std = {'shots': 1024, 'circuit_metadata': {}, 'simulator_metadata': {'time_taken_parameter_binding': 0.000115634, 'time_taken_execute': 0.006613547, 'omp_enabled': True, 'max_gpu_memory_mb': 0, 'max_memory_mb': 12977, 'parallel_experiments': 1}}
# [QAOA] Iter   3  Energy (mean) = 9.74084277+0.00000000j  std = {'shots': 1024, 'circuit_metadata': {}, 'simulator_metadata': {'time_taken_parameter_binding': 0.000116316, 'time_taken_execute': 0.006776594, 'omp_enabled': True, 'max_gpu_memory_mb': 0, 'max_memory_mb': 12977, 'parallel_experiments': 1}}
# [QAOA] Iter   4  Energy (mean) = 15.76058105+0.00000000j  std = {'shots': 1024, 'circuit_metadata': {}, 'simulator_metadata': {'time_taken_parameter_binding': 0.000126399, 'time_taken_execute': 0.006655666, 'omp_enabled': True, 'max_gpu_memory_mb': 0, 'max_memory_mb': 12977, 'parallel_experiments': 1}}
# [QAOA] Iter   5  Energy (mean) = 260.32493555+0.00000000j  std = {'shots': 1024, 'circuit_metadata': {}, 'simulator_metadata': {'time_taken_parameter_binding': 0.000120887, 'time_taken_execute': 0.00673706, 'omp_enabled': True, 'max_gpu_memory_mb': 0, 'max_memory_mb': 12977, 'parallel_experiments': 1}}
# /usr/local/lib/python3.12/dist-packages/qiskit_optimization/minimum_eigensolvers/qaoa.py:122: UserWarning: Using Sampler V2 (other than StatevectorSampler) without a pass_manager may result in an error. Consider providing a pass_manager for proper circuit transpilation.
#   super().__init__(
# [QAOA] Iter   6  Energy (mean) = 213.57461426+0.00000000j  std = {'shots': 1024, 'circuit_metadata': {}, 'simulator_metadata': {'time_taken_parameter_binding': 0.000115447, 'time_taken_execute': 0.006588177, 'omp_enabled': True, 'max_gpu_memory_mb': 0, 'max_memory_mb': 12977, 'parallel_experiments': 1}}
# [QAOA] Iter   7  Energy (mean) = -2890.31883984+0.00000000j  std = {'shots': 1024, 'circuit_metadata': {}, 'simulator_metadata': {'time_taken_parameter_binding': 0.00011479, 'time_taken_execute': 0.006253136, 'omp_enabled': True, 'max_gpu_memory_mb': 0, 'max_memory_mb': 12977, 'parallel_experiments': 1}}
# [QAOA] Iter   8  Energy (mean) = 5.55937402+0.00000000j  std = {'shots': 1024, 'circuit_metadata': {}, 'simulator_metadata': {'time_taken_parameter_binding': 0.000116176, 'time_taken_execute': 0.006710766, 'omp_enabled': True, 'max_gpu_memory_mb': 0, 'max_memory_mb': 12977, 'parallel_experiments': 1}}
# [QAOA] Iter   9  Energy (mean) = -153.06607617+0.00000000j  std = {'shots': 1024, 'circuit_metadata': {}, 'simulator_metadata': {'time_taken_parameter_binding': 0.000120321, 'time_taken_execute': 0.006752074, 'omp_enabled': True, 'max_gpu_memory_mb': 0, 'max_memory_mb': 12977, 'parallel_experiments': 1}}
# [QAOA] Iter  10  Energy (mean) = -328.60686914+0.00000000j  std = {'shots': 1024, 'circuit_metadata': {}, 'simulator_metadata': {'time_taken_parameter_binding': 0.000114785, 'time_taken_execute': 0.00663314, 'omp_enabled': True, 'max_gpu_memory_mb': 0, 'max_memory_mb': 12977, 'parallel_experiments': 1}}
# [QAOA] Iter  11  Energy (mean) = -41.48216016+0.00000000j  std = {'shots': 1024, 'circuit_metadata': {}, 'simulator_metadata': {'time_taken_parameter_binding': 0.000117528, 'time_taken_execute': 0.006624617, 'omp_enabled': True, 'max_gpu_memory_mb': 0, 'max_memory_mb': 12977, 'parallel_experiments': 1}}
# [QAOA] Iter  12  Energy (mean) = -461.71721777+0.00000000j  std = {'shots': 1024, 'circuit_metadata': {}, 'simulator_metadata': {'time_taken_parameter_binding': 0.000118082, 'time_taken_execute': 0.006649559, 'omp_enabled': True, 'max_gpu_memory_mb': 0, 'max_memory_mb': 12977, 'parallel_experiments': 1}}
# [QAOA] Iter  13  Energy (mean) = -1187.74989844+0.00000000j  std = {'shots': 1024, 'circuit_metadata': {}, 'simulator_metadata': {'time_taken_parameter_binding': 0.000120206, 'time_taken_execute': 0.006809565, 'omp_enabled': True, 'max_gpu_memory_mb': 0, 'max_memory_mb': 12977, 'parallel_experiments': 1}}
# [QAOA] Iter  14  Energy (mean) = 1133.67811328+0.00000000j  std = {'shots': 1024, 'circuit_metadata': {}, 'simulator_metadata': {'time_taken_parameter_binding': 0.000135669, 'time_taken_execute': 0.006571088, 'omp_enabled': True, 'max_gpu_memory_mb': 0, 'max_memory_mb': 12977, 'parallel_experiments': 1}}
# [QAOA] Iter  15  Energy (mean) = -1075.03228223+0.00000000j  std = {'shots': 1024, 'circuit_metadata': {}, 'simulator_metadata': {'time_taken_parameter_binding': 0.000116205, 'time_taken_execute': 0.007529152, 'omp_enabled': True, 'max_gpu_memory_mb': 0, 'max_memory_mb': 12977, 'parallel_experiments': 1}}
# [QAOA] Iter  16  Energy (mean) = -5.74918848+0.00000000j  std = {'shots': 1024, 'circuit_metadata': {}, 'simulator_metadata': {'time_taken_parameter_binding': 0.000186009, 'time_taken_execute': 0.011828306, 'omp_enabled': True, 'max_gpu_memory_mb': 0, 'max_memory_mb': 12977, 'parallel_experiments': 1}}
# [QAOA] Iter  17  Energy (mean) = 101.28197656+0.00000000j  std = {'shots': 1024, 'circuit_metadata': {}, 'simulator_metadata': {'time_taken_parameter_binding': 0.000187624, 'time_taken_execute': 0.014799458, 'omp_enabled': True, 'max_gpu_memory_mb': 0, 'max_memory_mb': 12977, 'parallel_experiments': 1}}
# [QAOA] Iter  18  Energy (mean) = 3812.92064355+0.00000000j  std = {'shots': 1024, 'circuit_metadata': {}, 'simulator_metadata': {'time_taken_parameter_binding': 0.000200862, 'time_taken_execute': 0.011825946, 'omp_enabled': True, 'max_gpu_memory_mb': 0, 'max_memory_mb': 12977, 'parallel_experiments': 1}}
# [QAOA] Iter  19  Energy (mean) = -1457.57805273+0.00000000j  std = {'shots': 1024, 'circuit_metadata': {}, 'simulator_metadata': {'time_taken_parameter_binding': 0.000174131, 'time_taken_execute': 0.010496483, 'omp_enabled': True, 'max_gpu_memory_mb': 0, 'max_memory_mb': 12977, 'parallel_experiments': 1}}
# [QAOA] Iter  20  Energy (mean) = 61.29529590+0.00000000j  std = {'shots': 1024, 'circuit_metadata': {}, 'simulator_metadata': {'time_taken_parameter_binding': 0.000125892, 'time_taken_execute': 0.028410223, 'omp_enabled': True, 'max_gpu_memory_mb': 0, 'max_memory_mb': 12977, 'parallel_experiments': 1}}
# [QAOA] Iter  21  Energy (mean) = -2305.55324902+0.00000000j  std = {'shots': 1024, 'circuit_metadata': {}, 'simulator_metadata': {'time_taken_parameter_binding': 0.000181544, 'time_taken_execute': 0.011289523, 'omp_enabled': True, 'max_gpu_memory_mb': 0, 'max_memory_mb': 12977, 'parallel_experiments': 1}}
# [QAOA] Iter  22  Energy (mean) = -55.04693457+0.00000000j  std = {'shots': 1024, 'circuit_metadata': {}, 'simulator_metadata': {'time_taken_parameter_binding': 0.000196485, 'time_taken_execute': 0.009561135, 'omp_enabled': True, 'max_gpu_memory_mb': 0, 'max_memory_mb': 12977, 'parallel_experiments': 1}}
# [QAOA] Iter  23  Energy (mean) = 2444.03379297+0.00000000j  std = {'shots': 1024, 'circuit_metadata': {}, 'simulator_metadata': {'time_taken_parameter_binding': 0.000192057, 'time_taken_execute': 0.008900088, 'omp_enabled': True, 'max_gpu_memory_mb': 0, 'max_memory_mb': 12977, 'parallel_experiments': 1}}
# [QAOA] Iter  24  Energy (mean) = 3115.05756641+0.00000000j  std = {'shots': 1024, 'circuit_metadata': {}, 'simulator_metadata': {'time_taken_parameter_binding': 0.00017433, 'time_taken_execute': 0.010195899, 'omp_enabled': True, 'max_gpu_memory_mb': 0, 'max_memory_mb': 12977, 'parallel_experiments': 1}}
# [QAOA] Iter  25  Energy (mean) = -245.79682129+0.00000000j  std = {'shots': 1024, 'circuit_metadata': {}, 'simulator_metadata': {'time_taken_parameter_binding': 0.000194468, 'time_taken_execute': 0.028558824, 'omp_enabled': True, 'max_gpu_memory_mb': 0, 'max_memory_mb': 12977, 'parallel_experiments': 1}}
# [QAOA] Iter  26  Energy (mean) = -2137.35364941+0.00000000j  std = {'shots': 1024, 'circuit_metadata': {}, 'simulator_metadata': {'time_taken_parameter_binding': 0.000194504, 'time_taken_execute': 0.009671009, 'omp_enabled': True, 'max_gpu_memory_mb': 0, 'max_memory_mb': 12977, 'parallel_experiments': 1}}
# [QAOA] Iter  27  Energy (mean) = -26.89391699+0.00000000j  std = {'shots': 1024, 'circuit_metadata': {}, 'simulator_metadata': {'time_taken_parameter_binding': 0.000173313, 'time_taken_execute': 0.030645001, 'omp_enabled': True, 'max_gpu_memory_mb': 0, 'max_memory_mb': 12977, 'parallel_experiments': 1}}
# [QAOA] Iter  28  Energy (mean) = -2486.28966895+0.00000000j  std = {'shots': 1024, 'circuit_metadata': {}, 'simulator_metadata': {'time_taken_parameter_binding': 0.000178469, 'time_taken_execute': 0.024852942, 'omp_enabled': True, 'max_gpu_memory_mb': 0, 'max_memory_mb': 12977, 'parallel_experiments': 1}}
# [QAOA] Iter  29  Energy (mean) = -222.97162305+0.00000000j  std = {'shots': 1024, 'circuit_metadata': {}, 'simulator_metadata': {'time_taken_parameter_binding': 0.000183829, 'time_taken_execute': 0.009884551, 'omp_enabled': True, 'max_gpu_memory_mb': 0, 'max_memory_mb': 12977, 'parallel_experiments': 1}}
# [QAOA] Iter  30  Energy (mean) = 710.40821875+0.00000000j  std = {'shots': 1024, 'circuit_metadata': {}, 'simulator_metadata': {'time_taken_parameter_binding': 0.000189978, 'time_taken_execute': 0.0088924, 'omp_enabled': True, 'max_gpu_memory_mb': 0, 'max_memory_mb': 12977, 'parallel_experiments': 1}}
# [QAOA] Iter  31  Energy (mean) = -2480.64466211+0.00000000j  std = {'shots': 1024, 'circuit_metadata': {}, 'simulator_metadata': {'time_taken_parameter_binding': 0.000195293, 'time_taken_execute': 0.011665848, 'omp_enabled': True, 'max_gpu_memory_mb': 0, 'max_memory_mb': 12977, 'parallel_experiments': 1}}
# [QAOA] Iter  32  Energy (mean) = -2666.23787793+0.00000000j  std = {'shots': 1024, 'circuit_metadata': {}, 'simulator_metadata': {'time_taken_parameter_binding': 0.000173506, 'time_taken_execute': 0.00922777, 'omp_enabled': True, 'max_gpu_memory_mb': 0, 'max_memory_mb': 12977, 'parallel_experiments': 1}}
# [QAOA] Iter  33  Energy (mean) = -2678.85951855+0.00000000j  std = {'shots': 1024, 'circuit_metadata': {}, 'simulator_metadata': {'time_taken_parameter_binding': 0.000182242, 'time_taken_execute': 0.029611708, 'omp_enabled': True, 'max_gpu_memory_mb': 0, 'max_memory_mb': 12977, 'parallel_experiments': 1}}
# [QAOA] Iter  34  Energy (mean) = -2558.83440137+0.00000000j  std = {'shots': 1024, 'circuit_metadata': {}, 'simulator_metadata': {'time_taken_parameter_binding': 0.000182786, 'time_taken_execute': 0.028687586, 'omp_enabled': True, 'max_gpu_memory_mb': 0, 'max_memory_mb': 12977, 'parallel_experiments': 1}}
# [QAOA] Iter  35  Energy (mean) = -2702.17533691+0.00000000j  std = {'shots': 1024, 'circuit_metadata': {}, 'simulator_metadata': {'time_taken_parameter_binding': 0.000191048, 'time_taken_execute': 0.028640862, 'omp_enabled': True, 'max_gpu_memory_mb': 0, 'max_memory_mb': 12977, 'parallel_experiments': 1}}
# [QAOA] Iter  36  Energy (mean) = -2645.20839746+0.00000000j  std = {'shots': 1024, 'circuit_metadata': {}, 'simulator_metadata': {'time_taken_parameter_binding': 0.000176339, 'time_taken_execute': 0.028449567, 'omp_enabled': True, 'max_gpu_memory_mb': 0, 'max_memory_mb': 12977, 'parallel_experiments': 1}}
# [QAOA] Iter  37  Energy (mean) = -2772.71609961+0.00000000j  std = {'shots': 1024, 'circuit_metadata': {}, 'simulator_metadata': {'time_taken_parameter_binding': 0.000187282, 'time_taken_execute': 0.027961001, 'omp_enabled': True, 'max_gpu_memory_mb': 0, 'max_memory_mb': 12977, 'parallel_experiments': 1}}
# QAOA solve finished in 2.792 s. result.fval = 31.414999999999054
#
# --- QAOA / solver diagnostics ---
# Eigenvalue (solver_result.eigenvalue): -2890.3188398437474
# solver_result.optimal_parameters: {ParameterVectorElement(β[0]): np.float64(-0.16077392724639739), ParameterVectorElement(β[1]): np.float64(3.840860634950833), ParameterVectorElement(γ[0]): np.float64(-2.576842128524221), ParameterVectorElement(γ[1]): np.float64(2.8472985707151666)}
# solver_result.optimal_point: [-0.16077393  3.84086063 -2.57684213  2.84729857]
# solver_result.eigenstate: {1044: 0.0087890625, 657: 0.0029296875, 660: 0.013671875, 3161: 0.0009765625, 2324: 0.001953125, 152: 0.0009765625, 405: 0.0107421875, 172: 0.0009765625, 2198: 0.0029296875, 903: 0.0009765625, 1201: 0.001953125, 1527: 0.0009765625, 517: 0.001953125, 726: 0.0029296875, 3248: 0.0009765625, 2130: 0.001953125, 1811: 0.001953125, 3985: 0.0009765625, 1173: 0.0068359375, 96: 0.0009765625, 1715: 0.0009765625, 1234: 0.001953125, 661: 0.0087890625, 149: 0.0263671875, 720: 0.005859375, 102: 0.0009765625, 1757: 0.0029296875, 183: 0.0087890625, 1809: 0.0009765625, 211: 0.001953125, 150: 0.01171875, 3537: 0.0009765625, 3144: 0.0009765625, 209: 0.0029296875, 552: 0.0009765625, 1617: 0.001953125, 663: 0.005859375, 421: 0.001953125, 93: 0.0009765625, 3217: 0.0029296875, 648: 0.0009765625, 2373: 0.0009765625, 182: 0.0107421875, 148: 0.025390625, 17: 0.005859375, 1302: 0.0009765625, 1046: 0.001953125, 2489: 0.0009765625, 898: 0.0009765625, 3458: 0.0009765625, 3092: 0.0029296875, 400: 0.001953125, 1362: 0.001953125, 1078: 0.0009765625, 3207: 0.0009765625, 21: 0.0107421875, 1122: 0.0009765625, 151: 0.009765625, 54: 0.0009765625, 81: 0.005859375, 1042: 0.00390625, 162: 0.0009765625, 644: 0.001953125, 656: 0.0078125, 216: 0.001953125, 3730: 0.0009765625, 2688: 0.0009765625, 2387: 0.0009765625, 662: 0.0078125, 2065: 0.0009765625, 724: 0.00390625, 135: 0.001953125, 1333: 0.0009765625, 1263: 0.0009765625, 254: 0.0009765625, 1927: 0.0009765625, 465: 0.001953125, 1468: 0.0009765625, 343: 0.0009765625, 3284: 0.0009765625, 13: 0.0009765625, 2772: 0.0009765625, 1426: 0.0009765625, 916: 0.00390625, 144: 0.0078125, 3157: 0.0009765625, 213: 0.0048828125, 1360: 0.001953125, 181: 0.013671875, 212: 0.0048828125, 80: 0.0068359375, 1301: 0.001953125, 1299: 0.0009765625, 167: 0.00390625, 16: 0.0087890625, 1245: 0.0009765625, 640: 0.001953125, 2692: 0.0009765625, 466: 0.0009765625, 3805: 0.0009765625, 913: 0.00390625, 1118: 0.0009765625, 900: 0.0009765625, 145: 0.0107421875, 756: 0.0029296875, 124: 0.0009765625, 1654: 0.001953125, 132: 0.001953125, 1170: 0.005859375, 1303: 0.001953125, 341: 0.001953125, 1104: 0.0048828125, 61: 0.0009765625, 1703: 0.0009765625, 458: 0.0009765625, 1169: 0.00390625, 215: 0.0029296875, 82: 0.0029296875, 2453: 0.001953125, 1984: 0.0009765625, 1108: 0.005859375, 305: 0.001953125, 797: 0.001953125, 397: 0.00390625, 2759: 0.0009765625, 3156: 0.0029296875, 1109: 0.0009765625, 409: 0.0009765625, 406: 0.005859375, 1206: 0.001953125, 2655: 0.0009765625, 1058: 0.0009765625, 1030: 0.0009765625, 701: 0.0009765625, 277: 0.0029296875, 1620: 0.001953125, 45: 0.001953125, 1429: 0.0009765625, 219: 0.0009765625, 401: 0.00390625, 177: 0.01171875, 2639: 0.0009765625, 20: 0.0048828125, 68: 0.0009765625, 489: 0.0009765625, 428: 0.0009765625, 136: 0.0009765625, 133: 0.0029296875, 1941: 0.001953125, 389: 0.001953125, 1204: 0.0009765625, 112: 0.001953125, 147: 0.0068359375, 753: 0.0009765625, 1172: 0.00390625, 695: 0.0029296875, 1956: 0.0009765625, 2062: 0.001953125, 1612: 0.0009765625, 2709: 0.0009765625, 919: 0.0009765625, 155: 0.0009765625, 271: 0.0009765625, 1428: 0.0009765625, 3089: 0.0009765625, 1437: 0.001953125, 1950: 0.0009765625, 3088: 0.001953125, 2048: 0.0009765625, 941: 0.0009765625, 180: 0.00390625, 165: 0.001953125, 3796: 0.0009765625, 85: 0.005859375, 989: 0.0009765625, 1181: 0.0009765625, 1459: 0.001953125, 642: 0.001953125, 1937: 0.0009765625, 3479: 0.001953125, 1744: 0.0029296875, 3125: 0.0009765625, 694: 0.0029296875, 1111: 0.0009765625, 1936: 0.0009765625, 252: 0.0009765625, 1174: 0.001953125, 468: 0.0009765625, 529: 0.001953125, 1300: 0.001953125, 1153: 0.0009765625, 1052: 0.0009765625, 2739: 0.001953125, 1168: 0.001953125, 2630: 0.0009765625, 2710: 0.0029296875, 3154: 0.0009765625, 309: 0.0009765625, 3509: 0.0009765625, 1156: 0.0009765625, 163: 0.0009765625, 3473: 0.0009765625, 2004: 0.0009765625, 1581: 0.0009765625, 1924: 0.0009765625, 2767: 0.0009765625, 1872: 0.0009765625, 2734: 0.0009765625, 2176: 0.001953125 ...
# solver_result.aux_operators_evaluated: None
#
# QAOA loss_history (last 10): [np.complex128(-2486.2896689453114+0j), np.complex128(-222.97162304687538+0j), np.complex128(710.4082187499996+0j), np.complex128(-2480.6446621093746+0j), np.complex128(-2666.2378779296855+0j), np.complex128(-2678.859518554685+0j), np.complex128(-2558.8344013671867+0j), np.complex128(-2702.175336914064+0j), np.complex128(-2645.20839746094+0j), np.complex128(-2772.7160996093726+0j)]
# Warning: extracted path is incomplete (may be due to QAOA approximation). Extracted local path: [0, 3]
# QAOA didn't give a clean Hamiltonian cycle; selected patients: [1, 2, 3]
# Using brute-force best permutation among selected patients: (1, 2, 3) cost: 34.661
# Trip A distance (evaluated): 34.661000, Trip B distance: 25.740000, Total: 60.401000
# >> New best solution recorded.
#
# --- Combination 2/10: Trip A patients = ['DT', 'GR', 'R3_2'] ---
# Local n_local=4, expected binary variables (qubits) = 12
# QAOA instantiated with args: {'optimizer': <__main__.SciPyOptimizerWrapper object at 0x7f06a3453800>, 'reps': 2}
# Running MinimumEigenOptimizer (QAOA) on QUBO...
# [QAOA] Iter   1  Energy (mean) = -374.49725586+0.00000000j  std = {'shots': 1024, 'circuit_metadata': {}, 'simulator_metadata': {'time_taken_parameter_binding': 0.000163354, 'time_taken_execute': 0.028328236, 'omp_enabled': True, 'max_gpu_memory_mb': 0, 'max_memory_mb': 12977, 'parallel_experiments': 1}}
# [QAOA] Iter   2  Energy (mean) = 20.38301074+0.00000000j  std = {'shots': 1024, 'circuit_metadata': {}, 'simulator_metadata': {'time_taken_parameter_binding': 0.000179131, 'time_taken_execute': 0.011193079, 'omp_enabled': True, 'max_gpu_memory_mb': 0, 'max_memory_mb': 12977, 'parallel_experiments': 1}}
# [QAOA] Iter   3  Energy (mean) = -24.58234570+0.00000000j  std = {'shots': 1024, 'circuit_metadata': {}, 'simulator_metadata': {'time_taken_parameter_binding': 0.000193303, 'time_taken_execute': 0.009324613, 'omp_enabled': True, 'max_gpu_memory_mb': 0, 'max_memory_mb': 12977, 'parallel_experiments': 1}}
# /usr/local/lib/python3.12/dist-packages/qiskit_optimization/minimum_eigensolvers/qaoa.py:122: UserWarning: Using Sampler V2 (other than StatevectorSampler) without a pass_manager may result in an error. Consider providing a pass_manager for proper circuit transpilation.
#   super().__init__(
# [QAOA] Iter   4  Energy (mean) = -1.94983594+0.00000000j  std = {'shots': 1024, 'circuit_metadata': {}, 'simulator_metadata': {'time_taken_parameter_binding': 0.000166892, 'time_taken_execute': 0.022514355, 'omp_enabled': True, 'max_gpu_memory_mb': 0, 'max_memory_mb': 12977, 'parallel_experiments': 1}}
# [QAOA] Iter   5  Energy (mean) = 608.73605664+0.00000000j  std = {'shots': 1024, 'circuit_metadata': {}, 'simulator_metadata': {'time_taken_parameter_binding': 0.000176461, 'time_taken_execute': 0.01235419, 'omp_enabled': True, 'max_gpu_memory_mb': 0, 'max_memory_mb': 12977, 'parallel_experiments': 1}}
# [QAOA] Iter   6  Energy (mean) = 805.18444043+0.00000000j  std = {'shots': 1024, 'circuit_metadata': {}, 'simulator_metadata': {'time_taken_parameter_binding': 0.000122354, 'time_taken_execute': 0.006610677, 'omp_enabled': True, 'max_gpu_memory_mb': 0, 'max_memory_mb': 12977, 'parallel_experiments': 1}}
# [QAOA] Iter   7  Energy (mean) = 217.63237793+0.00000000j  std = {'shots': 1024, 'circuit_metadata': {}, 'simulator_metadata': {'time_taken_parameter_binding': 0.000123391, 'time_taken_execute': 0.006647573, 'omp_enabled': True, 'max_gpu_memory_mb': 0, 'max_memory_mb': 12977, 'parallel_experiments': 1}}
# [QAOA] Iter   8  Energy (mean) = 78.34474512+0.00000000j  std = {'shots': 1024, 'circuit_metadata': {}, 'simulator_metadata': {'time_taken_parameter_binding': 0.000114829, 'time_taken_execute': 0.006704291, 'omp_enabled': True, 'max_gpu_memory_mb': 0, 'max_memory_mb': 12977, 'parallel_experiments': 1}}
# [QAOA] Iter   9  Energy (mean) = -55.33013086+0.00000000j  std = {'shots': 1024, 'circuit_metadata': {}, 'simulator_metadata': {'time_taken_parameter_binding': 0.000113155, 'time_taken_execute': 0.006765245, 'omp_enabled': True, 'max_gpu_memory_mb': 0, 'max_memory_mb': 12977, 'parallel_experiments': 1}}
# [QAOA] Iter  10  Energy (mean) = 810.00065039+0.00000000j  std = {'shots': 1024, 'circuit_metadata': {}, 'simulator_metadata': {'time_taken_parameter_binding': 0.000152795, 'time_taken_execute': 0.006693548, 'omp_enabled': True, 'max_gpu_memory_mb': 0, 'max_memory_mb': 12977, 'parallel_experiments': 1}}
# [QAOA] Iter  11  Energy (mean) = 337.93231152+0.00000000j  std = {'shots': 1024, 'circuit_metadata': {}, 'simulator_metadata': {'time_taken_parameter_binding': 0.000195936, 'time_taken_execute': 0.008098752, 'omp_enabled': True, 'max_gpu_memory_mb': 0, 'max_memory_mb': 12977, 'parallel_experiments': 1}}
# [QAOA] Iter  12  Energy (mean) = -33.31416797+0.00000000j  std = {'shots': 1024, 'circuit_metadata': {}, 'simulator_metadata': {'time_taken_parameter_binding': 0.000132241, 'time_taken_execute': 0.006627677, 'omp_enabled': True, 'max_gpu_memory_mb': 0, 'max_memory_mb': 12977, 'parallel_experiments': 1}}
# [QAOA] Iter  13  Energy (mean) = -775.11224316+0.00000000j  std = {'shots': 1024, 'circuit_metadata': {}, 'simulator_metadata': {'time_taken_parameter_binding': 0.000118437, 'time_taken_execute': 0.006525011, 'omp_enabled': True, 'max_gpu_memory_mb': 0, 'max_memory_mb': 12977, 'parallel_experiments': 1}}
# [QAOA] Iter  14  Energy (mean) = -113.77069824+0.00000000j  std = {'shots': 1024, 'circuit_metadata': {}, 'simulator_metadata': {'time_taken_parameter_binding': 0.000121883, 'time_taken_execute': 0.006638276, 'omp_enabled': True, 'max_gpu_memory_mb': 0, 'max_memory_mb': 12977, 'parallel_experiments': 1}}
# [QAOA] Iter  15  Energy (mean) = 516.39850391+0.00000000j  std = {'shots': 1024, 'circuit_metadata': {}, 'simulator_metadata': {'time_taken_parameter_binding': 0.000114175, 'time_taken_execute': 0.006748791, 'omp_enabled': True, 'max_gpu_memory_mb': 0, 'max_memory_mb': 12977, 'parallel_experiments': 1}}
# [QAOA] Iter  16  Energy (mean) = 167.59053418+0.00000000j  std = {'shots': 1024, 'circuit_metadata': {}, 'simulator_metadata': {'time_taken_parameter_binding': 0.000116684, 'time_taken_execute': 0.006796761, 'omp_enabled': True, 'max_gpu_memory_mb': 0, 'max_memory_mb': 12977, 'parallel_experiments': 1}}
# [QAOA] Iter  17  Energy (mean) = -127.92530078+0.00000000j  std = {'shots': 1024, 'circuit_metadata': {}, 'simulator_metadata': {'time_taken_parameter_binding': 0.000113891, 'time_taken_execute': 0.007095088, 'omp_enabled': True, 'max_gpu_memory_mb': 0, 'max_memory_mb': 12977, 'parallel_experiments': 1}}
# [QAOA] Iter  18  Energy (mean) = 113.01577441+0.00000000j  std = {'shots': 1024, 'circuit_metadata': {}, 'simulator_metadata': {'time_taken_parameter_binding': 0.000123429, 'time_taken_execute': 0.006646366, 'omp_enabled': True, 'max_gpu_memory_mb': 0, 'max_memory_mb': 12977, 'parallel_experiments': 1}}
# [QAOA] Iter  19  Energy (mean) = 233.69775098+0.00000000j  std = {'shots': 1024, 'circuit_metadata': {}, 'simulator_metadata': {'time_taken_parameter_binding': 0.00011412, 'time_taken_execute': 0.006618737, 'omp_enabled': True, 'max_gpu_memory_mb': 0, 'max_memory_mb': 12977, 'parallel_experiments': 1}}
# [QAOA] Iter  20  Energy (mean) = 372.82424707+0.00000000j  std = {'shots': 1024, 'circuit_metadata': {}, 'simulator_metadata': {'time_taken_parameter_binding': 0.000113978, 'time_taken_execute': 0.006700347, 'omp_enabled': True, 'max_gpu_memory_mb': 0, 'max_memory_mb': 12977, 'parallel_experiments': 1}}
# [QAOA] Iter  21  Energy (mean) = 251.26313184+0.00000000j  std = {'shots': 1024, 'circuit_metadata': {}, 'simulator_metadata': {'time_taken_parameter_binding': 0.000140587, 'time_taken_execute': 0.00670812, 'omp_enabled': True, 'max_gpu_memory_mb': 0, 'max_memory_mb': 12977, 'parallel_experiments': 1}}
# [QAOA] Iter  22  Energy (mean) = -182.21629199+0.00000000j  std = {'shots': 1024, 'circuit_metadata': {}, 'simulator_metadata': {'time_taken_parameter_binding': 0.000196188, 'time_taken_execute': 0.007896769, 'omp_enabled': True, 'max_gpu_memory_mb': 0, 'max_memory_mb': 12977, 'parallel_experiments': 1}}
# [QAOA] Iter  23  Energy (mean) = -121.45075391+0.00000000j  std = {'shots': 1024, 'circuit_metadata': {}, 'simulator_metadata': {'time_taken_parameter_binding': 0.000123542, 'time_taken_execute': 0.006603614, 'omp_enabled': True, 'max_gpu_memory_mb': 0, 'max_memory_mb': 12977, 'parallel_experiments': 1}}
# [QAOA] Iter  24  Energy (mean) = 901.30446191+0.00000000j  std = {'shots': 1024, 'circuit_metadata': {}, 'simulator_metadata': {'time_taken_parameter_binding': 0.000113911, 'time_taken_execute': 0.006737891, 'omp_enabled': True, 'max_gpu_memory_mb': 0, 'max_memory_mb': 12977, 'parallel_experiments': 1}}
# [QAOA] Iter  25  Energy (mean) = 3753.11956641+0.00000000j  std = {'shots': 1024, 'circuit_metadata': {}, 'simulator_metadata': {'time_taken_parameter_binding': 0.000131174, 'time_taken_execute': 0.006931015, 'omp_enabled': True, 'max_gpu_memory_mb': 0, 'max_memory_mb': 12977, 'parallel_experiments': 1}}
# [QAOA] Iter  26  Energy (mean) = 58.84702832+0.00000000j  std = {'shots': 1024, 'circuit_metadata': {}, 'simulator_metadata': {'time_taken_parameter_binding': 0.000119633, 'time_taken_execute': 0.00664558, 'omp_enabled': True, 'max_gpu_memory_mb': 0, 'max_memory_mb': 12977, 'parallel_experiments': 1}}
# [QAOA] Iter  27  Energy (mean) = 42.90144141+0.00000000j  std = {'shots': 1024, 'circuit_metadata': {}, 'simulator_metadata': {'time_taken_parameter_binding': 0.000113354, 'time_taken_execute': 0.006486157, 'omp_enabled': True, 'max_gpu_memory_mb': 0, 'max_memory_mb': 12977, 'parallel_experiments': 1}}
# [QAOA] Iter  28  Energy (mean) = 1077.28345996+0.00000000j  std = {'shots': 1024, 'circuit_metadata': {}, 'simulator_metadata': {'time_taken_parameter_binding': 0.000121271, 'time_taken_execute': 0.006755502, 'omp_enabled': True, 'max_gpu_memory_mb': 0, 'max_memory_mb': 12977, 'parallel_experiments': 1}}
# [QAOA] Iter  29  Energy (mean) = -1772.72548340+0.00000000j  std = {'shots': 1024, 'circuit_metadata': {}, 'simulator_metadata': {'time_taken_parameter_binding': 0.000164417, 'time_taken_execute': 0.007072498, 'omp_enabled': True, 'max_gpu_memory_mb': 0, 'max_memory_mb': 12977, 'parallel_experiments': 1}}
# [QAOA] Iter  30  Energy (mean) = 3638.80810742+0.00000000j  std = {'shots': 1024, 'circuit_metadata': {}, 'simulator_metadata': {'time_taken_parameter_binding': 0.000113918, 'time_taken_execute': 0.007172792, 'omp_enabled': True, 'max_gpu_memory_mb': 0, 'max_memory_mb': 12977, 'parallel_experiments': 1}}
# [QAOA] Iter  31  Energy (mean) = -838.78221680+0.00000000j  std = {'shots': 1024, 'circuit_metadata': {}, 'simulator_metadata': {'time_taken_parameter_binding': 0.000129594, 'time_taken_execute': 0.006679318, 'omp_enabled': True, 'max_gpu_memory_mb': 0, 'max_memory_mb': 12977, 'parallel_experiments': 1}}
# [QAOA] Iter  32  Energy (mean) = -329.78840234+0.00000000j  std = {'shots': 1024, 'circuit_metadata': {}, 'simulator_metadata': {'time_taken_parameter_binding': 0.00012576, 'time_taken_execute': 0.006709119, 'omp_enabled': True, 'max_gpu_memory_mb': 0, 'max_memory_mb': 12977, 'parallel_experiments': 1}}
# [QAOA] Iter  33  Energy (mean) = 342.68504492+0.00000000j  std = {'shots': 1024, 'circuit_metadata': {}, 'simulator_metadata': {'time_taken_parameter_binding': 0.000116903, 'time_taken_execute': 0.006515528, 'omp_enabled': True, 'max_gpu_memory_mb': 0, 'max_memory_mb': 12977, 'parallel_experiments': 1}}
# [QAOA] Iter  34  Energy (mean) = -1770.57776465+0.00000000j  std = {'shots': 1024, 'circuit_metadata': {}, 'simulator_metadata': {'time_taken_parameter_binding': 0.00018999, 'time_taken_execute': 0.009806107, 'omp_enabled': True, 'max_gpu_memory_mb': 0, 'max_memory_mb': 12977, 'parallel_experiments': 1}}
# [QAOA] Iter  35  Energy (mean) = -2259.40123926+0.00000000j  std = {'shots': 1024, 'circuit_metadata': {}, 'simulator_metadata': {'time_taken_parameter_binding': 0.000122369, 'time_taken_execute': 0.006593625, 'omp_enabled': True, 'max_gpu_memory_mb': 0, 'max_memory_mb': 12977, 'parallel_experiments': 1}}
# [QAOA] Iter  36  Energy (mean) = -1471.92539355+0.00000000j  std = {'shots': 1024, 'circuit_metadata': {}, 'simulator_metadata': {'time_taken_parameter_binding': 0.000115362, 'time_taken_execute': 0.006971572, 'omp_enabled': True, 'max_gpu_memory_mb': 0, 'max_memory_mb': 12977, 'parallel_experiments': 1}}
# [QAOA] Iter  37  Energy (mean) = -1905.51408594+0.00000000j  std = {'shots': 1024, 'circuit_metadata': {}, 'simulator_metadata': {'time_taken_parameter_binding': 0.00013181, 'time_taken_execute': 0.006611556, 'omp_enabled': True, 'max_gpu_memory_mb': 0, 'max_memory_mb': 12977, 'parallel_experiments': 1}}
# [QAOA] Iter  38  Energy (mean) = -2236.55268164+0.00000000j  std = {'shots': 1024, 'circuit_metadata': {}, 'simulator_metadata': {'time_taken_parameter_binding': 0.0001188, 'time_taken_execute': 0.006602475, 'omp_enabled': True, 'max_gpu_memory_mb': 0, 'max_memory_mb': 12977, 'parallel_experiments': 1}}
# [QAOA] Iter  39  Energy (mean) = -2263.72546680+0.00000000j  std = {'shots': 1024, 'circuit_metadata': {}, 'simulator_metadata': {'time_taken_parameter_binding': 0.000114473, 'time_taken_execute': 0.006540214, 'omp_enabled': True, 'max_gpu_memory_mb': 0, 'max_memory_mb': 12977, 'parallel_experiments': 1}}
# [QAOA] Iter  40  Energy (mean) = -2364.07959766+0.00000000j  std = {'shots': 1024, 'circuit_metadata': {}, 'simulator_metadata': {'time_taken_parameter_binding': 0.000117386, 'time_taken_execute': 0.00665262, 'omp_enabled': True, 'max_gpu_memory_mb': 0, 'max_memory_mb': 12977, 'parallel_experiments': 1}}
# [QAOA] Iter  41  Energy (mean) = -2120.90017187+0.00000000j  std = {'shots': 1024, 'circuit_metadata': {}, 'simulator_metadata': {'time_taken_parameter_binding': 0.000124754, 'time_taken_execute': 0.006605851, 'omp_enabled': True, 'max_gpu_memory_mb': 0, 'max_memory_mb': 12977, 'parallel_experiments': 1}}
# [QAOA] Iter  42  Energy (mean) = -2277.57534863+0.00000000j  std = {'shots': 1024, 'circuit_metadata': {}, 'simulator_metadata': {'time_taken_parameter_binding': 0.000115104, 'time_taken_execute': 0.006642567, 'omp_enabled': True, 'max_gpu_memory_mb': 0, 'max_memory_mb': 12977, 'parallel_experiments': 1}}
# QAOA solve finished in 2.356 s. result.fval = 42.84400000000096
#
# --- QAOA / solver diagnostics ---
# Eigenvalue (solver_result.eigenvalue): -2364.0795976562486
# solver_result.optimal_parameters: {ParameterVectorElement(β[0]): np.float64(-2.4279749633374204), ParameterVectorElement(β[1]): np.float64(3.816378197679154), ParameterVectorElement(γ[0]): np.float64(-5.48227471437393), ParameterVectorElement(γ[1]): np.float64(4.868979996103304)}
# solver_result.optimal_point: [-2.42797496  3.8163782  -5.48227471  4.86898   ]
# solver_result.eigenstate: {1769: 0.0029296875, 200: 0.0068359375, 362: 0.0009765625, 1065: 0.0009765625, 576: 0.001953125, 2144: 0.001953125, 109: 0.0029296875, 1440: 0.0029296875, 1225: 0.001953125, 1312: 0.001953125, 2451: 0.0009765625, 2291: 0.0009765625, 2318: 0.0009765625, 3273: 0.0029296875, 865: 0.001953125, 776: 0.0009765625, 2127: 0.001953125, 3139: 0.001953125, 2064: 0.0009765625, 168: 0.0009765625, 609: 0.001953125, 2625: 0.001953125, 64: 0.0029296875, 2404: 0.0009765625, 1860: 0.0009765625, 17: 0.0009765625, 3133: 0.0009765625, 1447: 0.0009765625, 334: 0.001953125, 2350: 0.0009765625, 3304: 0.00390625, 107: 0.0009765625, 1387: 0.001953125, 672: 0.0029296875, 1024: 0.0009765625, 680: 0.001953125, 1123: 0.0009765625, 3533: 0.0009765625, 1748: 0.0009765625, 1472: 0.001953125, 3240: 0.0009765625, 1929: 0.001953125, 936: 0.00390625, 1516: 0.0009765625, 4064: 0.0009765625, 2304: 0.001953125, 941: 0.0009765625, 744: 0.0029296875, 3488: 0.0029296875, 2447: 0.001953125, 904: 0.0009765625, 1089: 0.001953125, 2448: 0.001953125, 105: 0.0087890625, 3784: 0.0029296875, 1217: 0.001953125, 81: 0.001953125, 1131: 0.00390625, 3214: 0.001953125, 3081: 0.001953125, 3845: 0.0009765625, 425: 0.0009765625, 1386: 0.0009765625, 1196: 0.0009765625, 192: 0.0048828125, 104: 0.00390625, 2240: 0.0048828125, 2401: 0.0029296875, 656: 0.001953125, 2464: 0.0048828125, 2248: 0.0029296875, 102: 0.0009765625, 928: 0.0029296875, 3464: 0.00390625, 2376: 0.0009765625, 3009: 0.0009765625, 3980: 0.0009765625, 584: 0.00390625, 3425: 0.001953125, 1761: 0.001953125, 993: 0.0009765625, 3472: 0.0009765625, 681: 0.001953125, 3184: 0.0009765625, 1038: 0.001953125, 3420: 0.0009765625, 3753: 0.001953125, 1480: 0.0029296875, 1152: 0.001953125, 153: 0.0009765625, 432: 0.0009765625, 2380: 0.0029296875, 3489: 0.001953125, 2059: 0.0009765625, 1300: 0.0009765625, 1129: 0.001953125, 1248: 0.005859375, 3144: 0.0068359375, 2120: 0.00390625, 169: 0.0009765625, 2624: 0.0009765625, 1256: 0.0087890625, 1230: 0.0029296875, 2121: 0.0068359375, 1376: 0.0029296875, 3628: 0.0009765625, 3305: 0.00390625, 1224: 0.005859375, 2976: 0.001953125, 224: 0.00390625, 3808: 0.0029296875, 1231: 0.0009765625, 1128: 0.00390625, 3151: 0.001953125, 1380: 0.0009765625, 2315: 0.0029296875, 3689: 0.0009765625, 2272: 0.0078125, 3073: 0.0009765625, 257: 0.0009765625, 1185: 0.0009765625, 3481: 0.0009765625, 1555: 0.0009765625, 1889: 0.0009765625, 2145: 0.00390625, 2246: 0.0009765625, 392: 0.00390625, 3177: 0.0078125, 3270: 0.0009765625, 3400: 0.0009765625, 152: 0.0009765625, 3185: 0.001953125, 265: 0.00390625, 3538: 0.0009765625, 3265: 0.001953125, 3164: 0.0009765625, 3209: 0.0029296875, 1934: 0.0009765625, 2280: 0.0068359375, 3470: 0.001953125, 3147: 0.0009765625, 3188: 0.0009765625, 747: 0.0009765625, 2382: 0.001953125, 45: 0.0009765625, 3819: 0.0009765625, 3145: 0.0029296875, 3104: 0.001953125, 209: 0.0009765625, 208: 0.0029296875, 3297: 0.001953125, 1158: 0.0009765625, 3201: 0.0009765625, 2184: 0.0048828125, 1643: 0.0009765625, 1356: 0.0009765625, 2921: 0.0009765625, 1027: 0.0009765625, 1091: 0.0009765625, 1169: 0.0009765625, 1121: 0.0009765625, 232: 0.0087890625, 400: 0.001953125, 67: 0.0009765625, 460: 0.001953125, 328: 0.0029296875, 335: 0.0009765625, 422: 0.0009765625, 2278: 0.0009765625, 3719: 0.0009765625, 1032: 0.0009765625, 3339: 0.0029296875, 1283: 0.0009765625, 1192: 0.0009765625, 2152: 0.0029296875, 1094: 0.0009765625, 1607: 0.0009765625, 143: 0.0009765625, 3337: 0.00390625, 3584: 0.0009765625, 0: 0.0009765625, 3465: 0.001953125, 1257: 0.0048828125, 2180: 0.0009765625, 1777: 0.001953125, 1249: 0.0068359375, 1264: 0.0009765625, 144: 0.0009765625, 1107: 0.0009765625, 1168: 0.001953125, 924: 0.0009765625, 2496: 0.0009765625, 1313: 0.0009765625, 416: 0.0048828125, 2528: 0.0009765625, 412: 0.0009765625, 3248: 0.0009765625, 3279: 0.0009765625, 3438: 0.0009765625, 1372: 0.0009765625, 2336: 0.0029296875, 1198: 0.0009765625, 2409: 0.0009765625, 462: 0.0009765625, 1161: 0.001953125, 2368: 0.00195312 ...
# solver_result.aux_operators_evaluated: None
#
# QAOA loss_history (last 10): [np.complex128(342.6850449218749+0j), np.complex128(-1770.5777646484385+0j), np.complex128(-2259.401239257813+0j), np.complex128(-1471.9253935546865+0j), np.complex128(-1905.5140859374994+0j), np.complex128(-2236.5526816406223+0j), np.complex128(-2263.7254667968723+0j), np.complex128(-2364.0795976562486+0j), np.complex128(-2120.9001718749973+0j), np.complex128(-2277.575348632815+0j)]
# Trip A distance (evaluated): 42.844000, Trip B distance: 28.854000, Total: 71.698000
#
# --- Combination 3/10: Trip A patients = ['DT', 'GR', 'IT'] ---
# Local n_local=4, expected binary variables (qubits) = 12
# QAOA instantiated with args: {'optimizer': <__main__.SciPyOptimizerWrapper object at 0x7f06a3453800>, 'reps': 2}
# Running MinimumEigenOptimizer (QAOA) on QUBO...
# [QAOA] Iter   1  Energy (mean) = 149.98132324+0.00000000j  std = {'shots': 1024, 'circuit_metadata': {}, 'simulator_metadata': {'time_taken_parameter_binding': 0.000114843, 'time_taken_execute': 0.006689381, 'omp_enabled': True, 'max_gpu_memory_mb': 0, 'max_memory_mb': 12977, 'parallel_experiments': 1}}
# [QAOA] Iter   2  Energy (mean) = -21.64779004+0.00000000j  std = {'shots': 1024, 'circuit_metadata': {}, 'simulator_metadata': {'time_taken_parameter_binding': 0.000118768, 'time_taken_execute': 0.006735589, 'omp_enabled': True, 'max_gpu_memory_mb': 0, 'max_memory_mb': 12977, 'parallel_experiments': 1}}
# [QAOA] Iter   3  Energy (mean) = 88.52509180+0.00000000j  std = {'shots': 1024, 'circuit_metadata': {}, 'simulator_metadata': {'time_taken_parameter_binding': 0.000123259, 'time_taken_execute': 0.006692228, 'omp_enabled': True, 'max_gpu_memory_mb': 0, 'max_memory_mb': 12977, 'parallel_experiments': 1}}
# [QAOA] Iter   4  Energy (mean) = 2713.93917480+0.00000000j  std = {'shots': 1024, 'circuit_metadata': {}, 'simulator_metadata': {'time_taken_parameter_binding': 0.000121446, 'time_taken_execute': 0.006872769, 'omp_enabled': True, 'max_gpu_memory_mb': 0, 'max_memory_mb': 12977, 'parallel_experiments': 1}}
# [QAOA] Iter   5  Energy (mean) = -39.51272754+0.00000000j  std = {'shots': 1024, 'circuit_metadata': {}, 'simulator_metadata': {'time_taken_parameter_binding': 0.000129598, 'time_taken_execute': 0.006676418, 'omp_enabled': True, 'max_gpu_memory_mb': 0, 'max_memory_mb': 12977, 'parallel_experiments': 1}}
# /usr/local/lib/python3.12/dist-packages/qiskit_optimization/minimum_eigensolvers/qaoa.py:122: UserWarning: Using Sampler V2 (other than StatevectorSampler) without a pass_manager may result in an error. Consider providing a pass_manager for proper circuit transpilation.
#   super().__init__(
# [QAOA] Iter   6  Energy (mean) = 644.97751855+0.00000000j  std = {'shots': 1024, 'circuit_metadata': {}, 'simulator_metadata': {'time_taken_parameter_binding': 0.000121503, 'time_taken_execute': 0.00687758, 'omp_enabled': True, 'max_gpu_memory_mb': 0, 'max_memory_mb': 12977, 'parallel_experiments': 1}}
# [QAOA] Iter   7  Energy (mean) = -431.73944043+0.00000000j  std = {'shots': 1024, 'circuit_metadata': {}, 'simulator_metadata': {'time_taken_parameter_binding': 0.000131125, 'time_taken_execute': 0.006747078, 'omp_enabled': True, 'max_gpu_memory_mb': 0, 'max_memory_mb': 12977, 'parallel_experiments': 1}}
# [QAOA] Iter   8  Energy (mean) = -66.87089746+0.00000000j  std = {'shots': 1024, 'circuit_metadata': {}, 'simulator_metadata': {'time_taken_parameter_binding': 0.000119457, 'time_taken_execute': 0.006621238, 'omp_enabled': True, 'max_gpu_memory_mb': 0, 'max_memory_mb': 12977, 'parallel_experiments': 1}}
# [QAOA] Iter   9  Energy (mean) = -117.41446680+0.00000000j  std = {'shots': 1024, 'circuit_metadata': {}, 'simulator_metadata': {'time_taken_parameter_binding': 0.000134695, 'time_taken_execute': 0.00667609, 'omp_enabled': True, 'max_gpu_memory_mb': 0, 'max_memory_mb': 12977, 'parallel_experiments': 1}}
# [QAOA] Iter  10  Energy (mean) = 422.39721387+0.00000000j  std = {'shots': 1024, 'circuit_metadata': {}, 'simulator_metadata': {'time_taken_parameter_binding': 0.000132655, 'time_taken_execute': 0.007831975, 'omp_enabled': True, 'max_gpu_memory_mb': 0, 'max_memory_mb': 12977, 'parallel_experiments': 1}}
# [QAOA] Iter  11  Energy (mean) = 608.39425879+0.00000000j  std = {'shots': 1024, 'circuit_metadata': {}, 'simulator_metadata': {'time_taken_parameter_binding': 0.000122072, 'time_taken_execute': 0.006631656, 'omp_enabled': True, 'max_gpu_memory_mb': 0, 'max_memory_mb': 12977, 'parallel_experiments': 1}}
# [QAOA] Iter  12  Energy (mean) = 843.16374609+0.00000000j  std = {'shots': 1024, 'circuit_metadata': {}, 'simulator_metadata': {'time_taken_parameter_binding': 0.000113711, 'time_taken_execute': 0.006683952, 'omp_enabled': True, 'max_gpu_memory_mb': 0, 'max_memory_mb': 12977, 'parallel_experiments': 1}}
# [QAOA] Iter  13  Energy (mean) = -35.47250195+0.00000000j  std = {'shots': 1024, 'circuit_metadata': {}, 'simulator_metadata': {'time_taken_parameter_binding': 0.000115242, 'time_taken_execute': 0.006675303, 'omp_enabled': True, 'max_gpu_memory_mb': 0, 'max_memory_mb': 12977, 'parallel_experiments': 1}}
# [QAOA] Iter  14  Energy (mean) = -1857.52599609+0.00000000j  std = {'shots': 1024, 'circuit_metadata': {}, 'simulator_metadata': {'time_taken_parameter_binding': 0.000116354, 'time_taken_execute': 0.006508517, 'omp_enabled': True, 'max_gpu_memory_mb': 0, 'max_memory_mb': 12977, 'parallel_experiments': 1}}
# [QAOA] Iter  15  Energy (mean) = -263.58932520+0.00000000j  std = {'shots': 1024, 'circuit_metadata': {}, 'simulator_metadata': {'time_taken_parameter_binding': 0.000114769, 'time_taken_execute': 0.006556115, 'omp_enabled': True, 'max_gpu_memory_mb': 0, 'max_memory_mb': 12977, 'parallel_experiments': 1}}
# [QAOA] Iter  16  Energy (mean) = -1761.38683398+0.00000000j  std = {'shots': 1024, 'circuit_metadata': {}, 'simulator_metadata': {'time_taken_parameter_binding': 0.000118874, 'time_taken_execute': 0.006769919, 'omp_enabled': True, 'max_gpu_memory_mb': 0, 'max_memory_mb': 12977, 'parallel_experiments': 1}}
# [QAOA] Iter  17  Energy (mean) = -1234.33006055+0.00000000j  std = {'shots': 1024, 'circuit_metadata': {}, 'simulator_metadata': {'time_taken_parameter_binding': 0.000114116, 'time_taken_execute': 0.006857293, 'omp_enabled': True, 'max_gpu_memory_mb': 0, 'max_memory_mb': 12977, 'parallel_experiments': 1}}
# [QAOA] Iter  18  Energy (mean) = -442.10492187+0.00000000j  std = {'shots': 1024, 'circuit_metadata': {}, 'simulator_metadata': {'time_taken_parameter_binding': 0.000118392, 'time_taken_execute': 0.006577463, 'omp_enabled': True, 'max_gpu_memory_mb': 0, 'max_memory_mb': 12977, 'parallel_experiments': 1}}
# [QAOA] Iter  19  Energy (mean) = -2487.28999902+0.00000000j  std = {'shots': 1024, 'circuit_metadata': {}, 'simulator_metadata': {'time_taken_parameter_binding': 0.000146761, 'time_taken_execute': 0.006591539, 'omp_enabled': True, 'max_gpu_memory_mb': 0, 'max_memory_mb': 12977, 'parallel_experiments': 1}}
# [QAOA] Iter  20  Energy (mean) = -3155.18627539+0.00000000j  std = {'shots': 1024, 'circuit_metadata': {}, 'simulator_metadata': {'time_taken_parameter_binding': 0.000114425, 'time_taken_execute': 0.006643125, 'omp_enabled': True, 'max_gpu_memory_mb': 0, 'max_memory_mb': 12977, 'parallel_experiments': 1}}
# [QAOA] Iter  21  Energy (mean) = -1313.66817578+0.00000000j  std = {'shots': 1024, 'circuit_metadata': {}, 'simulator_metadata': {'time_taken_parameter_binding': 0.000151945, 'time_taken_execute': 0.006841065, 'omp_enabled': True, 'max_gpu_memory_mb': 0, 'max_memory_mb': 12977, 'parallel_experiments': 1}}
# [QAOA] Iter  22  Energy (mean) = -3593.76891016+0.00000000j  std = {'shots': 1024, 'circuit_metadata': {}, 'simulator_metadata': {'time_taken_parameter_binding': 0.00011477, 'time_taken_execute': 0.006542629, 'omp_enabled': True, 'max_gpu_memory_mb': 0, 'max_memory_mb': 12977, 'parallel_experiments': 1}}
# [QAOA] Iter  23  Energy (mean) = -2189.43741895+0.00000000j  std = {'shots': 1024, 'circuit_metadata': {}, 'simulator_metadata': {'time_taken_parameter_binding': 0.000115948, 'time_taken_execute': 0.006875162, 'omp_enabled': True, 'max_gpu_memory_mb': 0, 'max_memory_mb': 12977, 'parallel_experiments': 1}}
# [QAOA] Iter  24  Energy (mean) = 952.52490430+0.00000000j  std = {'shots': 1024, 'circuit_metadata': {}, 'simulator_metadata': {'time_taken_parameter_binding': 0.000133207, 'time_taken_execute': 0.006727092, 'omp_enabled': True, 'max_gpu_memory_mb': 0, 'max_memory_mb': 12977, 'parallel_experiments': 1}}
# [QAOA] Iter  25  Energy (mean) = -3739.83151074+0.00000000j  std = {'shots': 1024, 'circuit_metadata': {}, 'simulator_metadata': {'time_taken_parameter_binding': 0.000135706, 'time_taken_execute': 0.006619101, 'omp_enabled': True, 'max_gpu_memory_mb': 0, 'max_memory_mb': 12977, 'parallel_experiments': 1}}
# [QAOA] Iter  26  Energy (mean) = 4.29740820+0.00000000j  std = {'shots': 1024, 'circuit_metadata': {}, 'simulator_metadata': {'time_taken_parameter_binding': 0.000116413, 'time_taken_execute': 0.006692402, 'omp_enabled': True, 'max_gpu_memory_mb': 0, 'max_memory_mb': 12977, 'parallel_experiments': 1}}
# [QAOA] Iter  27  Energy (mean) = 163.32354688+0.00000000j  std = {'shots': 1024, 'circuit_metadata': {}, 'simulator_metadata': {'time_taken_parameter_binding': 0.000116421, 'time_taken_execute': 0.006707525, 'omp_enabled': True, 'max_gpu_memory_mb': 0, 'max_memory_mb': 12977, 'parallel_experiments': 1}}
# [QAOA] Iter  28  Energy (mean) = -466.40691309+0.00000000j  std = {'shots': 1024, 'circuit_metadata': {}, 'simulator_metadata': {'time_taken_parameter_binding': 0.000113964, 'time_taken_execute': 0.006638683, 'omp_enabled': True, 'max_gpu_memory_mb': 0, 'max_memory_mb': 12977, 'parallel_experiments': 1}}
# [QAOA] Iter  29  Energy (mean) = 1000.83723730+0.00000000j  std = {'shots': 1024, 'circuit_metadata': {}, 'simulator_metadata': {'time_taken_parameter_binding': 0.000115695, 'time_taken_execute': 0.006851304, 'omp_enabled': True, 'max_gpu_memory_mb': 0, 'max_memory_mb': 12977, 'parallel_experiments': 1}}
# [QAOA] Iter  30  Energy (mean) = -3519.61533594+0.00000000j  std = {'shots': 1024, 'circuit_metadata': {}, 'simulator_metadata': {'time_taken_parameter_binding': 0.00017901, 'time_taken_execute': 0.023352561, 'omp_enabled': True, 'max_gpu_memory_mb': 0, 'max_memory_mb': 12977, 'parallel_experiments': 1}}
# [QAOA] Iter  31  Energy (mean) = 202.42802051+0.00000000j  std = {'shots': 1024, 'circuit_metadata': {}, 'simulator_metadata': {'time_taken_parameter_binding': 0.000120708, 'time_taken_execute': 0.006643252, 'omp_enabled': True, 'max_gpu_memory_mb': 0, 'max_memory_mb': 12977, 'parallel_experiments': 1}}
# ...
# /usr/local/lib/python3.12/dist-packages/qiskit_optimization/minimum_eigensolvers/qaoa.py:122: UserWarning: Using Sampler V2 (other than StatevectorSampler) without a pass_manager may result in an error. Consider providing a pass_manager for proper circuit transpilation.
#   super().__init__(
# [QAOA] Iter   6  Energy (mean) = 2987.80144141+0.00000000j  std = {'shots': 1024, 'circuit_metadata': {}, 'simulator_metadata': {'time_taken_parameter_binding': 0.000114586, 'time_taken_execute': 0.007015623, 'omp_enabled': True, 'max_gpu_memory_mb': 0, 'max_memory_mb': 12977, 'parallel_experiments': 1}}
# [QAOA] Iter   7  Energy (mean) = -697.91557129+0.00000000j  std = {'shots': 1024, 'circuit_metadata': {}, 'simulator_metadata': {'time_taken_parameter_binding': 0.000125099, 'time_taken_execute': 0.00642071, 'omp_enabled': True, 'max_gpu_memory_mb': 0, 'max_memory_mb': 12977, 'parallel_experiments': 1}}
# [QAOA] Iter   8  Energy (mean) = -12.08595410+0.00000000j  std = {'shots': 1024, 'circuit_metadata': {}, 'simulator_metadata': {'time_taken_parameter_binding': 0.000121177, 'time_taken_execute': 0.006646245, 'omp_enabled': True, 'max_gpu_memory_mb': 0, 'max_memory_mb': 12977, 'parallel_experiments': 1}}
# [QAOA] Iter   9  Energy (mean) = 227.65085059+0.00000000j  std = {'shots': 1024, 'circuit_metadata': {}, 'simulator_metadata': {'time_taken_parameter_binding': 0.000116539, 'time_taken_execute': 0.006637492, 'omp_enabled': True, 'max_gpu_memory_mb': 0, 'max_memory_mb': 12977, 'parallel_experiments': 1}}
# [QAOA] Iter  10  Energy (mean) = -415.19518945+0.00000000j  std = {'shots': 1024, 'circuit_metadata': {}, 'simulator_metadata': {'time_taken_parameter_binding': 0.000127554, 'time_taken_execute': 0.006808696, 'omp_enabled': True, 'max_gpu_memory_mb': 0, 'max_memory_mb': 12977, 'parallel_experiments': 1}}
# [QAOA] Iter  11  Energy (mean) = -43.51066113+0.00000000j  std = {'shots': 1024, 'circuit_metadata': {}, 'simulator_metadata': {'time_taken_parameter_binding': 0.000114295, 'time_taken_execute': 0.006604107, 'omp_enabled': True, 'max_gpu_memory_mb': 0, 'max_memory_mb': 12977, 'parallel_experiments': 1}}
# [QAOA] Iter  12  Energy (mean) = 244.37745410+0.00000000j  std = {'shots': 1024, 'circuit_metadata': {}, 'simulator_metadata': {'time_taken_parameter_binding': 0.000112046, 'time_taken_execute': 0.006474575, 'omp_enabled': True, 'max_gpu_memory_mb': 0, 'max_memory_mb': 12977, 'parallel_experiments': 1}}
# [QAOA] Iter  13  Energy (mean) = -805.51853711+0.00000000j  std = {'shots': 1024, 'circuit_metadata': {}, 'simulator_metadata': {'time_taken_parameter_binding': 0.000141457, 'time_taken_execute': 0.006897607, 'omp_enabled': True, 'max_gpu_memory_mb': 0, 'max_memory_mb': 12977, 'parallel_experiments': 1}}
# [QAOA] Iter  14  Energy (mean) = 345.89760254+0.00000000j  std = {'shots': 1024, 'circuit_metadata': {}, 'simulator_metadata': {'time_taken_parameter_binding': 0.000129906, 'time_taken_execute': 0.007689004, 'omp_enabled': True, 'max_gpu_memory_mb': 0, 'max_memory_mb': 12977, 'parallel_experiments': 1}}
# [QAOA] Iter  15  Energy (mean) = -397.45335449+0.00000000j  std = {'shots': 1024, 'circuit_metadata': {}, 'simulator_metadata': {'time_taken_parameter_binding': 0.000118687, 'time_taken_execute': 0.006587088, 'omp_enabled': True, 'max_gpu_memory_mb': 0, 'max_memory_mb': 12977, 'parallel_experiments': 1}}
# [QAOA] Iter  16  Energy (mean) = -95.70290723+0.00000000j  std = {'shots': 1024, 'circuit_metadata': {}, 'simulator_metadata': {'time_taken_parameter_binding': 0.000119647, 'time_taken_execute': 0.006688868, 'omp_enabled': True, 'max_gpu_memory_mb': 0, 'max_memory_mb': 12977, 'parallel_experiments': 1}}
# [QAOA] Iter  17  Energy (mean) = 825.24131836+0.00000000j  std = {'shots': 1024, 'circuit_metadata': {}, 'simulator_metadata': {'time_taken_parameter_binding': 0.000115627, 'time_taken_execute': 0.006680503, 'omp_enabled': True, 'max_gpu_memory_mb': 0, 'max_memory_mb': 12977, 'parallel_experiments': 1}}
# [QAOA] Iter  18  Energy (mean) = 3.66084668+0.00000000j  std = {'shots': 1024, 'circuit_metadata': {}, 'simulator_metadata': {'time_taken_parameter_binding': 0.000113551, 'time_taken_execute': 0.006718755, 'omp_enabled': True, 'max_gpu_memory_mb': 0, 'max_memory_mb': 12977, 'parallel_experiments': 1}}
# [QAOA] Iter  19  Energy (mean) = -242.76436621+0.00000000j  std = {'shots': 1024, 'circuit_metadata': {}, 'simulator_metadata': {'time_taken_parameter_binding': 0.00011503, 'time_taken_execute': 0.006793753, 'omp_enabled': True, 'max_gpu_memory_mb': 0, 'max_memory_mb': 12977, 'parallel_experiments': 1}}
# [QAOA] Iter  20  Energy (mean) = -76.68574902+0.00000000j  std = {'shots': 1024, 'circuit_metadata': {}, 'simulator_metadata': {'time_taken_parameter_binding': 0.000142991, 'time_taken_execute': 0.006794329, 'omp_enabled': True, 'max_gpu_memory_mb': 0, 'max_memory_mb': 12977, 'parallel_experiments': 1}}
# [QAOA] Iter  21  Energy (mean) = -1535.53099609+0.00000000j  std = {'shots': 1024, 'circuit_metadata': {}, 'simulator_metadata': {'time_taken_parameter_binding': 0.000116072, 'time_taken_execute': 0.0065755, 'omp_enabled': True, 'max_gpu_memory_mb': 0, 'max_memory_mb': 12977, 'parallel_experiments': 1}}
# [QAOA] Iter  22  Energy (mean) = 1069.66662012+0.00000000j  std = {'shots': 1024, 'circuit_metadata': {}, 'simulator_metadata': {'time_taken_parameter_binding': 0.000112481, 'time_taken_execute': 0.006684417, 'omp_enabled': True, 'max_gpu_memory_mb': 0, 'max_memory_mb': 12977, 'parallel_experiments': 1}}
# [QAOA] Iter  23  Energy (mean) = -125.22756250+0.00000000j  std = {'shots': 1024, 'circuit_metadata': {}, 'simulator_metadata': {'time_taken_parameter_binding': 0.000145985, 'time_taken_execute': 0.006663494, 'omp_enabled': True, 'max_gpu_memory_mb': 0, 'max_memory_mb': 12977, 'parallel_experiments': 1}}
# [QAOA] Iter  24  Energy (mean) = -399.36443652+0.00000000j  std = {'shots': 1024, 'circuit_metadata': {}, 'simulator_metadata': {'time_taken_parameter_binding': 0.000115633, 'time_taken_execute': 0.006674642, 'omp_enabled': True, 'max_gpu_memory_mb': 0, 'max_memory_mb': 12977, 'parallel_experiments': 1}}
# [QAOA] Iter  25  Energy (mean) = -129.65652734+0.00000000j  std = {'shots': 1024, 'circuit_metadata': {}, 'simulator_metadata': {'time_taken_parameter_binding': 0.000116942, 'time_taken_execute': 0.006666795, 'omp_enabled': True, 'max_gpu_memory_mb': 0, 'max_memory_mb': 12977, 'parallel_experiments': 1}}
# [QAOA] Iter  26  Energy (mean) = -1084.67588477+0.00000000j  std = {'shots': 1024, 'circuit_metadata': {}, 'simulator_metadata': {'time_taken_parameter_binding': 0.000116176, 'time_taken_execute': 0.006638501, 'omp_enabled': True, 'max_gpu_memory_mb': 0, 'max_memory_mb': 12977, 'parallel_experiments': 1}}
# [QAOA] Iter  27  Energy (mean) = -66.34012988+0.00000000j  std = {'shots': 1024, 'circuit_metadata': {}, 'simulator_metadata': {'time_taken_parameter_binding': 0.000116199, 'time_taken_execute': 0.006760367, 'omp_enabled': True, 'max_gpu_memory_mb': 0, 'max_memory_mb': 12977, 'parallel_experiments': 1}}
# [QAOA] Iter  28  Energy (mean) = -1479.75462598+0.00000000j  std = {'shots': 1024, 'circuit_metadata': {}, 'simulator_metadata': {'time_taken_parameter_binding': 0.000115732, 'time_taken_execute': 0.007550367, 'omp_enabled': True, 'max_gpu_memory_mb': 0, 'max_memory_mb': 12977, 'parallel_experiments': 1}}
# [QAOA] Iter  29  Energy (mean) = -0.33572070+0.00000000j  std = {'shots': 1024, 'circuit_metadata': {}, 'simulator_metadata': {'time_taken_parameter_binding': 0.000128764, 'time_taken_execute': 0.00672715, 'omp_enabled': True, 'max_gpu_memory_mb': 0, 'max_memory_mb': 12977, 'parallel_experiments': 1}}
# [QAOA] Iter  30  Energy (mean) = 35.11153223+0.00000000j  std = {'shots': 1024, 'circuit_metadata': {}, 'simulator_metadata': {'time_taken_parameter_binding': 0.000131338, 'time_taken_execute': 0.00687137, 'omp_enabled': True, 'max_gpu_memory_mb': 0, 'max_memory_mb': 12977, 'parallel_experiments': 1}}
# [QAOA] Iter  31  Energy (mean) = -343.43360254+0.00000000j  std = {'shots': 1024, 'circuit_metadata': {}, 'simulator_metadata': {'time_taken_parameter_binding': 0.000121817, 'time_taken_execute': 0.006711956, 'omp_enabled': True, 'max_gpu_memory_mb': 0, 'max_memory_mb': 12977, 'parallel_experiments': 1}}
# [QAOA] Iter  32  Energy (mean) = 1229.86529492+0.00000000j  std = {'shots': 1024, 'circuit_metadata': {}, 'simulator_metadata': {'time_taken_parameter_binding': 0.000113595, 'time_taken_execute': 0.006806458, 'omp_enabled': True, 'max_gpu_memory_mb': 0, 'max_memory_mb': 12977, 'parallel_experiments': 1}}
# [QAOA] Iter  33  Energy (mean) = -1420.60448730+0.00000000j  std = {'shots': 1024, 'circuit_metadata': {}, 'simulator_metadata': {'time_taken_parameter_binding': 0.000127153, 'time_taken_execute': 0.006551604, 'omp_enabled': True, 'max_gpu_memory_mb': 0, 'max_memory_mb': 12977, 'parallel_experiments': 1}}
# [QAOA] Iter  34  Energy (mean) = -738.14541797+0.00000000j  std = {'shots': 1024, 'circuit_metadata': {}, 'simulator_metadata': {'time_taken_parameter_binding': 0.000117732, 'time_taken_execute': 0.006661059, 'omp_enabled': True, 'max_gpu_memory_mb': 0, 'max_memory_mb': 12977, 'parallel_experiments': 1}}
# [QAOA] Iter  35  Energy (mean) = -1704.43710938+0.00000000j  std = {'shots': 1024, 'circuit_metadata': {}, 'simulator_metadata': {'time_taken_parameter_binding': 0.000119708, 'time_taken_execute': 0.006525091, 'omp_enabled': True, 'max_gpu_memory_mb': 0, 'max_memory_mb': 12977, 'parallel_experiments': 1}}
# [QAOA] Iter  36  Energy (mean) = -1667.27655273+0.00000000j  std = {'shots': 1024, 'circuit_metadata': {}, 'simulator_metadata': {'time_taken_parameter_binding': 0.000112302, 'time_taken_execute': 0.00658019, 'omp_enabled': True, 'max_gpu_memory_mb': 0, 'max_memory_mb': 12977, 'parallel_experiments': 1}}
# [QAOA] Iter  37  Energy (mean) = -1609.52086621+0.00000000j  std = {'shots': 1024, 'circuit_metadata': {}, 'simulator_metadata': {'time_taken_parameter_binding': 0.000116382, 'time_taken_execute': 0.006632781, 'omp_enabled': True, 'max_gpu_memory_mb': 0, 'max_memory_mb': 12977, 'parallel_experiments': 1}}
# [QAOA] Iter  38  Energy (mean) = -1602.70459082+0.00000000j  std = {'shots': 1024, 'circuit_metadata': {}, 'simulator_metadata': {'time_taken_parameter_binding': 0.000111859, 'time_taken_execute': 0.006572872, 'omp_enabled': True, 'max_gpu_memory_mb': 0, 'max_memory_mb': 12977, 'parallel_experiments': 1}}
# QAOA solve finished in 2.152 s. result.fval = 34.332000000000335
#
# --- QAOA / solver diagnostics ---
# Eigenvalue (solver_result.eigenvalue): -1704.4371093750003
# solver_result.optimal_parameters: {ParameterVectorElement(β[0]): np.float64(-4.3563191792633535), ParameterVectorElement(β[1]): np.float64(-1.2771364369234337), ParameterVectorElement(γ[0]): np.float64(0.7859994191162816), ParameterVectorElement(γ[1]): np.float64(-2.994559865243612)}
# solver_result.optimal_point: [-4.35631918 -1.27713644  0.78599942 -2.99455987]
# solver_result.eigenstate: {166: 0.0009765625, 3278: 0.0009765625, 2836: 0.0009765625, 1703: 0.0009765625, 2645: 0.005859375, 45: 0.001953125, 2353: 0.001953125, 612: 0.0009765625, 1276: 0.0009765625, 3329: 0.0009765625, 982: 0.0009765625, 21: 0.001953125, 2069: 0.0029296875, 3886: 0.001953125, 595: 0.0009765625, 1878: 0.001953125, 1603: 0.0029296875, 383: 0.0009765625, 3853: 0.0009765625, 2374: 0.0009765625, 3893: 0.0009765625, 3139: 0.001953125, 1717: 0.0009765625, 3685: 0.0048828125, 525: 0.001953125, 542: 0.0009765625, 2060: 0.0029296875, 517: 0.0029296875, 637: 0.0009765625, 1874: 0.0009765625, 893: 0.0029296875, 357: 0.0029296875, 1557: 0.005859375, 1621: 0.0078125, 301: 0.0009765625, 2885: 0.0029296875, 3447: 0.0009765625, 892: 0.0009765625, 2307: 0.00390625, 668: 0.0009765625, 1776: 0.0009765625, 851: 0.001953125, 533: 0.0048828125, 2720: 0.0009765625, 573: 0.0029296875, 3681: 0.0009765625, 2661: 0.00390625, 3429: 0.00390625, 477: 0.0009765625, 3072: 0.0009765625, 2981: 0.0009765625, 2425: 0.0009765625, 285: 0.0029296875, 1819: 0.0009765625, 827: 0.001953125, 2886: 0.0029296875, 51: 0.001953125, 3908: 0.0009765625, 115: 0.0009765625, 279: 0.0009765625, 1803: 0.001953125, 2407: 0.001953125, 361: 0.001953125, 3331: 0.0009765625, 3620: 0.001953125, 3349: 0.005859375, 3085: 0.0048828125, 1629: 0.0009765625, 3799: 0.0009765625, 835: 0.001953125, 544: 0.0009765625, 89: 0.0009765625, 333: 0.0009765625, 3173: 0.001953125, 1858: 0.0009765625, 2053: 0.0009765625, 557: 0.0009765625, 2673: 0.0029296875, 611: 0.001953125, 309: 0.0078125, 3141: 0.00390625, 2070: 0.0009765625, 369: 0.001953125, 36: 0.0009765625, 156: 0.00390625, 2582: 0.001953125, 3633: 0.0029296875, 56: 0.0009765625, 1716: 0.0029296875, 1620: 0.0009765625, 2421: 0.001953125, 2018: 0.0009765625, 3157: 0.0029296875, 799: 0.0009765625, 3125: 0.005859375, 2171: 0.0009765625, 1863: 0.0029296875, 1879: 0.0009765625, 1731: 0.0029296875, 2206: 0.0009765625, 3628: 0.0009765625, 3301: 0.0009765625, 1607: 0.0048828125, 597: 0.00390625, 3151: 0.001953125, 3527: 0.0009765625, 1734: 0.0009765625, 566: 0.001953125, 28: 0.0009765625, 355: 0.0009765625, 2023: 0.0009765625, 1315: 0.0009765625, 749: 0.0009765625, 381: 0.0009765625, 535: 0.001953125, 1319: 0.0009765625, 2093: 0.0029296875, 2692: 0.0009765625, 589: 0.0009765625, 1875: 0.0029296875, 78: 0.0009765625, 3169: 0.0029296875, 2228: 0.001953125, 261: 0.001953125, 178: 0.0009765625, 3430: 0.0009765625, 1551: 0.0009765625, 1987: 0.0009765625, 3115: 0.001953125, 2101: 0.0029296875, 785: 0.0009765625, 1729: 0.0009765625, 1045: 0.0009765625, 3782: 0.0009765625, 2589: 0.00390625, 3221: 0.0009765625, 302: 0.0009765625, 676: 0.0009765625, 2372: 0.0009765625, 527: 0.0009765625, 1589: 0.001953125, 3396: 0.001953125, 294: 0.0009765625, 565: 0.0068359375, 1796: 0.0009765625, 2189: 0.0009765625, 2188: 0.001953125, 424: 0.0009765625, 596: 0.0029296875, 284: 0.001953125, 3284: 0.001953125, 3363: 0.0009765625, 3622: 0.001953125, 4021: 0.0009765625, 2357: 0.0048828125, 854: 0.0029296875, 317: 0.001953125, 2068: 0.0009765625, 174: 0.0029296875, 3660: 0.0009765625, 1862: 0.005859375, 3103: 0.001953125, 371: 0.0009765625, 107: 0.0009765625, 1876: 0.001953125, 2881: 0.001953125, 1487: 0.0009765625, 2637: 0.0009765625, 2340: 0.0009765625, 1588: 0.001953125, 1352: 0.0009765625, 1058: 0.0009765625, 2607: 0.0009765625, 879: 0.0009765625, 3653: 0.0029296875, 1178: 0.0009765625, 3861: 0.001953125, 67: 0.001953125, 173: 0.0009765625, 22: 0.0009765625, 1587: 0.0009765625, 516: 0.0009765625, 1582: 0.0009765625, 15: 0.001953125, 323: 0.0009765625, 591: 0.0009765625, 44: 0.001953125, 3526: 0.0009765625, 2220: 0.001953125, 3179: 0.0009765625, 2658: 0.0009765625, 1809: 0.0009765625, 849: 0.0009765625, 680: 0.0009765625, 561: 0.001953125, 1299: 0.0009765625, 2887: 0.0029296875, 3877: 0.0029296875, 3117: 0.0029296875, 3194: 0.0009765625, 853: 0.001953125, 2597: 0.00390625, 2662: 0.0009765625, 837: 0.00390625, 140: 0.001953125, 1655: 0.0009765625, 3909: 0.000976562 ...
# solver_result.aux_operators_evaluated: None
#
# QAOA loss_history (last 10): [np.complex128(-0.33572070312501046+0j), np.complex128(35.111532226562424+0j), np.complex128(-343.4336025390621+0j), np.complex128(1229.8652949218751+0j), np.complex128(-1420.604487304687+0j), np.complex128(-738.1454179687499+0j), np.complex128(-1704.4371093750003+0j), np.complex128(-1667.2765527343734+0j), np.complex128(-1609.5208662109367+0j), np.complex128(-1602.704590820313+0j)]
# Trip A distance (evaluated): 34.332000, Trip B distance: 28.774000, Total: 63.106000
#
# ==================================================
# FINAL BEST SOLUTION (quantum Trip A):
# Total optimal distance (hybrid): 60.401000
# Trip A (3 patients): ['DT', 'GR', 'R2'] Route: H -> DT -> GR -> R2 -> H Distance: 34.661000
# Trip B (2 patients): ['R3_2', 'IT'] Route: H -> IT -> R3_2 -> H Distance: 25.740000
# QAOA sampler: SamplerV2 QAOA time (s): 2.7919228076934814
# ==================================================

# %% [markdown]
# ## Noisy Simulation

# %%
# Robust cell: FakeProvider noise -> AerSimulator -> primitives Sampler -> QAOA + MinimumEigenOptimizer


import time, itertools, math, traceback
import numpy as np

# Qiskit optimization pieces
from qiskit_optimization import QuadraticProgram
from qiskit_optimization.converters import QuadraticProgramToQubo
from qiskit_optimization.algorithms import MinimumEigenOptimizer
from qiskit_optimization.minimum_eigensolvers import QAOA

# Fake provider + Aer noise
from qiskit.providers.fake_provider import GenericBackendV2
from qiskit_aer import AerSimulator
from qiskit_aer.noise import NoiseModel

# Try to find a primitives-style Sampler implementation (many Qiskit versions expose one)
PrimitiveSamplerClass = None
sampler_creation_exceptions = []

# Try qiskit.primitives.Sampler first (common)
try:
    from qiskit.primitives import Sampler as _SamplerPrimitive
    PrimitiveSamplerClass = _SamplerPrimitive
    print("Found qiskit.primitives.Sampler")
except Exception as e:
    sampler_creation_exceptions.append(("qiskit.primitives.Sampler import", e))

# Try qiskit_aer.primitives.SamplerV2 next
if PrimitiveSamplerClass is None:
    try:
        from qiskit_aer.primitives import SamplerV2 as _SamplerPrimitiveV2
        PrimitiveSamplerClass = _SamplerPrimitiveV2
        print("Found qiskit_aer.primitives.SamplerV2")
    except Exception as e:
        sampler_creation_exceptions.append(("qiskit_aer.primitives.SamplerV2 import", e))

# As a last attempt, try qiskit_aer.primitives.Sampler (older naming)
if PrimitiveSamplerClass is None:
    try:
        from qiskit_aer.primitives import Sampler as _SamplerPrimitiveAlt
        PrimitiveSamplerClass = _SamplerPrimitiveAlt
        print("Found qiskit_aer.primitives.Sampler (alt)")
    except Exception as e:
        sampler_creation_exceptions.append(("qiskit_aer.primitives.Sampler import", e))



# Optimizer selection / SciPy fallback (keeps minimize() signature used by Qiskit)
optimizer = None
try:
    from qiskit.algorithms.optimizers import SPSA
    optimizer = SPSA(maxiter=50)
    print("Using SPSA optimizer.")
except Exception:
    try:
        from qiskit.algorithms.optimizers import COBYLA
        optimizer = COBYLA(maxiter=200)
        print("Using COBYLA optimizer.")
    except Exception:
        # SciPy-based wrapper (implements minimize compatible with Qiskit)
        from scipy.optimize import minimize as scipy_minimize
        class SciPyOptimizerWrapper:
            def __init__(self, method='COBYLA', options=None):
                self.method = method
                self.options = options or {"maxiter":200}
            def optimize(self, num_vars, objective, initial_point=None):
                def obj_for_scipy(x):
                    val = objective(x)
                    return float(val) if not isinstance(val, (tuple,list)) else float(val[0])
                x0 = initial_point if initial_point is not None else [0.0]*num_vars
                res = scipy_minimize(obj_for_scipy, x0, method=self.method, options=self.options)
                return res.x, float(res.fun), getattr(res, "nfev", None)
            def minimize(self, fun, x0, **kwargs):
                method = kwargs.pop("method", self.method)
                options = kwargs.pop("options", self.options)
                res = scipy_minimize(fun, x0, method=method, options=options, **kwargs)
                return res
        optimizer = SciPyOptimizerWrapper(method='COBYLA', options={"maxiter":100})
        print("Using SciPy-based optimizer wrapper.")

# ------------------------------
# Problem data 
# ------------------------------
distance_matrix = np.array(
      [[ 0.   ,  8.628, 11.496,  9.445, 10.852,  9.672],
       [14.194,  0.   ,  2.361, 10.922,  9.238,  9.43 ],
       [17.785,  7.745,  0.   , 11.808, 10.124, 10.478],
       [11.864, 19.672, 15.661,  0.   , 11.572, 11.538],
       [ 7.343, 12.172, 10.053,  4.071,  0.   ,  5.931],
       [ 9.269,  9.398, 12.266,  7.318,  8.725,  0.   ]]
)
locations = ['H', 'DT', 'GR', 'R2', 'R3_2', 'IT']
patient_indices = [1,2,3,4,5]
penalty = 1000

# Build fake backend & noise model
max_n_local = 4
expected_qubits = max_n_local * (max_n_local - 1)
print("Creating GenericBackendV2 with", expected_qubits, "qubits (for noise model).")
fake_backend = GenericBackendV2(num_qubits=expected_qubits)
try:
    # try using QasmSimulator.from_backend if available 
    from qiskit_aer import QasmSimulator
    try:
        device_for_noise = QasmSimulator.from_backend(fake_backend)
        noise_model = NoiseModel.from_backend(device_for_noise)
    except Exception:
        noise_model = NoiseModel.from_backend(fake_backend)
except Exception:
    noise_model = NoiseModel.from_backend(fake_backend)

print("Noise model created from fake backend.")

# Build noisy AerSimulator defensively (avoid passing unsupported kwargs)
sim_seed = 1234
simulator = None
try:
    simulator = AerSimulator(noise_model=noise_model, method='density_matrix', seed_simulator=sim_seed)
    print("AerSimulator created with method='density_matrix' and seed_simulator.")
except Exception as e1:
    print("Preferred AerSimulator constructor failed:", type(e1).__name__, e1)
    try:
        simulator = AerSimulator(noise_model=noise_model, method='density_matrix')
        print("AerSimulator created with method='density_matrix' (no seed).")
    except Exception:
        try:
            simulator = AerSimulator(noise_model=noise_model)
            print("AerSimulator created with noise_model (default method).")
        except Exception as e_last:
            print("Failed to create AerSimulator with noise_model. Exception:")
            traceback.print_exc()
            raise RuntimeError("Cannot create AerSimulator in this environment.") from e_last

# Now create a primitives-style sampler backed by the simulator
sampler = None
sampler_errors = []

if PrimitiveSamplerClass is not None:
    # try several common constructor signatures
    constructors = [
        lambda cls=PrimitiveSamplerClass: cls(backend=simulator),
        lambda cls=PrimitiveSamplerClass: cls(backend=simulator, shots=1024),
        lambda cls=PrimitiveSamplerClass: cls(backend=simulator, mode=simulator),
        lambda cls=PrimitiveSamplerClass: cls(mode=simulator),
        lambda cls=PrimitiveSamplerClass: cls(),
    ]
    for ctor in constructors:
        try:
            sampler = ctor()
            print("Primitive sampler created with constructor:", ctor)
            break
        except Exception as e:
            sampler_errors.append((ctor, e))
else:
    sampler_errors.append(("PrimitiveSamplerClass not found", sampler_creation_exceptions))

# If still failed -> helpful error message
if sampler is None:
    print("Failed to create a primitives-style Sampler. Attempts and exceptions:")
    for c, e in sampler_errors:
        print("-", c, "raised:", repr(e))
    raise RuntimeError(
        "Unable to instantiate a primitives Sampler compatible with this Qiskit version. "
        "Please ensure you have a primitives Sampler implementation available (e.g. install qiskit-aer and try importing qiskit.primitives.Sampler or qiskit_aer.primitives.SamplerV2)."
    )

print("Using sampler object of type:", type(sampler).__name__)

# ---- QuadraticProgram helper and reconstruction ----
def build_tsp_quadratic_program(dist_local, penalty=penalty):
    n = dist_local.shape[0]
    qp = QuadraticProgram(name="TSP_local")
    for i in range(n):
        for j in range(n):
            if i == j: continue
            qp.binary_var(name=f"x_{i}_{j}")
    linear = {f"x_{i}_{j}": float(dist_local[i,j]) for i in range(n) for j in range(n) if i!=j}
    qp.minimize(linear=linear)
    for i in range(n):
        arrive = {f"x_{j}_{i}": 1 for j in range(n) if j!=i}
        qp.linear_constraint(linear=arrive, sense="==", rhs=1, name=f"arrive_{i}")
        depart = {f"x_{i}_{j}": 1 for j in range(n) if j!=i}
        qp.linear_constraint(linear=depart, sense="==", rhs=1, name=f"depart_{i}")
    qubo = QuadraticProgramToQubo(penalty=penalty).convert(qp)
    return qp, qubo

def reconstruct_tour_from_solution(variables_dict):
    path_dict = {}
    for varname, val in variables_dict.items():
        try:
            if float(val) > 0.5:
                parts = varname.split('_')
                if len(parts) >= 3:
                    si = int(parts[1]); sj = int(parts[2])
                    path_dict[si] = sj
        except Exception:
            continue
    path = [0]
    cur = 0
    while True:
        nxt = path_dict.get(cur, None)
        if nxt is None: break
        if nxt in path: break
        path.append(nxt); cur = nxt
        if len(path) > 50: break
    if len(path) >= 1 and path[-1] != 0 and len(path) == len(path_dict)+1:
        path.append(0)
    return path

# QAOA callback & loss history
loss_history = []
def qaoa_callback(eval_count, parameters, mean, std):
    loss_history.append(mean)
    print(f"[QAOA] Iter {eval_count:3d}  Energy = {mean:.8f}  std = {std if std is not None else 'N/A'}")

# Top-level hybrid search (Trip A quantum on 3 patients; Trip B classical on remaining 2)
best = {"distance": float('inf')}

print("Starting hybrid search using noisy sampler (FakeProvider -> AerSimulator -> primitives Sampler).")

for idx, group_A in enumerate(itertools.combinations(patient_indices, 3), start=1):
    print(f"\n--- Combination {idx}/10: Trip A patients = {[locations[i] for i in group_A]} ---")
    group_B = tuple(p for p in patient_indices if p not in group_A)

    trip_A_nodes = (0,) + group_A
    dist_A_local = distance_matrix[np.ix_(trip_A_nodes, trip_A_nodes)]
    n_local = dist_A_local.shape[0]
    print(f"Local problem size n_local={n_local} nodes -> expected binary vars = {n_local*(n_local-1)}")

    qp_local, qubo_local = build_tsp_quadratic_program(dist_A_local, penalty=penalty)

    # Instantiate QAOA robustly (use sampler + optimizer)
    qaoa = None
    qaoa_errors = []
    attempts = [
        {"sampler": sampler, "optimizer": optimizer, "reps": 2, "callback": qaoa_callback},
        {"optimizer": optimizer, "sampler": sampler, "reps": 2, "callback": qaoa_callback},
        {"sampler": sampler, "reps": 2, "optimizer": optimizer, "callback": qaoa_callback},
        {"sampler": sampler, "reps": 2, "optimizer": optimizer},
    ]
    for kwargs in attempts:
        try:
            qaoa = QAOA(**kwargs)
            print("QAOA instantiated with args:", {k:v for k,v in kwargs.items() if k not in ('sampler','callback')})
            break
        except Exception as e:
            qaoa_errors.append((kwargs, e))

    if qaoa is None:
        print("QAOA instantiation failed. Details:")
        for kw, err in qaoa_errors:
            print("Attempt:", {k: (v if k!='sampler' else "<sampler>") for k,v in kw.items()})
            print(" ->", type(err).__name__, err)
        raise RuntimeError("QAOA could not be instantiated.")

    # Wrap in MinimumEigenOptimizer (handle older/newer constructors)
    try:
        meo = MinimumEigenOptimizer(min_eigen_solver=qaoa)
    except TypeError:
        meo = MinimumEigenOptimizer(qaoa)

    print("Running MinimumEigenOptimizer (QAOA) on noisy QUBO ...")
    t0 = time.time()
    try:
        result = meo.solve(qubo_local)
    except Exception:
        traceback.print_exc()
        raise
    t1 = time.time()
    print(f"QAOA solve finished in {t1-t0:.3f} s. result.fval = {getattr(result, 'fval', 'N/A')}")

    # Diagnostics
    solver_result = getattr(result, "min_eigen_solver_result", None)
    if solver_result is None:
        print("No min_eigen_solver_result found on result; printing basic attributes:")
        for k in ['fval','status','variables_dict']:
            if hasattr(result, k):
                print(" result.", k, "=", getattr(result, k))
    else:
        for field in ("eigenvalue", "optimal_parameters", "optimal_point", "eigenstate", "aux_operators_evaluated"):
            if hasattr(solver_result, field):
                print(f"solver_result.{field}:", getattr(solver_result, field))

    if loss_history:
        print("Recent loss_history (last 10):", loss_history[-10:])
    else:
        print("No loss_history recorded (callback may not have been called).")

    # Reconstruct route and evaluate trip A distance
    path_local = reconstruct_tour_from_solution(result.variables_dict)
    if len(path_local) < n_local:
        print("Warning: extracted path incomplete:", path_local)

    if len(path_local) == n_local and path_local[0] == 0:
        tour = path_local + ([0] if path_local[-1] != 0 else [])
        tripA_dist = sum(float(dist_A_local[a,b]) for a,b in zip(tour[:-1], tour[1:]))
        path_global = [trip_A_nodes[i] for i in path_local]
        if path_global[-1] != 0:
            path_global = path_global + [0]
    else:
        selected = sorted([j for j in range(1,n_local) if any((f"x_{i}_{j}" in result.variables_dict and result.variables_dict[f"x_{i}_{j}"]>0.5) for i in range(n_local) if i!=j)])
        if not selected:
            raise RuntimeError("QAOA returned no selected patient edges; aborting.")
        best_perm = None; best_perm_cost = math.inf
        for perm in itertools.permutations(selected):
            tour = [0] + list(perm) + [0]
            cost = sum(float(dist_A_local[a,b]) for a,b in zip(tour[:-1], tour[1:]))
            if cost < best_perm_cost:
                best_perm_cost = cost; best_perm = perm
        tripA_dist = best_perm_cost
        path_global = [trip_A_nodes[i] for i in ([0] + list(best_perm) + [0])]
        print("Fallback brute-force chosen subset:", [trip_A_nodes[i] for i in selected], "best perm:", best_perm)

    # Trip B classical exact (2 patients)
    p1, p2 = group_B
    dist_B_option1 = distance_matrix[0,p1] + distance_matrix[p1,p2] + distance_matrix[p2,0]
    dist_B_option2 = distance_matrix[0,p2] + distance_matrix[p2,p1] + distance_matrix[p1,0]
    if dist_B_option1 <= dist_B_option2:
        tripB_dist = float(dist_B_option1); pathB_global = [0, p1, p2, 0]
    else:
        tripB_dist = float(dist_B_option2); pathB_global = [0, p2, p1, 0]

    total = float(tripA_dist) + float(tripB_dist)
    print(f"Trip A distance: {tripA_dist:.6f}, Trip B distance: {tripB_dist:.6f}, Total: {total:.6f}")

    if total < best["distance"]:
        best.update({
            "distance": total,
            "trip_A_group": [locations[i] for i in group_A],
            "trip_B_group": [locations[i] for i in group_B],
            "trip_A_route": [locations[i] for i in path_global],
            "trip_B_route": [locations[i] for i in pathB_global],
            "trip_A_dist": tripA_dist,
            "trip_B_dist": tripB_dist,
            "qaoa_time": t1-t0,
            "qaoa_sampler_constructor": type(sampler).__name__
        })
        print(">> New best solution recorded.")

# Final results
print("\n" + "="*50)
print("FINAL BEST SOLUTION (quantum Trip A, noisy simulator):")
print("Total optimal distance (hybrid): {:.6f}".format(best["distance"]))
print("Trip A (3 patients):", best["trip_A_group"], "Route:", " -> ".join(best["trip_A_route"]), f"Distance: {best['trip_A_dist']:.6f}")
print("Trip B (2 patients):", best["trip_B_group"], "Route:", " -> ".join(best["trip_B_route"]), f"Distance: {best['trip_B_dist']:.6f}")
print("QAOA sampler:", best.get("qaoa_sampler_constructor"), "QAOA time (s):", best.get("qaoa_time"))
print("="*50)
# Out:
# Found qiskit_aer.primitives.SamplerV2
# Using SciPy-based optimizer wrapper.
# Creating GenericBackendV2 with 12 qubits (for noise model).
# Noise model created from fake backend.
# AerSimulator created with method='density_matrix' and seed_simulator.
# Primitive sampler created with constructor: <function <lambda> at 0x7f068ee43d80>
# Using sampler object of type: SamplerV2
# Starting hybrid search using noisy sampler (FakeProvider -> AerSimulator -> primitives Sampler).
#
# --- Combination 1/10: Trip A patients = ['DT', 'GR', 'R2'] ---
# Local problem size n_local=4 nodes -> expected binary vars = 12
# QAOA instantiated with args: {'optimizer': <__main__.SciPyOptimizerWrapper object at 0x7f069c4c24e0>, 'reps': 2}
# Running MinimumEigenOptimizer (QAOA) on noisy QUBO ...
# [QAOA] Iter   1  Energy = 373.38925098+0.00000000j  std = {'shots': 1024, 'circuit_metadata': {}, 'simulator_metadata': {'time_taken_parameter_binding': 0.000118242, 'time_taken_execute': 0.006716816, 'omp_enabled': True, 'max_gpu_memory_mb': 0, 'max_memory_mb': 12977, 'parallel_experiments': 1}}
# [QAOA] Iter   2  Energy = -1133.96861719+0.00000000j  std = {'shots': 1024, 'circuit_metadata': {}, 'simulator_metadata': {'time_taken_parameter_binding': 0.000120354, 'time_taken_execute': 0.006653275, 'omp_enabled': True, 'max_gpu_memory_mb': 0, 'max_memory_mb': 12977, 'parallel_experiments': 1}}
# [QAOA] Iter   3  Energy = 2108.12678516+0.00000000j  std = {'shots': 1024, 'circuit_metadata': {}, 'simulator_metadata': {'time_taken_parameter_binding': 0.000123783, 'time_taken_execute': 0.006507327, 'omp_enabled': True, 'max_gpu_memory_mb': 0, 'max_memory_mb': 12977, 'parallel_experiments': 1}}
# [QAOA] Iter   4  Energy = 1291.97485840+0.00000000j  std = {'shots': 1024, 'circuit_metadata': {}, 'simulator_metadata': {'time_taken_parameter_binding': 0.000126871, 'time_taken_execute': 0.0066431, 'omp_enabled': True, 'max_gpu_memory_mb': 0, 'max_memory_mb': 12977, 'parallel_experiments': 1}}
# [QAOA] Iter   5  Energy = -158.62575781+0.00000000j  std = {'shots': 1024, 'circuit_metadata': {}, 'simulator_metadata': {'time_taken_parameter_binding': 0.000118587, 'time_taken_execute': 0.006639121, 'omp_enabled': True, 'max_gpu_memory_mb': 0, 'max_memory_mb': 12977, 'parallel_experiments': 1}}
# /usr/local/lib/python3.12/dist-packages/qiskit_optimization/minimum_eigensolvers/qaoa.py:122: UserWarning: Using Sampler V2 (other than StatevectorSampler) without a pass_manager may result in an error. Consider providing a pass_manager for proper circuit transpilation.
#   super().__init__(
# [QAOA] Iter   6  Energy = -440.25929688+0.00000000j  std = {'shots': 1024, 'circuit_metadata': {}, 'simulator_metadata': {'time_taken_parameter_binding': 0.000117472, 'time_taken_execute': 0.006641965, 'omp_enabled': True, 'max_gpu_memory_mb': 0, 'max_memory_mb': 12977, 'parallel_experiments': 1}}
# [QAOA] Iter   7  Energy = -327.91006543+0.00000000j  std = {'shots': 1024, 'circuit_metadata': {}, 'simulator_metadata': {'time_taken_parameter_binding': 0.000138742, 'time_taken_execute': 0.006737952, 'omp_enabled': True, 'max_gpu_memory_mb': 0, 'max_memory_mb': 12977, 'parallel_experiments': 1}}
# [QAOA] Iter   8  Energy = -388.76979297+0.00000000j  std = {'shots': 1024, 'circuit_metadata': {}, 'simulator_metadata': {'time_taken_parameter_binding': 0.000131477, 'time_taken_execute': 0.006669629, 'omp_enabled': True, 'max_gpu_memory_mb': 0, 'max_memory_mb': 12977, 'parallel_experiments': 1}}
# [QAOA] Iter   9  Energy = 159.67464746+0.00000000j  std = {'shots': 1024, 'circuit_metadata': {}, 'simulator_metadata': {'time_taken_parameter_binding': 0.000116271, 'time_taken_execute': 0.012295283, 'omp_enabled': True, 'max_gpu_memory_mb': 0, 'max_memory_mb': 12977, 'parallel_experiments': 1}}
# [QAOA] Iter  10  Energy = 353.52658496+0.00000000j  std = {'shots': 1024, 'circuit_metadata': {}, 'simulator_metadata': {'time_taken_parameter_binding': 0.000117948, 'time_taken_execute': 0.006733016, 'omp_enabled': True, 'max_gpu_memory_mb': 0, 'max_memory_mb': 12977, 'parallel_experiments': 1}}
# [QAOA] Iter  11  Energy = -130.03588086+0.00000000j  std = {'shots': 1024, 'circuit_metadata': {}, 'simulator_metadata': {'time_taken_parameter_binding': 0.000123029, 'time_taken_execute': 0.008343605, 'omp_enabled': True, 'max_gpu_memory_mb': 0, 'max_memory_mb': 12977, 'parallel_experiments': 1}}
# [QAOA] Iter  12  Energy = -52.98599121+0.00000000j  std = {'shots': 1024, 'circuit_metadata': {}, 'simulator_metadata': {'time_taken_parameter_binding': 0.000132412, 'time_taken_execute': 0.007901851, 'omp_enabled': True, 'max_gpu_memory_mb': 0, 'max_memory_mb': 12977, 'parallel_experiments': 1}}
# [QAOA] Iter  13  Energy = 350.64486621+0.00000000j  std = {'shots': 1024, 'circuit_metadata': {}, 'simulator_metadata': {'time_taken_parameter_binding': 0.000118861, 'time_taken_execute': 0.006780974, 'omp_enabled': True, 'max_gpu_memory_mb': 0, 'max_memory_mb': 12977, 'parallel_experiments': 1}}
# [QAOA] Iter  14  Energy = -1170.88496582+0.00000000j  std = {'shots': 1024, 'circuit_metadata': {}, 'simulator_metadata': {'time_taken_parameter_binding': 0.000119732, 'time_taken_execute': 0.006854588, 'omp_enabled': True, 'max_gpu_memory_mb': 0, 'max_memory_mb': 12977, 'parallel_experiments': 1}}
# [QAOA] Iter  15  Energy = -41.21498437+0.00000000j  std = {'shots': 1024, 'circuit_metadata': {}, 'simulator_metadata': {'time_taken_parameter_binding': 0.000131343, 'time_taken_execute': 0.006811377, 'omp_enabled': True, 'max_gpu_memory_mb': 0, 'max_memory_mb': 12977, 'parallel_experiments': 1}}
# [QAOA] Iter  16  Energy = 1062.39362793+0.00000000j  std = {'shots': 1024, 'circuit_metadata': {}, 'simulator_metadata': {'time_taken_parameter_binding': 0.000119965, 'time_taken_execute': 0.006809927, 'omp_enabled': True, 'max_gpu_memory_mb': 0, 'max_memory_mb': 12977, 'parallel_experiments': 1}}
# [QAOA] Iter  17  Energy = -1350.96590820+0.00000000j  std = {'shots': 1024, 'circuit_metadata': {}, 'simulator_metadata': {'time_taken_parameter_binding': 0.000113318, 'time_taken_execute': 0.0068807, 'omp_enabled': True, 'max_gpu_memory_mb': 0, 'max_memory_mb': 12977, 'parallel_experiments': 1}}
# [QAOA] Iter  18  Energy = 547.79758594+0.00000000j  std = {'shots': 1024, 'circuit_metadata': {}, 'simulator_metadata': {'time_taken_parameter_binding': 0.000127891, 'time_taken_execute': 0.006720422, 'omp_enabled': True, 'max_gpu_memory_mb': 0, 'max_memory_mb': 12977, 'parallel_experiments': 1}}
# [QAOA] Iter  19  Energy = -1094.79662109+0.00000000j  std = {'shots': 1024, 'circuit_metadata': {}, 'simulator_metadata': {'time_taken_parameter_binding': 0.000127708, 'time_taken_execute': 0.006714531, 'omp_enabled': True, 'max_gpu_memory_mb': 0, 'max_memory_mb': 12977, 'parallel_experiments': 1}}
# [QAOA] Iter  20  Energy = 50.92121777+0.00000000j  std = {'shots': 1024, 'circuit_metadata': {}, 'simulator_metadata': {'time_taken_parameter_binding': 0.000117397, 'time_taken_execute': 0.006730953, 'omp_enabled': True, 'max_gpu_memory_mb': 0, 'max_memory_mb': 12977, 'parallel_experiments': 1}}
# [QAOA] Iter  21  Energy = -110.07495508+0.00000000j  std = {'shots': 1024, 'circuit_metadata': {}, 'simulator_metadata': {'time_taken_parameter_binding': 0.000144589, 'time_taken_execute': 0.006718418, 'omp_enabled': True, 'max_gpu_memory_mb': 0, 'max_memory_mb': 12977, 'parallel_experiments': 1}}
# [QAOA] Iter  22  Energy = 1344.39088379+0.00000000j  std = {'shots': 1024, 'circuit_metadata': {}, 'simulator_metadata': {'time_taken_parameter_binding': 0.000151234, 'time_taken_execute': 0.006713851, 'omp_enabled': True, 'max_gpu_memory_mb': 0, 'max_memory_mb': 12977, 'parallel_experiments': 1}}
# [QAOA] Iter  23  Energy = 998.86800000+0.00000000j  std = {'shots': 1024, 'circuit_metadata': {}, 'simulator_metadata': {'time_taken_parameter_binding': 0.000115725, 'time_taken_execute': 0.006633348, 'omp_enabled': True, 'max_gpu_memory_mb': 0, 'max_memory_mb': 12977, 'parallel_experiments': 1}}
# [QAOA] Iter  24  Energy = -210.83785059+0.00000000j  std = {'shots': 1024, 'circuit_metadata': {}, 'simulator_metadata': {'time_taken_parameter_binding': 0.00011823, 'time_taken_execute': 0.006718087, 'omp_enabled': True, 'max_gpu_memory_mb': 0, 'max_memory_mb': 12977, 'parallel_experiments': 1}}
# [QAOA] Iter  25  Energy = 1010.80891113+0.00000000j  std = {'shots': 1024, 'circuit_metadata': {}, 'simulator_metadata': {'time_taken_parameter_binding': 0.000129982, 'time_taken_execute': 0.006747548, 'omp_enabled': True, 'max_gpu_memory_mb': 0, 'max_memory_mb': 12977, 'parallel_experiments': 1}}
# [QAOA] Iter  26  Energy = -361.21294531+0.00000000j  std = {'shots': 1024, 'circuit_metadata': {}, 'simulator_metadata': {'time_taken_parameter_binding': 0.000116269, 'time_taken_execute': 0.00668115, 'omp_enabled': True, 'max_gpu_memory_mb': 0, 'max_memory_mb': 12977, 'parallel_experiments': 1}}
# [QAOA] Iter  27  Energy = -1136.54002637+0.00000000j  std = {'shots': 1024, 'circuit_metadata': {}, 'simulator_metadata': {'time_taken_parameter_binding': 0.00012831, 'time_taken_execute': 0.006692073, 'omp_enabled': True, 'max_gpu_memory_mb': 0, 'max_memory_mb': 12977, 'parallel_experiments': 1}}
# [QAOA] Iter  28  Energy = 432.95086816+0.00000000j  std = {'shots': 1024, 'circuit_metadata': {}, 'simulator_metadata': {'time_taken_parameter_binding': 0.000113625, 'time_taken_execute': 0.00669841, 'omp_enabled': True, 'max_gpu_memory_mb': 0, 'max_memory_mb': 12977, 'parallel_experiments': 1}}
# [QAOA] Iter  29  Energy = 93.25746680+0.00000000j  std = {'shots': 1024, 'circuit_metadata': {}, 'simulator_metadata': {'time_taken_parameter_binding': 0.000120141, 'time_taken_execute': 0.006729356, 'omp_enabled': True, 'max_gpu_memory_mb': 0, 'max_memory_mb': 12977, 'parallel_experiments': 1}}
# [QAOA] Iter  30  Energy = -589.42099609+0.00000000j  std = {'shots': 1024, 'circuit_metadata': {}, 'simulator_metadata': {'time_taken_parameter_binding': 0.00012386, 'time_taken_execute': 0.006764577, 'omp_enabled': True, 'max_gpu_memory_mb': 0, 'max_memory_mb': 12977, 'parallel_experiments': 1}}
# [QAOA] Iter  31  Energy = 277.45019922+0.00000000j  std = {'shots': 1024, 'circuit_metadata': {}, 'simulator_metadata': {'time_taken_parameter_binding': 0.000120868, 'time_taken_execute': 0.006742929, 'omp_enabled': True, 'max_gpu_memory_mb': 0, 'max_memory_mb': 12977, 'parallel_experiments': 1}}
# [QAOA] Iter  32  Energy = 899.52415820+0.00000000j  std = {'shots': 1024, 'circuit_metadata': {}, 'simulator_metadata': {'time_taken_parameter_binding': 0.000133117, 'time_taken_execute': 0.007742428, 'omp_enabled': True, 'max_gpu_memory_mb': 0, 'max_memory_mb': 12977, 'parallel_experiments': 1}}
# [QAOA] Iter  33  Energy = -1762.00924121+0.00000000j  std = {'shots': 1024, 'circuit_metadata': {}, 'simulator_metadata': {'time_taken_parameter_binding': 0.000126683, 'time_taken_execute': 0.00672438, 'omp_enabled': True, 'max_gpu_memory_mb': 0, 'max_memory_mb': 12977, 'parallel_experiments': 1}}
# [QAOA] Iter  34  Energy = 83.31111914+0.00000000j  std = {'shots': 1024, 'circuit_metadata': {}, 'simulator_metadata': {'time_taken_parameter_binding': 0.000115716, 'time_taken_execute': 0.006772778, 'omp_enabled': True, 'max_gpu_memory_mb': 0, 'max_memory_mb': 12977, 'parallel_experiments': 1}}
# [QAOA] Iter  35  Energy = -1185.78612598+0.00000000j  std = {'shots': 1024, 'circuit_metadata': {}, 'simulator_metadata': {'time_taken_parameter_binding': 0.000116919, 'time_taken_execute': 0.006730357, 'omp_enabled': True, 'max_gpu_memory_mb': 0, 'max_memory_mb': 12977, 'parallel_experiments': 1}}
# [QAOA] Iter  36  Energy = -1468.03098828+0.00000000j  std = {'shots': 1024, 'circuit_metadata': {}, 'simulator_metadata': {'time_taken_parameter_binding': 0.00011921, 'time_taken_execute': 0.006852933, 'omp_enabled': True, 'max_gpu_memory_mb': 0, 'max_memory_mb': 12977, 'parallel_experiments': 1}}
# [QAOA] Iter  37  Energy = -1709.95406641+0.00000000j  std = {'shots': 1024, 'circuit_metadata': {}, 'simulator_metadata': {'time_taken_parameter_binding': 0.000127981, 'time_taken_execute': 0.006729698, 'omp_enabled': True, 'max_gpu_memory_mb': 0, 'max_memory_mb': 12977, 'parallel_experiments': 1}}
# [QAOA] Iter  38  Energy = -1519.04235449+0.00000000j  std = {'shots': 1024, 'circuit_metadata': {}, 'simulator_metadata': {'time_taken_parameter_binding': 0.000116495, 'time_taken_execute': 0.006772685, 'omp_enabled': True, 'max_gpu_memory_mb': 0, 'max_memory_mb': 12977, 'parallel_experiments': 1}}
# [QAOA] Iter  39  Energy = -1750.42646191+0.00000000j  std = {'shots': 1024, 'circuit_metadata': {}, 'simulator_metadata': {'time_taken_parameter_binding': 0.00018389, 'time_taken_execute': 0.009380282, 'omp_enabled': True, 'max_gpu_memory_mb': 0, 'max_memory_mb': 12977, 'parallel_experiments': 1}}
# [QAOA] Iter  40  Energy = -1665.43030371+0.00000000j  std = {'shots': 1024, 'circuit_metadata': {}, 'simulator_metadata': {'time_taken_parameter_binding': 0.00012285, 'time_taken_execute': 0.006835542, 'omp_enabled': True, 'max_gpu_memory_mb': 0, 'max_memory_mb': 12977, 'parallel_experiments': 1}}
# [QAOA] Iter  41  Energy = -1415.95720898+0.00000000j  std = {'shots': 1024, 'circuit_metadata': {}, 'simulator_metadata': {'time_taken_parameter_binding': 0.000128412, 'time_taken_execute': 0.006736892, 'omp_enabled': True, 'max_gpu_memory_mb': 0, 'max_memory_mb': 12977, 'parallel_experiments': 1}}
# [QAOA] Iter  42  Energy = -1499.02515625+0.00000000j  std = {'shots': 1024, 'circuit_metadata': {}, 'simulator_metadata': {'time_taken_parameter_binding': 0.000139108, 'time_taken_execute': 0.00669789, 'omp_enabled': True, 'max_gpu_memory_mb': 0, 'max_memory_mb': 12977, 'parallel_experiments': 1}}
# [QAOA] Iter  43  Energy = -1544.25943262+0.00000000j  std = {'shots': 1024, 'circuit_metadata': {}, 'simulator_metadata': {'time_taken_parameter_binding': 0.000119657, 'time_taken_execute': 0.006777665, 'omp_enabled': True, 'max_gpu_memory_mb': 0, 'max_memory_mb': 12977, 'parallel_experiments': 1}}
# QAOA solve finished in 2.463 s. result.fval = 52.995999999999185
# solver_result.eigenvalue: -1762.0092412109427
# solver_result.optimal_parameters: {ParameterVectorElement(β[0]): np.float64(-4.868364457315055), ParameterVectorElement(β[1]): np.float64(-4.9121931288896565), ParameterVectorElement(γ[0]): np.float64(1.1189003947638263), ParameterVectorElement(γ[1]): np.float64(-1.0370595698181337)}
# solver_result.optimal_point: [-4.86836446 -4.91219313  1.11890039 -1.03705957]
# solver_result.eigenstate: {3124: 0.0078125, 3764: 0.0009765625, 2157: 0.0009765625, 3085: 0.0029296875, 2099: 0.0009765625, 4072: 0.0009765625, 3240: 0.0009765625, 3788: 0.001953125, 547: 0.001953125, 2110: 0.0009765625, 3214: 0.001953125, 162: 0.0029296875, 3093: 0.0009765625, 3548: 0.001953125, 3460: 0.001953125, 1031: 0.0009765625, 2753: 0.0009765625, 1189: 0.001953125, 453: 0.0009765625, 418: 0.0009765625, 2213: 0.0029296875, 2192: 0.00390625, 164: 0.001953125, 1677: 0.001953125, 2516: 0.001953125, 188: 0.001953125, 2200: 0.0029296875, 1028: 0.0009765625, 2326: 0.0009765625, 1428: 0.0009765625, 1518: 0.0009765625, 2314: 0.001953125, 820: 0.0009765625, 1232: 0.0029296875, 3208: 0.0029296875, 1798: 0.0009765625, 3121: 0.001953125, 1567: 0.0009765625, 3204: 0.005859375, 1630: 0.0009765625, 3536: 0.0009765625, 3285: 0.0009765625, 488: 0.0009765625, 50: 0.001953125, 2060: 0.001953125, 3209: 0.0009765625, 128: 0.0029296875, 3276: 0.0009765625, 1365: 0.0009765625, 3619: 0.0009765625, 3245: 0.001953125, 3129: 0.001953125, 2180: 0.00390625, 3524: 0.0029296875, 2744: 0.0009765625, 1202: 0.001953125, 3692: 0.0009765625, 3120: 0.0009765625, 1471: 0.001953125, 1557: 0.0009765625, 4077: 0.0009765625, 2277: 0.0009765625, 1413: 0.0009765625, 2432: 0.0009765625, 2764: 0.001953125, 1230: 0.0009765625, 1056: 0.0009765625, 3250: 0.001953125, 2292: 0.0009765625, 2046: 0.0009765625, 2125: 0.0009765625, 2223: 0.0009765625, 3033: 0.0009765625, 3534: 0.0009765625, 30: 0.0009765625, 1165: 0.001953125, 3123: 0.0009765625, 4: 0.001953125, 2512: 0.0009765625, 2229: 0.0009765625, 3749: 0.001953125, 1802: 0.0009765625, 1067: 0.0009765625, 3957: 0.001953125, 2777: 0.0009765625, 2700: 0.0009765625, 3724: 0.0009765625, 2076: 0.005859375, 20: 0.001953125, 2548: 0.0009765625, 6: 0.001953125, 3076: 0.001953125, 3473: 0.001953125, 5: 0.001953125, 2164: 0.0009765625, 2053: 0.0029296875, 1778: 0.0009765625, 150: 0.0009765625, 354: 0.0009765625, 2247: 0.001953125, 2085: 0.0009765625, 1410: 0.0009765625, 2261: 0.001953125, 2632: 0.0009765625, 3672: 0.0009765625, 3156: 0.0009765625, 3200: 0.001953125, 2230: 0.0009765625, 3201: 0.0029296875, 3294: 0.001953125, 2208: 0.001953125, 4068: 0.0009765625, 1756: 0.0009765625, 3709: 0.0009765625, 818: 0.0009765625, 3242: 0.001953125, 2694: 0.0009765625, 3236: 0.0068359375, 1517: 0.0009765625, 157: 0.0009765625, 1591: 0.0009765625, 261: 0.0009765625, 1504: 0.0009765625, 4061: 0.001953125, 2224: 0.0029296875, 51: 0.0009765625, 3092: 0.0048828125, 2324: 0.0009765625, 2773: 0.001953125, 3248: 0.00390625, 3159: 0.0009765625, 3592: 0.0009765625, 2949: 0.001953125, 2226: 0.001953125, 2245: 0.001953125, 3182: 0.0009765625, 2196: 0.00390625, 2160: 0.001953125, 3213: 0.0009765625, 2100: 0.0029296875, 1194: 0.0009765625, 3789: 0.0009765625, 1254: 0.001953125, 3476: 0.00390625, 2227: 0.001953125, 3170: 0.0009765625, 3241: 0.00390625, 213: 0.0009765625, 4053: 0.0009765625, 3629: 0.0009765625, 3736: 0.001953125, 3817: 0.0009765625, 2186: 0.0009765625, 2612: 0.0009765625, 3748: 0.001953125, 3676: 0.001953125, 3246: 0.0009765625, 616: 0.0009765625, 2736: 0.0029296875, 2081: 0.0009765625, 3284: 0.0029296875, 3632: 0.0009765625, 2228: 0.0048828125, 3136: 0.0009765625, 1417: 0.0009765625, 160: 0.0068359375, 1483: 0.0009765625, 1500: 0.0009765625, 2720: 0.001953125, 553: 0.0009765625, 4044: 0.0009765625, 3117: 0.0029296875, 2093: 0.001953125, 822: 0.0009765625, 2766: 0.001953125, 3270: 0.001953125, 2797: 0.0009765625, 3304: 0.0009765625, 733: 0.0009765625, 2708: 0.0029296875, 2352: 0.0009765625, 3501: 0.0009765625, 90: 0.001953125, 3366: 0.0009765625, 3080: 0.0029296875, 3444: 0.0009765625, 1554: 0.0009765625, 3077: 0.0048828125, 166: 0.0009765625, 1997: 0.0009765625, 1048: 0.0029296875, 3316: 0.0029296875, 3624: 0.0009765625, 3288: 0.001953125, 2524: 0.001953125, 2132: 0.0009765625, 3616: 0.0009765625, 2328: 0.0009765625, 1072: 0.0009765625, 2436: 0.0009765625, 913: 0.0009765625, 1573: 0.001953125, 2592: 0.0009765625, 2279: 0.0009765625, 2530: ...
# solver_result.aux_operators_evaluated: None
# Recent loss_history (last 10): [np.complex128(83.31111914062504+0j), np.complex128(-1185.7861259765623+0j), np.complex128(-1468.03098828125+0j), np.complex128(-1709.954066406252+0j), np.complex128(-1519.0423544921853+0j), np.complex128(-1750.4264619140627+0j), np.complex128(-1665.4303037109364+0j), np.complex128(-1415.9572089843732+0j), np.complex128(-1499.0251562500011+0j), np.complex128(-1544.259432617188+0j)]
# Trip A distance: 52.996000, Trip B distance: 25.740000, Total: 78.736000
# >> New best solution recorded.
#
# --- Combination 2/10: Trip A patients = ['DT', 'GR', 'R3_2'] ---
# Local problem size n_local=4 nodes -> expected binary vars = 12
# QAOA instantiated with args: {'optimizer': <__main__.SciPyOptimizerWrapper object at 0x7f069c4c24e0>, 'reps': 2}
# Running MinimumEigenOptimizer (QAOA) on noisy QUBO ...
# [QAOA] Iter   1  Energy = -37.48018262+0.00000000j  std = {'shots': 1024, 'circuit_metadata': {}, 'simulator_metadata': {'time_taken_parameter_binding': 0.00013187, 'time_taken_execute': 0.006691486, 'omp_enabled': True, 'max_gpu_memory_mb': 0, 'max_memory_mb': 12977, 'parallel_experiments': 1}}
# [QAOA] Iter   2  Energy = 17.65281738+0.00000000j  std = {'shots': 1024, 'circuit_metadata': {}, 'simulator_metadata': {'time_taken_parameter_binding': 0.000116341, 'time_taken_execute': 0.00670464, 'omp_enabled': True, 'max_gpu_memory_mb': 0, 'max_memory_mb': 12977, 'parallel_experiments': 1}}
# [QAOA] Iter   3  Energy = 129.72738672+0.00000000j  std = {'shots': 1024, 'circuit_metadata': {}, 'simulator_metadata': {'time_taken_parameter_binding': 0.000114492, 'time_taken_execute': 0.00664791, 'omp_enabled': True, 'max_gpu_memory_mb': 0, 'max_memory_mb': 12977, 'parallel_experiments': 1}}
# [QAOA] Iter   4  Energy = -31.79479297+0.00000000j  std = {'shots': 1024, 'circuit_metadata': {}, 'simulator_metadata': {'time_taken_parameter_binding': 0.000133847, 'time_taken_execute': 0.006490278, 'omp_enabled': True, 'max_gpu_memory_mb': 0, 'max_memory_mb': 12977, 'parallel_experiments': 1}}
# [QAOA] Iter   5  Energy = -145.98587988+0.00000000j  std = {'shots': 1024, 'circuit_metadata': {}, 'simulator_metadata': {'time_taken_parameter_binding': 0.000113248, 'time_taken_execute': 0.006675773, 'omp_enabled': True, 'max_gpu_memory_mb': 0, 'max_memory_mb': 12977, 'parallel_experiments': 1}}
# /usr/local/lib/python3.12/dist-packages/qiskit_optimization/minimum_eigensolvers/qaoa.py:122: UserWarning: Using Sampler V2 (other than StatevectorSampler) without a pass_manager may result in an error. Consider providing a pass_manager for proper circuit transpilation.
#   super().__init__(
# [QAOA] Iter   6  Energy = -299.46635254+0.00000000j  std = {'shots': 1024, 'circuit_metadata': {}, 'simulator_metadata': {'time_taken_parameter_binding': 0.000114359, 'time_taken_execute': 0.00659552, 'omp_enabled': True, 'max_gpu_memory_mb': 0, 'max_memory_mb': 12977, 'parallel_experiments': 1}}
# [QAOA] Iter   7  Energy = -1145.16175879+0.00000000j  std = {'shots': 1024, 'circuit_metadata': {}, 'simulator_metadata': {'time_taken_parameter_binding': 0.00011404, 'time_taken_execute': 0.006738057, 'omp_enabled': True, 'max_gpu_memory_mb': 0, 'max_memory_mb': 12977, 'parallel_experiments': 1}}
# [QAOA] Iter   8  Energy = -15.70459082+0.00000000j  std = {'shots': 1024, 'circuit_metadata': {}, 'simulator_metadata': {'time_taken_parameter_binding': 0.000128009, 'time_taken_execute': 0.006965246, 'omp_enabled': True, 'max_gpu_memory_mb': 0, 'max_memory_mb': 12977, 'parallel_experiments': 1}}
# [QAOA] Iter   9  Energy = 2501.57650781+0.00000000j  std = {'shots': 1024, 'circuit_metadata': {}, 'simulator_metadata': {'time_taken_parameter_binding': 0.000124929, 'time_taken_execute': 0.006459748, 'omp_enabled': True, 'max_gpu_memory_mb': 0, 'max_memory_mb': 12977, 'parallel_experiments': 1}}
# [QAOA] Iter  10  Energy = 161.64036230+0.00000000j  std = {'shots': 1024, 'circuit_metadata': {}, 'simulator_metadata': {'time_taken_parameter_binding': 0.000115347, 'time_taken_execute': 0.006676007, 'omp_enabled': True, 'max_gpu_memory_mb': 0, 'max_memory_mb': 12977, 'parallel_experiments': 1}}
# [QAOA] Iter  11  Energy = -574.70893359+0.00000000j  std = {'shots': 1024, 'circuit_metadata': {}, 'simulator_metadata': {'time_taken_parameter_binding': 0.000118, 'time_taken_execute': 0.007071216, 'omp_enabled': True, 'max_gpu_memory_mb': 0, 'max_memory_mb': 12977, 'parallel_experiments': 1}}
# [QAOA] Iter  12  Energy = 334.55528418+0.00000000j  std = {'shots': 1024, 'circuit_metadata': {}, 'simulator_metadata': {'time_taken_parameter_binding': 0.000124046, 'time_taken_execute': 0.007013993, 'omp_enabled': True, 'max_gpu_memory_mb': 0, 'max_memory_mb': 12977, 'parallel_experiments': 1}}
# [QAOA] Iter  13  Energy = -1236.05629883+0.00000000j  std = {'shots': 1024, 'circuit_metadata': {}, 'simulator_metadata': {'time_taken_parameter_binding': 0.000120825, 'time_taken_execute': 0.006898559, 'omp_enabled': True, 'max_gpu_memory_mb': 0, 'max_memory_mb': 12977, 'parallel_experiments': 1}}
# [QAOA] Iter  14  Energy = -5.42379980+0.00000000j  std = {'shots': 1024, 'circuit_metadata': {}, 'simulator_metadata': {'time_taken_parameter_binding': 0.000121697, 'time_taken_execute': 0.00666465, 'omp_enabled': True, 'max_gpu_memory_mb': 0, 'max_memory_mb': 12977, 'parallel_experiments': 1}}
# [QAOA] Iter  15  Energy = 561.93010449+0.00000000j  std = {'shots': 1024, 'circuit_metadata': {}, 'simulator_metadata': {'time_taken_parameter_binding': 0.000126908, 'time_taken_execute': 0.006379225, 'omp_enabled': True, 'max_gpu_memory_mb': 0, 'max_memory_mb': 12977, 'parallel_experiments': 1}}
# [QAOA] Iter  16  Energy = -154.39712500+0.00000000j  std = {'shots': 1024, 'circuit_metadata': {}, 'simulator_metadata': {'time_taken_parameter_binding': 0.000120567, 'time_taken_execute': 0.006691507, 'omp_enabled': True, 'max_gpu_memory_mb': 0, 'max_memory_mb': 12977, 'parallel_experiments': 1}}
# [QAOA] Iter  17  Energy = 74.17089551+0.00000000j  std = {'shots': 1024, 'circuit_metadata': {}, 'simulator_metadata': {'time_taken_parameter_binding': 0.000149195, 'time_taken_execute': 0.00684545, 'omp_enabled': True, 'max_gpu_memory_mb': 0, 'max_memory_mb': 12977, 'parallel_experiments': 1}}
# [QAOA] Iter  18  Energy = -1444.44500684+0.00000000j  std = {'shots': 1024, 'circuit_metadata': {}, 'simulator_metadata': {'time_taken_parameter_binding': 0.000127326, 'time_taken_execute': 0.006257278, 'omp_enabled': True, 'max_gpu_memory_mb': 0, 'max_memory_mb': 12977, 'parallel_experiments': 1}}
# [QAOA] Iter  19  Energy = -74.15710937+0.00000000j  std = {'shots': 1024, 'circuit_metadata': {}, 'simulator_metadata': {'time_taken_parameter_binding': 0.000116732, 'time_taken_execute': 0.006756769, 'omp_enabled': True, 'max_gpu_memory_mb': 0, 'max_memory_mb': 12977, 'parallel_experiments': 1}}
# [QAOA] Iter  20  Energy = -1163.55863281+0.00000000j  std = {'shots': 1024, 'circuit_metadata': {}, 'simulator_metadata': {'time_taken_parameter_binding': 0.000163551, 'time_taken_execute': 0.006362046, 'omp_enabled': True, 'max_gpu_memory_mb': 0, 'max_memory_mb': 12977, 'parallel_experiments': 1}}
# [QAOA] Iter  21  Energy = -29.75430859+0.00000000j  std = {'shots': 1024, 'circuit_metadata': {}, 'simulator_metadata': {'time_taken_parameter_binding': 0.000116128, 'time_taken_execute': 0.007054152, 'omp_enabled': True, 'max_gpu_memory_mb': 0, 'max_memory_mb': 12977, 'parallel_experiments': 1}}
# [QAOA] Iter  22  Energy = -1581.91096484+0.00000000j  std = {'shots': 1024, 'circuit_metadata': {}, 'simulator_metadata': {'time_taken_parameter_binding': 0.000129448, 'time_taken_execute': 0.006212928, 'omp_enabled': True, 'max_gpu_memory_mb': 0, 'max_memory_mb': 12977, 'parallel_experiments': 1}}
# [QAOA] Iter  23  Energy = -88.71804004+0.00000000j  std = {'shots': 1024, 'circuit_metadata': {}, 'simulator_metadata': {'time_taken_parameter_binding': 0.000119377, 'time_taken_execute': 0.006679564, 'omp_enabled': True, 'max_gpu_memory_mb': 0, 'max_memory_mb': 12977, 'parallel_experiments': 1}}
# [QAOA] Iter  24  Energy = -88.41540527+0.00000000j  std = {'shots': 1024, 'circuit_metadata': {}, 'simulator_metadata': {'time_taken_parameter_binding': 0.000123576, 'time_taken_execute': 0.006675503, 'omp_enabled': True, 'max_gpu_memory_mb': 0, 'max_memory_mb': 12977, 'parallel_experiments': 1}}
# [QAOA] Iter  25  Energy = 820.54162695+0.00000000j  std = {'shots': 1024, 'circuit_metadata': {}, 'simulator_metadata': {'time_taken_parameter_binding': 0.000118745, 'time_taken_execute': 0.006668099, 'omp_enabled': True, 'max_gpu_memory_mb': 0, 'max_memory_mb': 12977, 'parallel_experiments': 1}}
# [QAOA] Iter  26  Energy = 756.09260645+0.00000000j  std = {'shots': 1024, 'circuit_metadata': {}, 'simulator_metadata': {'time_taken_parameter_binding': 0.000116946, 'time_taken_execute': 0.006708669, 'omp_enabled': True, 'max_gpu_memory_mb': 0, 'max_memory_mb': 12977, 'parallel_experiments': 1}}
# [QAOA] Iter  27  Energy = -203.30750977+0.00000000j  std = {'shots': 1024, 'circuit_metadata': {}, 'simulator_metadata': {'time_taken_parameter_binding': 0.000130777, 'time_taken_execute': 0.006755149, 'omp_enabled': True, 'max_gpu_memory_mb': 0, 'max_memory_mb': 12977, 'parallel_experiments': 1}}
# [QAOA] Iter  28  Energy = 658.35633105+0.00000000j  std = {'shots': 1024, 'circuit_metadata': {}, 'simulator_metadata': {'time_taken_parameter_binding': 0.000140914, 'time_taken_execute': 0.006760874, 'omp_enabled': True, 'max_gpu_memory_mb': 0, 'max_memory_mb': 12977, 'parallel_experiments': 1}}
# [QAOA] Iter  29  Energy = 515.14352539+0.00000000j  std = {'shots': 1024, 'circuit_metadata': {}, 'simulator_metadata': {'time_taken_parameter_binding': 0.000120493, 'time_taken_execute': 0.006747565, 'omp_enabled': True, 'max_gpu_memory_mb': 0, 'max_memory_mb': 12977, 'parallel_experiments': 1}}
# [QAOA] Iter  30  Energy = 702.63612402+0.00000000j  std = {'shots': 1024, 'circuit_metadata': {}, 'simulator_metadata': {'time_taken_parameter_binding': 0.000176762, 'time_taken_execute': 0.006888654, 'omp_enabled': True, 'max_gpu_memory_mb': 0, 'max_memory_mb': 12977, 'parallel_experiments': 1}}
# [QAOA] Iter  31  Energy = 561.89775684+0.00000000j  std = {'shots': 1024, 'circuit_metadata': {}, 'simulator_metadata': {'time_taken_parameter_binding': 0.000123889, 'time_taken_execute': 0.006935099, 'omp_enabled': True, 'max_gpu_memory_mb': 0, 'max_memory_mb': 12977, 'parallel_experiments': 1}}
# [QAOA] Iter  32  Energy = -121.46293555+0.00000000j  std = {'shots': 1024, 'circuit_metadata': {}, 'simulator_metadata': {'time_taken_parameter_binding': 0.000124423, 'time_taken_execute': 0.006637917, 'omp_enabled': True, 'max_gpu_memory_mb': 0, 'max_memory_mb': 12977, 'parallel_experiments': 1}}
# [QAOA] Iter  33  Energy = 488.71630176+0.00000000j  std = {'shots': 1024, 'circuit_metadata': {}, 'simulator_metadata': {'time_taken_parameter_binding': 0.000124011, 'time_taken_execute': 0.006675953, 'omp_enabled': True, 'max_gpu_memory_mb': 0, 'max_memory_mb': 12977, 'parallel_experiments': 1}}
# [QAOA] Iter  34  Energy = 668.42905957+0.00000000j  std = {'shots': 1024, 'circuit_metadata': {}, 'simulator_metadata': {'time_taken_parameter_binding': 0.000116689, 'time_taken_execute': 0.006628742, 'omp_enabled': True, 'max_gpu_memory_mb': 0, 'max_memory_mb': 12977, 'parallel_experiments': 1}}
# [QAOA] Iter  35  Energy = 6.74710156+0.00000000j  std = {'shots': 1024, 'circuit_metadata': {}, 'simulator_metadata': {'time_taken_parameter_binding': 0.000120011, 'time_taken_execute': 0.006649339, 'omp_enabled': True, 'max_gpu_memory_mb': 0, 'max_memory_mb': 12977, 'parallel_experiments': 1}}
# [QAOA] Iter  36  Energy = -1589.35775000+0.00000000j  std = {'shots': 1024, 'circuit_metadata': {}, 'simulator_metadata': {'time_taken_parameter_binding': 0.000228654, 'time_taken_execute': 0.015990508, 'omp_enabled': True, 'max_gpu_memory_mb': 0, 'max_memory_mb': 12977, 'parallel_experiments': 1}}
# [QAOA] Iter  37  Energy = 738.18154883+0.00000000j  std = {'shots': 1024, 'circuit_metadata': {}, 'simulator_metadata': {'time_taken_parameter_binding': 0.000179549, 'time_taken_execute': 0.010066208, 'omp_enabled': True, 'max_gpu_memory_mb': 0, 'max_memory_mb': 12977, 'parallel_experiments': 1}}
# [QAOA] Iter  38  Energy = -1775.09940039+0.00000000j  std = {'shots': 1024, 'circuit_metadata': {}, 'simulator_metadata': {'time_taken_parameter_binding': 0.000190744, 'time_taken_execute': 0.009294407, 'omp_enabled': True, 'max_gpu_memory_mb': 0, 'max_memory_mb': 12977, 'parallel_experiments': 1}}
# [QAOA] Iter  39  Energy = -426.30687891+0.00000000j  std = {'shots': 1024, 'circuit_metadata': {}, 'simulator_metadata': {'time_taken_parameter_binding': 0.000160129, 'time_taken_execute': 0.010416403, 'omp_enabled': True, 'max_gpu_memory_mb': 0, 'max_memory_mb': 12977, 'parallel_experiments': 1}}
# [QAOA] Iter  40  Energy = -1630.73681738+0.00000000j  std = {'shots': 1024, 'circuit_metadata': {}, 'simulator_metadata': {'time_taken_parameter_binding': 0.000193548, 'time_taken_execute': 0.030900925, 'omp_enabled': True, 'max_gpu_memory_mb': 0, 'max_memory_mb': 12977, 'parallel_experiments': 1}}
# [QAOA] Iter  41  Energy = -1623.00872461+0.00000000j  std = {'shots': 1024, 'circuit_metadata': {}, 'simulator_metadata': {'time_taken_parameter_binding': 0.000179707, 'time_taken_execute': 0.008572035, 'omp_enabled': True, 'max_gpu_memory_mb': 0, 'max_memory_mb': 12977, 'parallel_experiments': 1}}
# [QAOA] Iter  42  Energy = -1576.27881445+0.00000000j  std = {'shots': 1024, 'circuit_metadata': {}, 'simulator_metadata': {'time_taken_parameter_binding': 0.000178282, 'time_taken_execute': 0.027713266, 'omp_enabled': True, 'max_gpu_memory_mb': 0, 'max_memory_mb': 12977, 'parallel_experiments': 1}}
# [QAOA] Iter  43  Energy = -1628.39446387+0.00000000j  std = {'shots': 1024, 'circuit_metadata': {}, 'simulator_metadata': {'time_taken_parameter_binding': 0.000178763, 'time_taken_execute': 0.02350133, 'omp_enabled': True, 'max_gpu_memory_mb': 0, 'max_memory_mb': 12977, 'parallel_experiments': 1}}
# [QAOA] Iter  44  Energy = -1480.65464160+0.00000000j  std = {'shots': 1024, 'circuit_metadata': {}, 'simulator_metadata': {'time_taken_parameter_binding': 0.000189905, 'time_taken_execute': 0.026913417, 'omp_enabled': True, 'max_gpu_memory_mb': 0, 'max_memory_mb': 12977, 'parallel_experiments': 1}}
# QAOA solve finished in 2.267 s. result.fval = 2020.5560000000005
# solver_result.eigenvalue: -1775.0994003906258
# solver_result.optimal_parameters: {ParameterVectorElement(β[0]): np.float64(-6.286814618634962), ParameterVectorElement(β[1]): np.float64(-5.759082724759369), ParameterVectorElement(γ[0]): np.float64(1.998412467109336), ParameterVectorElement(γ[1]): np.float64(4.620943216014318)}
# solver_result.optimal_point: [-6.28681462 -5.75908272  1.99841247  4.62094322]
# solver_result.eigenstate: {1171: 0.0068359375, 153: 0.0068359375, 143: 0.029296875, 147: 0.0263671875, 5: 0.0009765625, 646: 0.0029296875, 2199: 0.013671875, 134: 0.0205078125, 415: 0.0048828125, 787: 0.0009765625, 399: 0.005859375, 647: 0.0029296875, 406: 0.001953125, 151: 0.0478515625, 142: 0.0146484375, 2059: 0.0009765625, 271: 0.001953125, 26: 0.0009765625, 131: 0.025390625, 149: 0.0068359375, 198: 0.00390625, 391: 0.0029296875, 128: 0.0009765625, 133: 0.017578125, 278: 0.001953125, 139: 0.0146484375, 31: 0.00390625, 135: 0.04296875, 138: 0.0068359375, 13: 0.001953125, 3: 0.009765625, 2463: 0.0009765625, 2195: 0.015625, 150: 0.013671875, 1231: 0.0009765625, 671: 0.0068359375, 1439: 0.001953125, 1177: 0.001953125, 140: 0.0048828125, 159: 0.0380859375, 211: 0.00390625, 1154: 0.0029296875, 407: 0.00390625, 207: 0.001953125, 2586: 0.0009765625, 2198: 0.0087890625, 661: 0.0009765625, 1167: 0.0029296875, 2214: 0.0009765625, 2197: 0.00390625, 191: 0.00390625, 1238: 0.0009765625, 2180: 0.0009765625, 1189: 0.0009765625, 213: 0.0009765625, 157: 0.0078125, 2183: 0.01953125, 2263: 0.0009765625, 2238: 0.0009765625, 63: 0.001953125, 2203: 0.005859375, 1474: 0.0009765625, 3093: 0.0009765625, 132: 0.00390625, 387: 0.005859375, 643: 0.0029296875, 193: 0.0009765625, 7: 0.0029296875, 6: 0.001953125, 2179: 0.0087890625, 1176: 0.0009765625, 2691: 0.001953125, 1159: 0.0126953125, 146: 0.005859375, 129: 0.009765625, 1166: 0.0009765625, 158: 0.0087890625, 141: 0.0078125, 155: 0.0224609375, 2190: 0.001953125, 2055: 0.0029296875, 209: 0.0009765625, 2076: 0.0009765625, 12: 0.001953125, 30: 0.001953125, 2447: 0.0009765625, 2207: 0.0146484375, 1175: 0.0107421875, 1035: 0.0009765625, 215: 0.0029296875, 2194: 0.0029296875, 659: 0.001953125, 199: 0.00390625, 2187: 0.0068359375, 203: 0.0029296875, 3203: 0.0009765625, 2696: 0.0009765625, 2057: 0.0009765625, 167: 0.0029296875, 2184: 0.001953125, 162: 0.0009765625, 2585: 0.0009765625, 2063: 0.001953125, 23: 0.00390625, 1156: 0.0009765625, 2054: 0.0009765625, 1195: 0.0009765625, 534: 0.0009765625, 519: 0.0009765625, 130: 0.0068359375, 3286: 0.0009765625, 418: 0.0009765625, 439: 0.0009765625, 404: 0.0009765625, 2239: 0.0009765625, 951: 0.0009765625, 170: 0.001953125, 2191: 0.0078125, 1158: 0.00390625, 189: 0.001953125, 2189: 0.00390625, 1091: 0.0009765625, 2186: 0.001953125, 657: 0.001953125, 2079: 0.00390625, 20: 0.0009765625, 2201: 0.00390625, 663: 0.001953125, 3465: 0.0009765625, 148: 0.0029296875, 2443: 0.0009765625, 156: 0.0029296875, 389: 0.0029296875, 3230: 0.0009765625, 17: 0.0029296875, 414: 0.0029296875, 2178: 0.0029296875, 36: 0.0009765625, 244: 0.0009765625, 206: 0.0029296875, 2185: 0.0009765625, 2449: 0.001953125, 174: 0.0009765625, 2219: 0.001953125, 163: 0.00390625, 1181: 0.001953125, 29: 0.0009765625, 3543: 0.0009765625, 145: 0.0068359375, 22: 0.00390625, 2474: 0.0009765625, 2193: 0.001953125, 670: 0.0009765625, 183: 0.001953125, 187: 0.0009765625, 664: 0.0009765625, 413: 0.0029296875, 15: 0.0068359375, 3283: 0.0009765625, 1162: 0.0009765625, 655: 0.0009765625, 78: 0.001953125, 190: 0.001953125, 2471: 0.0009765625, 453: 0.0009765625, 2445: 0.001953125, 397: 0.001953125, 65: 0.0009765625, 3223: 0.001953125, 3202: 0.001953125, 3205: 0.0009765625, 1155: 0.0029296875, 2451: 0.0029296875, 2231: 0.00390625, 136: 0.0009765625, 2095: 0.0009765625, 423: 0.0009765625, 154: 0.001953125, 1047: 0.0009765625, 1183: 0.005859375, 1261: 0.0009765625, 386: 0.0009765625, 408: 0.0009765625, 70: 0.001953125, 1031: 0.0029296875, 2067: 0.0009765625, 4: 0.0009765625, 403: 0.0048828125, 2709: 0.0009765625, 532: 0.0009765625, 644: 0.001953125, 2209: 0.0009765625, 1239: 0.0009765625, 703: 0.0009765625, 137: 0.0029296875, 2182: 0.0029296875, 2215: 0.0009765625, 2462: 0.0009765625, 1423: 0.0009765625, 177: 0.0009765625, 3214: 0.0009765625, 0: 0.0009765625, 563: 0.0009765625, 2070: 0.001953125, 2439: 0.001953125, 9: 0.0009765625, 2205: 0.0009765625, 662: 0.0009765625, 182: 0.0009765625, 2487: 0.0009765625, 2262: 0.000976562 ...
# solver_result.aux_operators_evaluated: None
# Recent loss_history (last 10): [np.complex128(6.747101562499871+0j), np.complex128(-1589.35775+0j), np.complex128(738.181548828125+0j), np.complex128(-1775.0994003906258+0j), np.complex128(-426.3068789062501+0j), np.complex128(-1630.7368173828136+0j), np.complex128(-1623.0087246093744+0j), np.complex128(-1576.2788144531269+0j), np.complex128(-1628.3944638671878+0j), np.complex128(-1480.654641601564+0j)]
# Warning: extracted path incomplete: [0, 3]
# Fallback brute-force chosen subset: [2, 4] best perm: (2, 3)
# Trip A distance: 28.963000, Trip B distance: 28.854000, Total: 57.817000
# >> New best solution recorded.
#
# --- Combination 3/10: Trip A patients = ['DT', 'GR', 'IT'] ---
# Local problem size n_local=4 nodes -> expected binary vars = 12
# QAOA instantiated with args: {'optimizer': <__main__.SciPyOptimizerWrapper object at 0x7f069c4c24e0>, 'reps': 2}
# Running MinimumEigenOptimizer (QAOA) on noisy QUBO ...
# [QAOA] Iter   1  Energy = 416.22716309+0.00000000j  std = {'shots': 1024, 'circuit_metadata': {}, 'simulator_metadata': {'time_taken_parameter_binding': 0.000192671, 'time_taken_execute': 0.0288369, 'omp_enabled': True, 'max_gpu_memory_mb': 0, 'max_memory_mb': 12977, 'parallel_experiments': 1}}
# [QAOA] Iter   2  Energy = 434.26520996+0.00000000j  std = {'shots': 1024, 'circuit_metadata': {}, 'simulator_metadata': {'time_taken_parameter_binding': 0.000193279, 'time_taken_execute': 0.025294076, 'omp_enabled': True, 'max_gpu_memory_mb': 0, 'max_memory_mb': 12977, 'parallel_experiments': 1}}
# /usr/local/lib/python3.12/dist-packages/qiskit_optimization/minimum_eigensolvers/qaoa.py:122: UserWarning: Using Sampler V2 (other than StatevectorSampler) without a pass_manager may result in an error. Consider providing a pass_manager for proper circuit transpilation.
#   super().__init__(
# [QAOA] Iter   3  Energy = -548.98112988+0.00000000j  std = {'shots': 1024, 'circuit_metadata': {}, 'simulator_metadata': {'time_taken_parameter_binding': 0.000177267, 'time_taken_execute': 0.022429231, 'omp_enabled': True, 'max_gpu_memory_mb': 0, 'max_memory_mb': 12977, 'parallel_experiments': 1}}
# [QAOA] Iter   4  Energy = -516.88912988+0.00000000j  std = {'shots': 1024, 'circuit_metadata': {}, 'simulator_metadata': {'time_taken_parameter_binding': 0.000195102, 'time_taken_execute': 0.009883592, 'omp_enabled': True, 'max_gpu_memory_mb': 0, 'max_memory_mb': 12977, 'parallel_experiments': 1}}
# [QAOA] Iter   5  Energy = -563.19758594+0.00000000j  std = {'shots': 1024, 'circuit_metadata': {}, 'simulator_metadata': {'time_taken_parameter_binding': 0.000203279, 'time_taken_execute': 0.029363188, 'omp_enabled': True, 'max_gpu_memory_mb': 0, 'max_memory_mb': 12977, 'parallel_experiments': 1}}
# [QAOA] Iter   6  Energy = -18.55001855+0.00000000j  std = {'shots': 1024, 'circuit_metadata': {}, 'simulator_metadata': {'time_taken_parameter_binding': 0.000173326, 'time_taken_execute': 0.010352865, 'omp_enabled': True, 'max_gpu_memory_mb': 0, 'max_memory_mb': 12977, 'parallel_experiments': 1}}
# [QAOA] Iter   7  Energy = 113.07156445+0.00000000j  std = {'shots': 1024, 'circuit_metadata': {}, 'simulator_metadata': {'time_taken_parameter_binding': 0.000188457, 'time_taken_execute': 0.009886494, 'omp_enabled': True, 'max_gpu_memory_mb': 0, 'max_memory_mb': 12977, 'parallel_experiments': 1}}
# [QAOA] Iter   8  Energy = 17.81141406+0.00000000j  std = {'shots': 1024, 'circuit_metadata': {}, 'simulator_metadata': {'time_taken_parameter_binding': 0.000209569, 'time_taken_execute': 0.028554072, 'omp_enabled': True, 'max_gpu_memory_mb': 0, 'max_memory_mb': 12977, 'parallel_experiments': 1}}
# [QAOA] Iter   9  Energy = -166.65917676+0.00000000j  std = {'shots': 1024, 'circuit_metadata': {}, 'simulator_metadata': {'time_taken_parameter_binding': 0.000178768, 'time_taken_execute': 0.010981488, 'omp_enabled': True, 'max_gpu_memory_mb': 0, 'max_memory_mb': 12977, 'parallel_experiments': 1}}
# [QAOA] Iter  10  Energy = -810.34735645+0.00000000j  std = {'shots': 1024, 'circuit_metadata': {}, 'simulator_metadata': {'time_taken_parameter_binding': 0.00043523, 'time_taken_execute': 0.007360559, 'omp_enabled': True, 'max_gpu_memory_mb': 0, 'max_memory_mb': 12977, 'parallel_experiments': 1}}
# [QAOA] Iter  11  Energy = -2568.16892188+0.00000000j  std = {'shots': 1024, 'circuit_metadata': {}, 'simulator_metadata': {'time_taken_parameter_binding': 0.000181653, 'time_taken_execute': 0.025041785, 'omp_enabled': True, 'max_gpu_memory_mb': 0, 'max_memory_mb': 12977, 'parallel_experiments': 1}}
# [QAOA] Iter  12  Energy = 490.66487793+0.00000000j  std = {'shots': 1024, 'circuit_metadata': {}, 'simulator_metadata': {'time_taken_parameter_binding': 0.000192061, 'time_taken_execute': 0.010979017, 'omp_enabled': True, 'max_gpu_memory_mb': 0, 'max_memory_mb': 12977, 'parallel_experiments': 1}}
# [QAOA] Iter  13  Energy = 3814.69395117+0.00000000j  std = {'shots': 1024, 'circuit_metadata': {}, 'simulator_metadata': {'time_taken_parameter_binding': 0.000177305, 'time_taken_execute': 0.020175634, 'omp_enabled': True, 'max_gpu_memory_mb': 0, 'max_memory_mb': 12977, 'parallel_experiments': 1}}
# [QAOA] Iter  14  Energy = -1586.36494531+0.00000000j  std = {'shots': 1024, 'circuit_metadata': {}, 'simulator_metadata': {'time_taken_parameter_binding': 0.000191152, 'time_taken_execute': 0.016870009, 'omp_enabled': True, 'max_gpu_memory_mb': 0, 'max_memory_mb': 12977, 'parallel_experiments': 1}}
# [QAOA] Iter  15  Energy = 12892.87870020+0.00000000j  std = {'shots': 1024, 'circuit_metadata': {}, 'simulator_metadata': {'time_taken_parameter_binding': 0.00019175, 'time_taken_execute': 0.012926133, 'omp_enabled': True, 'max_gpu_memory_mb': 0, 'max_memory_mb': 12977, 'parallel_experiments': 1}}
# [QAOA] Iter  16  Energy = 9269.83665430+0.00000000j  std = {'shots': 1024, 'circuit_metadata': {}, 'simulator_metadata': {'time_taken_parameter_binding': 0.000179372, 'time_taken_execute': 0.026243541, 'omp_enabled': True, 'max_gpu_memory_mb': 0, 'max_memory_mb': 12977, 'parallel_experiments': 1}}
# [QAOA] Iter  17  Energy = -432.53113281+0.00000000j  std = {'shots': 1024, 'circuit_metadata': {}, 'simulator_metadata': {'time_taken_parameter_binding': 0.000179176, 'time_taken_execute': 0.011794643, 'omp_enabled': True, 'max_gpu_memory_mb': 0, 'max_memory_mb': 12977, 'parallel_experiments': 1}}
# [QAOA] Iter  18  Energy = -2882.55344727+0.00000000j  std = {'shots': 1024, 'circuit_metadata': {}, 'simulator_metadata': {'time_taken_parameter_binding': 0.000185888, 'time_taken_execute': 0.009630983, 'omp_enabled': True, 'max_gpu_memory_mb': 0, 'max_memory_mb': 12977, 'parallel_experiments': 1}}
# [QAOA] Iter  19  Energy = -1075.99692578+0.00000000j  std = {'shots': 1024, 'circuit_metadata': {}, 'simulator_metadata': {'time_taken_parameter_binding': 0.000217869, 'time_taken_execute': 0.031556766, 'omp_enabled': True, 'max_gpu_memory_mb': 0, 'max_memory_mb': 12977, 'parallel_experiments': 1}}
# [QAOA] Iter  20  Energy = 69.91653223+0.00000000j  std = {'shots': 1024, 'circuit_metadata': {}, 'simulator_metadata': {'time_taken_parameter_binding': 0.000200662, 'time_taken_execute': 0.009208516, 'omp_enabled': True, 'max_gpu_memory_mb': 0, 'max_memory_mb': 12977, 'parallel_experiments': 1}}
# [QAOA] Iter  21  Energy = 458.99835937+0.00000000j  std = {'shots': 1024, 'circuit_metadata': {}, 'simulator_metadata': {'time_taken_parameter_binding': 0.0001926, 'time_taken_execute': 0.027990617, 'omp_enabled': True, 'max_gpu_memory_mb': 0, 'max_memory_mb': 12977, 'parallel_experiments': 1}}
# [QAOA] Iter  22  Energy = -1972.22249316+0.00000000j  std = {'shots': 1024, 'circuit_metadata': {}, 'simulator_metadata': {'time_taken_parameter_binding': 0.000184556, 'time_taken_execute': 0.027568314, 'omp_enabled': True, 'max_gpu_memory_mb': 0, 'max_memory_mb': 12977, 'parallel_experiments': 1}}
# [QAOA] Iter  23  Energy = -2118.40784277+0.00000000j  std = {'shots': 1024, 'circuit_metadata': {}, 'simulator_metadata': {'time_taken_parameter_binding': 0.000177508, 'time_taken_execute': 0.018157918, 'omp_enabled': True, 'max_gpu_memory_mb': 0, 'max_memory_mb': 12977, 'parallel_experiments': 1}}
# [QAOA] Iter  24  Energy = -1310.83643945+0.00000000j  std = {'shots': 1024, 'circuit_metadata': {}, 'simulator_metadata': {'time_taken_parameter_binding': 0.000184361, 'time_taken_execute': 0.00937019, 'omp_enabled': True, 'max_gpu_memory_mb': 0, 'max_memory_mb': 12977, 'parallel_experiments': 1}}
# [QAOA] Iter  25  Energy = 2031.70872363+0.00000000j  std = {'shots': 1024, 'circuit_metadata': {}, 'simulator_metadata': {'time_taken_parameter_binding': 0.000177109, 'time_taken_execute': 0.026816748, 'omp_enabled': True, 'max_gpu_memory_mb': 0, 'max_memory_mb': 12977, 'parallel_experiments': 1}}
# [QAOA] Iter  26  Energy = -942.34860254+0.00000000j  std = {'shots': 1024, 'circuit_metadata': {}, 'simulator_metadata': {'time_taken_parameter_binding': 0.000115691, 'time_taken_execute': 0.006641452, 'omp_enabled': True, 'max_gpu_memory_mb': 0, 'max_memory_mb': 12977, 'parallel_experiments': 1}}
# [QAOA] Iter  27  Energy = 52.99741699+0.00000000j  std = {'shots': 1024, 'circuit_metadata': {}, 'simulator_metadata': {'time_taken_parameter_binding': 0.000121806, 'time_taken_execute': 0.006737064, 'omp_enabled': True, 'max_gpu_memory_mb': 0, 'max_memory_mb': 12977, 'parallel_experiments': 1}}
# [QAOA] Iter  28  Energy = -2040.54150000+0.00000000j  std = {'shots': 1024, 'circuit_metadata': {}, 'simulator_metadata': {'time_taken_parameter_binding': 0.000120866, 'time_taken_execute': 0.006323647, 'omp_enabled': True, 'max_gpu_memory_mb': 0, 'max_memory_mb': 12977, 'parallel_experiments': 1}}
# [QAOA] Iter  29  Energy = -3069.53382520+0.00000000j  std = {'shots': 1024, 'circuit_metadata': {}, 'simulator_metadata': {'time_taken_parameter_binding': 0.000120413, 'time_taken_execute': 0.006432791, 'omp_enabled': True, 'max_gpu_memory_mb': 0, 'max_memory_mb': 12977, 'parallel_experiments': 1}}
# [QAOA] Iter  30  Energy = -1323.41866211+0.00000000j  std = {'shots': 1024, 'circuit_metadata': {}, 'simulator_metadata': {'time_taken_parameter_binding': 0.000121156, 'time_taken_execute': 0.006541618, 'omp_enabled': True, 'max_gpu_memory_mb': 0, 'max_memory_mb': 12977, 'parallel_experiments': 1}}
# [QAOA] Iter  31  Energy = -1954.26447852+0.00000000j  std = {'shots': 1024, 'circuit_metadata': {}, 'simulator_metadata': {'time_taken_parameter_binding': 0.000116673, 'time_taken_execute': 0.006530012, 'omp_enabled': True, 'max_gpu_memory_mb': 0, 'max_memory_mb': 12977, 'parallel_experiments': 1}}
# [QAOA] Iter  32  Energy = 1741.13086133+0.00000000j  std = {'shots': 1024, 'circuit_metadata': {}, 'simulator_metadata': {'time_taken_parameter_binding': 0.000132685, 'time_taken_execute': 0.00677893, 'omp_enabled': True, 'max_gpu_memory_mb': 0, 'max_memory_mb': 12977, 'parallel_experiments': 1}}
# ...
# [QAOA] Iter   4  Energy = -188.42344434+0.00000000j  std = {'shots': 1024, 'circuit_metadata': {}, 'simulator_metadata': {'time_taken_parameter_binding': 0.000117562, 'time_taken_execute': 0.006770506, 'omp_enabled': True, 'max_gpu_memory_mb': 0, 'max_memory_mb': 12977, 'parallel_experiments': 1}}
# [QAOA] Iter   5  Energy = -565.51471582+0.00000000j  std = {'shots': 1024, 'circuit_metadata': {}, 'simulator_metadata': {'time_taken_parameter_binding': 0.000114324, 'time_taken_execute': 0.006664076, 'omp_enabled': True, 'max_gpu_memory_mb': 0, 'max_memory_mb': 12977, 'parallel_experiments': 1}}
# /usr/local/lib/python3.12/dist-packages/qiskit_optimization/minimum_eigensolvers/qaoa.py:122: UserWarning: Using Sampler V2 (other than StatevectorSampler) without a pass_manager may result in an error. Consider providing a pass_manager for proper circuit transpilation.
#   super().__init__(
# [QAOA] Iter   6  Energy = 3.35500293+0.00000000j  std = {'shots': 1024, 'circuit_metadata': {}, 'simulator_metadata': {'time_taken_parameter_binding': 0.000119312, 'time_taken_execute': 0.006837155, 'omp_enabled': True, 'max_gpu_memory_mb': 0, 'max_memory_mb': 12977, 'parallel_experiments': 1}}
# [QAOA] Iter   7  Energy = -7.87304395+0.00000000j  std = {'shots': 1024, 'circuit_metadata': {}, 'simulator_metadata': {'time_taken_parameter_binding': 0.000201679, 'time_taken_execute': 0.00774369, 'omp_enabled': True, 'max_gpu_memory_mb': 0, 'max_memory_mb': 12977, 'parallel_experiments': 1}}
# [QAOA] Iter   8  Energy = -358.36241211+0.00000000j  std = {'shots': 1024, 'circuit_metadata': {}, 'simulator_metadata': {'time_taken_parameter_binding': 0.000112901, 'time_taken_execute': 0.006634816, 'omp_enabled': True, 'max_gpu_memory_mb': 0, 'max_memory_mb': 12977, 'parallel_experiments': 1}}
# [QAOA] Iter   9  Energy = -37.37767187+0.00000000j  std = {'shots': 1024, 'circuit_metadata': {}, 'simulator_metadata': {'time_taken_parameter_binding': 0.000118148, 'time_taken_execute': 0.00666632, 'omp_enabled': True, 'max_gpu_memory_mb': 0, 'max_memory_mb': 12977, 'parallel_experiments': 1}}
# [QAOA] Iter  10  Energy = -211.89661719+0.00000000j  std = {'shots': 1024, 'circuit_metadata': {}, 'simulator_metadata': {'time_taken_parameter_binding': 0.000122982, 'time_taken_execute': 0.006645311, 'omp_enabled': True, 'max_gpu_memory_mb': 0, 'max_memory_mb': 12977, 'parallel_experiments': 1}}
# [QAOA] Iter  11  Energy = -510.40429297+0.00000000j  std = {'shots': 1024, 'circuit_metadata': {}, 'simulator_metadata': {'time_taken_parameter_binding': 0.000116098, 'time_taken_execute': 0.006681748, 'omp_enabled': True, 'max_gpu_memory_mb': 0, 'max_memory_mb': 12977, 'parallel_experiments': 1}}
# [QAOA] Iter  12  Energy = -105.95578125+0.00000000j  std = {'shots': 1024, 'circuit_metadata': {}, 'simulator_metadata': {'time_taken_parameter_binding': 0.000114726, 'time_taken_execute': 0.006616819, 'omp_enabled': True, 'max_gpu_memory_mb': 0, 'max_memory_mb': 12977, 'parallel_experiments': 1}}
# [QAOA] Iter  13  Energy = -1499.11491016+0.00000000j  std = {'shots': 1024, 'circuit_metadata': {}, 'simulator_metadata': {'time_taken_parameter_binding': 0.000142058, 'time_taken_execute': 0.00708005, 'omp_enabled': True, 'max_gpu_memory_mb': 0, 'max_memory_mb': 12977, 'parallel_experiments': 1}}
# [QAOA] Iter  14  Energy = -581.49286719+0.00000000j  std = {'shots': 1024, 'circuit_metadata': {}, 'simulator_metadata': {'time_taken_parameter_binding': 0.000114724, 'time_taken_execute': 0.006879679, 'omp_enabled': True, 'max_gpu_memory_mb': 0, 'max_memory_mb': 12977, 'parallel_experiments': 1}}
# [QAOA] Iter  15  Energy = -604.07441504+0.00000000j  std = {'shots': 1024, 'circuit_metadata': {}, 'simulator_metadata': {'time_taken_parameter_binding': 0.000127465, 'time_taken_execute': 0.006671056, 'omp_enabled': True, 'max_gpu_memory_mb': 0, 'max_memory_mb': 12977, 'parallel_experiments': 1}}
# [QAOA] Iter  16  Energy = -818.67069824+0.00000000j  std = {'shots': 1024, 'circuit_metadata': {}, 'simulator_metadata': {'time_taken_parameter_binding': 0.000123598, 'time_taken_execute': 0.006731169, 'omp_enabled': True, 'max_gpu_memory_mb': 0, 'max_memory_mb': 12977, 'parallel_experiments': 1}}
# [QAOA] Iter  17  Energy = -1131.05454492+0.00000000j  std = {'shots': 1024, 'circuit_metadata': {}, 'simulator_metadata': {'time_taken_parameter_binding': 0.000110037, 'time_taken_execute': 0.006737586, 'omp_enabled': True, 'max_gpu_memory_mb': 0, 'max_memory_mb': 12977, 'parallel_experiments': 1}}
# [QAOA] Iter  18  Energy = -1412.35477051+0.00000000j  std = {'shots': 1024, 'circuit_metadata': {}, 'simulator_metadata': {'time_taken_parameter_binding': 0.000115309, 'time_taken_execute': 0.006585594, 'omp_enabled': True, 'max_gpu_memory_mb': 0, 'max_memory_mb': 12977, 'parallel_experiments': 1}}
# [QAOA] Iter  19  Energy = -1555.05385254+0.00000000j  std = {'shots': 1024, 'circuit_metadata': {}, 'simulator_metadata': {'time_taken_parameter_binding': 0.000135535, 'time_taken_execute': 0.00661791, 'omp_enabled': True, 'max_gpu_memory_mb': 0, 'max_memory_mb': 12977, 'parallel_experiments': 1}}
# [QAOA] Iter  20  Energy = -206.65679785+0.00000000j  std = {'shots': 1024, 'circuit_metadata': {}, 'simulator_metadata': {'time_taken_parameter_binding': 0.000114289, 'time_taken_execute': 0.006643647, 'omp_enabled': True, 'max_gpu_memory_mb': 0, 'max_memory_mb': 12977, 'parallel_experiments': 1}}
# [QAOA] Iter  21  Energy = -404.10509766+0.00000000j  std = {'shots': 1024, 'circuit_metadata': {}, 'simulator_metadata': {'time_taken_parameter_binding': 0.000110804, 'time_taken_execute': 0.006657332, 'omp_enabled': True, 'max_gpu_memory_mb': 0, 'max_memory_mb': 12977, 'parallel_experiments': 1}}
# [QAOA] Iter  22  Energy = -2112.54788184+0.00000000j  std = {'shots': 1024, 'circuit_metadata': {}, 'simulator_metadata': {'time_taken_parameter_binding': 0.000132038, 'time_taken_execute': 0.006684107, 'omp_enabled': True, 'max_gpu_memory_mb': 0, 'max_memory_mb': 12977, 'parallel_experiments': 1}}
# [QAOA] Iter  23  Energy = -785.85202637+0.00000000j  std = {'shots': 1024, 'circuit_metadata': {}, 'simulator_metadata': {'time_taken_parameter_binding': 0.000117216, 'time_taken_execute': 0.006669301, 'omp_enabled': True, 'max_gpu_memory_mb': 0, 'max_memory_mb': 12977, 'parallel_experiments': 1}}
# [QAOA] Iter  24  Energy = -869.86688477+0.00000000j  std = {'shots': 1024, 'circuit_metadata': {}, 'simulator_metadata': {'time_taken_parameter_binding': 0.000128746, 'time_taken_execute': 0.006536437, 'omp_enabled': True, 'max_gpu_memory_mb': 0, 'max_memory_mb': 12977, 'parallel_experiments': 1}}
# [QAOA] Iter  25  Energy = -1106.07363672+0.00000000j  std = {'shots': 1024, 'circuit_metadata': {}, 'simulator_metadata': {'time_taken_parameter_binding': 0.000116719, 'time_taken_execute': 0.006732392, 'omp_enabled': True, 'max_gpu_memory_mb': 0, 'max_memory_mb': 12977, 'parallel_experiments': 1}}
# [QAOA] Iter  26  Energy = -988.48956543+0.00000000j  std = {'shots': 1024, 'circuit_metadata': {}, 'simulator_metadata': {'time_taken_parameter_binding': 0.000114362, 'time_taken_execute': 0.006609976, 'omp_enabled': True, 'max_gpu_memory_mb': 0, 'max_memory_mb': 12977, 'parallel_experiments': 1}}
# [QAOA] Iter  27  Energy = -1505.34152832+0.00000000j  std = {'shots': 1024, 'circuit_metadata': {}, 'simulator_metadata': {'time_taken_parameter_binding': 0.000176231, 'time_taken_execute': 0.007334383, 'omp_enabled': True, 'max_gpu_memory_mb': 0, 'max_memory_mb': 12977, 'parallel_experiments': 1}}
# [QAOA] Iter  28  Energy = -1412.11725781+0.00000000j  std = {'shots': 1024, 'circuit_metadata': {}, 'simulator_metadata': {'time_taken_parameter_binding': 0.000117363, 'time_taken_execute': 0.006696146, 'omp_enabled': True, 'max_gpu_memory_mb': 0, 'max_memory_mb': 12977, 'parallel_experiments': 1}}
# [QAOA] Iter  29  Energy = -2093.28907422+0.00000000j  std = {'shots': 1024, 'circuit_metadata': {}, 'simulator_metadata': {'time_taken_parameter_binding': 0.000118615, 'time_taken_execute': 0.006422422, 'omp_enabled': True, 'max_gpu_memory_mb': 0, 'max_memory_mb': 12977, 'parallel_experiments': 1}}
# [QAOA] Iter  30  Energy = -1001.95201270+0.00000000j  std = {'shots': 1024, 'circuit_metadata': {}, 'simulator_metadata': {'time_taken_parameter_binding': 0.000117412, 'time_taken_execute': 0.006623144, 'omp_enabled': True, 'max_gpu_memory_mb': 0, 'max_memory_mb': 12977, 'parallel_experiments': 1}}
# [QAOA] Iter  31  Energy = -1641.18709863+0.00000000j  std = {'shots': 1024, 'circuit_metadata': {}, 'simulator_metadata': {'time_taken_parameter_binding': 0.000116885, 'time_taken_execute': 0.006471085, 'omp_enabled': True, 'max_gpu_memory_mb': 0, 'max_memory_mb': 12977, 'parallel_experiments': 1}}
# [QAOA] Iter  32  Energy = -1783.10999414+0.00000000j  std = {'shots': 1024, 'circuit_metadata': {}, 'simulator_metadata': {'time_taken_parameter_binding': 0.000119365, 'time_taken_execute': 0.006624838, 'omp_enabled': True, 'max_gpu_memory_mb': 0, 'max_memory_mb': 12977, 'parallel_experiments': 1}}
# [QAOA] Iter  33  Energy = -1944.34236035+0.00000000j  std = {'shots': 1024, 'circuit_metadata': {}, 'simulator_metadata': {'time_taken_parameter_binding': 0.000130527, 'time_taken_execute': 0.006552365, 'omp_enabled': True, 'max_gpu_memory_mb': 0, 'max_memory_mb': 12977, 'parallel_experiments': 1}}
# [QAOA] Iter  34  Energy = -2063.88800195+0.00000000j  std = {'shots': 1024, 'circuit_metadata': {}, 'simulator_metadata': {'time_taken_parameter_binding': 0.000111089, 'time_taken_execute': 0.006561135, 'omp_enabled': True, 'max_gpu_memory_mb': 0, 'max_memory_mb': 12977, 'parallel_experiments': 1}}
# [QAOA] Iter  35  Energy = -2045.59555273+0.00000000j  std = {'shots': 1024, 'circuit_metadata': {}, 'simulator_metadata': {'time_taken_parameter_binding': 0.00011235, 'time_taken_execute': 0.006529127, 'omp_enabled': True, 'max_gpu_memory_mb': 0, 'max_memory_mb': 12977, 'parallel_experiments': 1}}
# [QAOA] Iter  36  Energy = -1752.53137891+0.00000000j  std = {'shots': 1024, 'circuit_metadata': {}, 'simulator_metadata': {'time_taken_parameter_binding': 0.000176109, 'time_taken_execute': 0.01101262, 'omp_enabled': True, 'max_gpu_memory_mb': 0, 'max_memory_mb': 12977, 'parallel_experiments': 1}}
# [QAOA] Iter  37  Energy = -2064.15271973+0.00000000j  std = {'shots': 1024, 'circuit_metadata': {}, 'simulator_metadata': {'time_taken_parameter_binding': 0.000118296, 'time_taken_execute': 0.006490444, 'omp_enabled': True, 'max_gpu_memory_mb': 0, 'max_memory_mb': 12977, 'parallel_experiments': 1}}
# QAOA solve finished in 2.232 s. result.fval = 35.904999999998836
# solver_result.eigenvalue: -2112.547881835937
# solver_result.optimal_parameters: {ParameterVectorElement(β[0]): np.float64(2.921521651888985), ParameterVectorElement(β[1]): np.float64(4.581310132166535), ParameterVectorElement(γ[0]): np.float64(4.219503099642369), ParameterVectorElement(γ[1]): np.float64(4.925545422185899)}
# solver_result.optimal_point: [2.92152165 4.58131013 4.2195031  4.92554542]
# solver_result.eigenstate: {1324: 0.0009765625, 1230: 0.001953125, 333: 0.0009765625, 616: 0.0009765625, 10: 0.0009765625, 3010: 0.0009765625, 325: 0.0009765625, 2383: 0.0009765625, 589: 0.001953125, 552: 0.0009765625, 1638: 0.0009765625, 2087: 0.0009765625, 1897: 0.0009765625, 2898: 0.001953125, 1294: 0.00390625, 79: 0.001953125, 1289: 0.0029296875, 796: 0.0009765625, 3403: 0.0009765625, 1604: 0.0009765625, 668: 0.001953125, 1032: 0.0009765625, 1801: 0.0068359375, 648: 0.00390625, 1618: 0.0009765625, 625: 0.0009765625, 871: 0.0009765625, 3109: 0.0009765625, 2829: 0.001953125, 520: 0.0029296875, 1803: 0.0078125, 650: 0.0029296875, 904: 0.005859375, 266: 0.001953125, 847: 0.0048828125, 3435: 0.0009765625, 2141: 0.0009765625, 2696: 0.001953125, 722: 0.0009765625, 578: 0.001953125, 1389: 0.0009765625, 3681: 0.001953125, 3405: 0.0009765625, 783: 0.0087890625, 567: 0.001953125, 3872: 0.0009765625, 2511: 0.001953125, 1390: 0.0009765625, 3400: 0.0068359375, 2056: 0.0009765625, 684: 0.0009765625, 1802: 0.0048828125, 868: 0.001953125, 2507: 0.0009765625, 3848: 0.00390625, 2442: 0.0029296875, 2587: 0.0009765625, 781: 0.0029296875, 808: 0.001953125, 2600: 0.0009765625, 1288: 0.0048828125, 1823: 0.001953125, 834: 0.0009765625, 1797: 0.0009765625, 2825: 0.0029296875, 1368: 0.0009765625, 1071: 0.001953125, 1105: 0.0009765625, 2856: 0.0009765625, 2903: 0.0009765625, 2880: 0.0009765625, 791: 0.001953125, 1817: 0.001953125, 814: 0.001953125, 2589: 0.0009765625, 2831: 0.0029296875, 584: 0.001953125, 221: 0.001953125, 2151: 0.0009765625, 3404: 0.0009765625, 638: 0.0009765625, 3685: 0.0009765625, 3880: 0.001953125, 2838: 0.0009765625, 1751: 0.0009765625, 602: 0.001953125, 609: 0.0009765625, 1612: 0.0009765625, 2576: 0.0009765625, 332: 0.0009765625, 706: 0.0009765625, 3328: 0.0009765625, 1888: 0.001953125, 322: 0.001953125, 1129: 0.0009765625, 1026: 0.0009765625, 1865: 0.0009765625, 2086: 0.0009765625, 3212: 0.0009765625, 1126: 0.0009765625, 2952: 0.0029296875, 2700: 0.001953125, 1100: 0.001953125, 2638: 0.001953125, 2376: 0.001953125, 1559: 0.0009765625, 2157: 0.0009765625, 1602: 0.0009765625, 2127: 0.001953125, 624: 0.001953125, 2888: 0.001953125, 2446: 0.0009765625, 1608: 0.0029296875, 1800: 0.01171875, 2668: 0.0009765625, 2975: 0.0009765625, 1295: 0.005859375, 776: 0.001953125, 2828: 0.005859375, 903: 0.001953125, 3466: 0.0009765625, 239: 0.0009765625, 1871: 0.001953125, 1610: 0.0009765625, 855: 0.001953125, 3352: 0.0009765625, 925: 0.0009765625, 2349: 0.0009765625, 654: 0.001953125, 667: 0.0009765625, 2063: 0.0029296875, 1103: 0.001953125, 2850: 0.0009765625, 524: 0.0009765625, 1822: 0.0009765625, 1309: 0.0009765625, 1819: 0.001953125, 2761: 0.0009765625, 1311: 0.0029296875, 2159: 0.0029296875, 2400: 0.0029296875, 3337: 0.0029296875, 2960: 0.0009765625, 724: 0.0009765625, 2863: 0.001953125, 320: 0.0009765625, 1868: 0.001953125, 3815: 0.0009765625, 1928: 0.0048828125, 1571: 0.0009765625, 1947: 0.0009765625, 911: 0.0009765625, 2374: 0.0009765625, 3904: 0.0009765625, 2120: 0.001953125, 553: 0.0009765625, 2953: 0.00390625, 3008: 0.0009765625, 649: 0.001953125, 2184: 0.001953125, 2378: 0.001953125, 2826: 0.00390625, 1676: 0.0009765625, 896: 0.001953125, 1546: 0.0009765625, 1816: 0.005859375, 208: 0.0009765625, 2570: 0.0009765625, 1052: 0.0009765625, 2664: 0.001953125, 2702: 0.001953125, 840: 0.00390625, 615: 0.00390625, 1889: 0.0009765625, 976: 0.001953125, 812: 0.001953125, 2049: 0.0009765625, 802: 0.0009765625, 1806: 0.001953125, 1672: 0.0009765625, 119: 0.001953125, 1223: 0.001953125, 2505: 0.0009765625, 2830: 0.00390625, 708: 0.0009765625, 3340: 0.0009765625, 858: 0.001953125, 1562: 0.0009765625, 2247: 0.0009765625, 2317: 0.001953125, 1376: 0.0029296875, 1813: 0.001953125, 2955: 0.0009765625, 2560: 0.001953125, 2640: 0.001953125, 2658: 0.0009765625, 811: 0.0009765625, 2832: 0.0009765625, 715: 0.001953125, 2728: 0.001953125, 3866: 0.0009765625, 1623: 0.0009765625, 1545: 0.001953125, 2982: 0.0009765625, 1708: 0.0009765625, 2380: 0.0029296875, 240 ...
# solver_result.aux_operators_evaluated: None
# Recent loss_history (last 10): [np.complex128(-1412.117257812501+0j), np.complex128(-2093.289074218749+0j), np.complex128(-1001.9520126953124+0j), np.complex128(-1641.1870986328106+0j), np.complex128(-1783.1099941406274+0j), np.complex128(-1944.342360351564+0j), np.complex128(-2063.8880019531266+0j), np.complex128(-2045.5955527343747+0j), np.complex128(-1752.5313789062502+0j), np.complex128(-2064.1527197265623+0j)]
# Trip A distance: 35.905000, Trip B distance: 28.774000, Total: 64.679000
#
# ==================================================
# FINAL BEST SOLUTION (quantum Trip A, noisy simulator):
# Total optimal distance (hybrid): 57.523000
# Trip A (3 patients): ['DT', 'GR', 'IT'] Route: H -> DT -> GR -> IT -> H Distance: 30.736000
# Trip B (2 patients): ['R2', 'R3_2'] Route: H -> R3_2 -> R2 -> H Distance: 26.787000
# QAOA sampler: SamplerV2 QAOA time (s): 2.823753833770752
# ==================================================

# %% [markdown]
# ## Noisy simulation but with a clearer logging

# %%
# Clean prints version: FakeProvider noise -> AerSimulator -> primitives Sampler -> QAOA + MinimumEigenOptimizer
# Toggle VERBOSE for more internal debug prints (constructor errors, solver_result fields, etc.)

import time, itertools, math, traceback
import numpy as np

VERBOSE = False  # set True to see more debug output

# small helper for controlled printing
def info(*args, **kwargs):
    print(*args, **kwargs)

def dbg(*args, **kwargs):
    if VERBOSE:
        print(*args, **kwargs)

# Qiskit optimization pieces
from qiskit_optimization import QuadraticProgram
from qiskit_optimization.converters import QuadraticProgramToQubo
from qiskit_optimization.algorithms import MinimumEigenOptimizer
from qiskit_optimization.minimum_eigensolvers import QAOA

# Fake provider + Aer noise
from qiskit.providers.fake_provider import GenericBackendV2
from qiskit_aer import AerSimulator
from qiskit_aer.noise import NoiseModel

# Try to find a primitives-style Sampler implementation
PrimitiveSamplerClass = None
sampler_creation_exceptions = []

for attempt_name, attempt_import in [
    ("qiskit.primitives.Sampler", lambda: __import__("qiskit.primitives", fromlist=["Sampler"]).Sampler),
    ("qiskit_aer.primitives.SamplerV2", lambda: __import__("qiskit_aer.primitives", fromlist=["SamplerV2"]).SamplerV2),
    ("qiskit_aer.primitives.Sampler", lambda: __import__("qiskit_aer.primitives", fromlist=["Sampler"]).Sampler),
]:
    try:
        cls = attempt_import()
        PrimitiveSamplerClass = cls
        dbg(f"Primitive sampler available via: {attempt_name}")
        break
    except Exception as e:
        sampler_creation_exceptions.append((attempt_name, e))
        dbg(f"Sampler import {attempt_name} failed: {type(e).__name__}: {e}")

# Optimizer selection / SciPy fallback
optimizer = None
try:
    from qiskit.algorithms.optimizers import SPSA
    optimizer = SPSA(maxiter=50)
    dbg("Using SPSA optimizer.")
except Exception:
    try:
        from qiskit.algorithms.optimizers import COBYLA
        optimizer = COBYLA(maxiter=200)
        dbg("Using COBYLA optimizer.")
    except Exception:
        # SciPy wrapper compatible with QAOA expectations
        from scipy.optimize import minimize as scipy_minimize
        class SciPyOptimizerWrapper:
            def __init__(self, method='COBYLA', options=None):
                self.method = method
                self.options = options or {"maxiter":200}
            def optimize(self, num_vars, objective, initial_point=None):
                def obj_for_scipy(x):
                    val = objective(x)
                    return float(val) if not isinstance(val, (tuple,list)) else float(val[0])
                x0 = initial_point if initial_point is not None else [0.0]*num_vars
                res = scipy_minimize(obj_for_scipy, x0, method=self.method, options=self.options)
                return res.x, float(res.fun), getattr(res, "nfev", None)
            def minimize(self, fun, x0, **kwargs):
                method = kwargs.pop("method", self.method)
                options = kwargs.pop("options", self.options)
                res = scipy_minimize(fun, x0, method=method, options=options, **kwargs)
                return res
        optimizer = SciPyOptimizerWrapper(method='COBYLA', options={"maxiter":100})
        dbg("Using SciPy-based optimizer wrapper.")

# ------------------------------
# Problem data (same as before)
# ------------------------------
distance_matrix = np.array(
      [[ 0.   ,  8.628, 11.496,  9.445, 10.852,  9.672],
       [14.194,  0.   ,  2.361, 10.922,  9.238,  9.43 ],
       [17.785,  7.745,  0.   , 11.808, 10.124, 10.478],
       [11.864, 19.672, 15.661,  0.   , 11.572, 11.538],
       [ 7.343, 12.172, 10.053,  4.071,  0.   ,  5.931],
       [ 9.269,  9.398, 12.266,  7.318,  8.725,  0.   ]]
)
locations = ['H', 'DT', 'GR', 'R2', 'R3_2', 'IT']
patient_indices = [1,2,3,4,5]
penalty = 1000

# Build fake backend & noise model
max_n_local = 4
expected_qubits = max_n_local * (max_n_local - 1)
info(f"Setup: FakeProvider GenericBackendV2 -> noise model with {expected_qubits} qubits (for Trip A up to 3 patients).")
fake_backend = GenericBackendV2(num_qubits=expected_qubits)

try:
    from qiskit_aer import QasmSimulator
    try:
        device_for_noise = QasmSimulator.from_backend(fake_backend)
        noise_model = NoiseModel.from_backend(device_for_noise)
    except Exception:
        noise_model = NoiseModel.from_backend(fake_backend)
except Exception:
    noise_model = NoiseModel.from_backend(fake_backend)
dbg("Noise model created from fake backend.")

# Create AerSimulator defensively (avoid unsupported kwargs)
sim_seed = 1234
simulator = None
try:
    simulator = AerSimulator(noise_model=noise_model, method='density_matrix', seed_simulator=sim_seed)
    dbg("AerSimulator(method='density_matrix', seed_simulator) created.")
except Exception as e1:
    dbg("Preferred AerSimulator constructor failed:", type(e1).__name__, e1)
    try:
        simulator = AerSimulator(noise_model=noise_model, method='density_matrix')
        dbg("AerSimulator(method='density_matrix') created.")
    except Exception:
        simulator = AerSimulator(noise_model=noise_model)
        dbg("AerSimulator(noise_model) created.")

# Build primitives sampler (try a few constructors) or raise helpful error
sampler = None
sampler_errors = []

if PrimitiveSamplerClass is not None:
    constructors = [
        lambda cls=PrimitiveSamplerClass: cls(backend=simulator),
        lambda cls=PrimitiveSamplerClass: cls(backend=simulator, shots=1024),
        lambda cls=PrimitiveSamplerClass: cls(backend=simulator, mode=simulator),
        lambda cls=PrimitiveSamplerClass: cls(mode=simulator),
        lambda cls=PrimitiveSamplerClass: cls(),
    ]
    for ctor in constructors:
        try:
            sampler = ctor()
            dbg("Primitive sampler created with constructor:", ctor)
            break
        except Exception as e:
            sampler_errors.append((ctor, e))
else:
    sampler_errors.append(("PrimitiveSamplerClass not found", sampler_creation_exceptions))

if sampler is None:
    # give a short, actionable error
    info("ERROR: Could not instantiate a primitives-style Sampler compatible with this Qiskit.")
    if VERBOSE:
        for label, ex in sampler_errors:
            dbg("Attempt:", label, "->", repr(ex))
    raise RuntimeError(
        "Install or enable a primitives Sampler (qiskit.primitives.Sampler or qiskit_aer.primitives.SamplerV2)."
    )

info(f"Using sampler: {type(sampler).__name__}")

# ---- QuadraticProgram helper and reconstruction ----
def build_tsp_quadratic_program(dist_local, penalty=penalty):
    n = dist_local.shape[0]
    qp = QuadraticProgram(name="TSP_local")
    for i in range(n):
        for j in range(n):
            if i == j: continue
            qp.binary_var(name=f"x_{i}_{j}")
    linear = {f"x_{i}_{j}": float(dist_local[i,j]) for i in range(n) for j in range(n) if i!=j}
    qp.minimize(linear=linear)
    for i in range(n):
        arrive = {f"x_{j}_{i}": 1 for j in range(n) if j!=i}
        qp.linear_constraint(linear=arrive, sense="==", rhs=1, name=f"arrive_{i}")
        depart = {f"x_{i}_{j}": 1 for j in range(n) if j!=i}
        qp.linear_constraint(linear=depart, sense="==", rhs=1, name=f"depart_{i}")
    qubo = QuadraticProgramToQubo(penalty=penalty).convert(qp)
    return qp, qubo

def reconstruct_tour_from_solution(variables_dict):
    path_dict = {}
    for varname, val in variables_dict.items():
        try:
            if float(val) > 0.5:
                parts = varname.split('_')
                if len(parts) >= 3:
                    si = int(parts[1]); sj = int(parts[2])
                    path_dict[si] = sj
        except Exception:
            continue
    path = [0]; cur = 0
    while True:
        nxt = path_dict.get(cur, None)
        if nxt is None: break
        if nxt in path: break
        path.append(nxt); cur = nxt
        if len(path) > 50: break
    if len(path) >= 1 and path[-1] != 0 and len(path) == len(path_dict)+1:
        path.append(0)
    return path

# QAOA callback & loss history (quiet by default)
loss_history = []
def qaoa_callback(eval_count, parameters, mean, std):
    loss_history.append(mean)
    dbg(f"[QAOA cb] Iter {eval_count}: Energy={mean:.6f} std={std}")

# Top-level hybrid search (Trip A quantum on 3 patients; Trip B classical on remaining 2)
best = {"distance": float('inf')}

info("Running hybrid search (noisy sampler).")
for idx, group_A in enumerate(itertools.combinations(patient_indices, 3), start=1):
    patient_names = [locations[i] for i in group_A]
    info(f"\n[{idx:02d}/10] Trip A patients: {patient_names}")

    group_B = tuple(p for p in patient_indices if p not in group_A)
    trip_A_nodes = (0,) + group_A
    dist_A_local = distance_matrix[np.ix_(trip_A_nodes, trip_A_nodes)]
    n_local = dist_A_local.shape[0]
    dbg(f"n_local={n_local} -> binary_vars={n_local*(n_local-1)}")

    qp_local, qubo_local = build_tsp_quadratic_program(dist_A_local, penalty=penalty)

    # Instantiate QAOA (try a few signatures quietly)
    qaoa = None
    qaoa_errors = []
    attempts = [
        {"sampler": sampler, "optimizer": optimizer, "reps": 2, "callback": qaoa_callback},
        {"optimizer": optimizer, "sampler": sampler, "reps": 2, "callback": qaoa_callback},
        {"sampler": sampler, "reps": 2, "optimizer": optimizer, "callback": qaoa_callback},
        {"sampler": sampler, "reps": 2, "optimizer": optimizer},
    ]
    for kwargs in attempts:
        try:
            qaoa = QAOA(**kwargs)
            dbg("QAOA created with:", {k:v for k,v in kwargs.items() if k not in ('sampler','callback')})
            break
        except Exception as e:
            qaoa_errors.append((kwargs, e))
            dbg("QAOA attempt failed:", type(e).__name__, e)

    if qaoa is None:
        info("QAOA instantiation failed for this environment. (run with VERBOSE=True for details)")
        if VERBOSE:
            for kw, err in qaoa_errors:
                dbg("Attempt:", {k:(v if k!='sampler' else "<sampler>") for k,v in kw.items()}, "->", repr(err))
        raise RuntimeError("QAOA could not be instantiated.")

    try:
        meo = MinimumEigenOptimizer(min_eigen_solver=qaoa)
    except TypeError:
        meo = MinimumEigenOptimizer(qaoa)

    # Run solver and time it
    t0 = time.time()
    try:
        result = meo.solve(qubo_local)
    except Exception:
        dbg("Exception during solve:")
        traceback.print_exc()
        raise
    t1 = time.time()
    elapsed = t1 - t0

    # concise diagnostics
    fval = getattr(result, "fval", None)
    solver_result = getattr(result, "min_eigen_solver_result", None)
    eigval = None
    if solver_result is not None:
        eigval = getattr(solver_result, "eigenvalue", None)
        # also try alternate common names
        if eigval is None:
            eigval = getattr(solver_result, "min_eigenvalue", None)

    # show short summary: time, fval, eigenvalue (if any), loss history summary
    lh_summary = ""
    if loss_history:
        try:
            lh_summary = f"loss(first/last/min)={loss_history[0]:.6f}/{loss_history[-1]:.6f}/{min(loss_history):.6f}"
        except Exception:
            lh_summary = "loss_history present"
    else:
        lh_summary = "no loss_history"

    info(f"  -> time: {elapsed:.3f}s  raw_obj: {fval if fval is not None else 'N/A'}  eigenval: {eigval if eigval is not None else 'N/A'}  ({lh_summary})")

    # if VERBOSE, show more solver_result internals
    if VERBOSE and solver_result is not None:
        dbg("  solver_result fields (selected):")
        for field in ("optimal_parameters","optimal_point","eigenstate","aux_operators_evaluated"):
            if hasattr(solver_result, field):
                dbg(f"   - {field}: {getattr(solver_result, field)}")

    # Reconstruct path (fallback brute-force if needed)
    path_local = reconstruct_tour_from_solution(result.variables_dict)
    if len(path_local) < n_local:
        dbg("  Warning: extracted path incomplete:", path_local)

    if len(path_local) == n_local and path_local[0] == 0:
        tour = path_local + ([0] if path_local[-1] != 0 else [])
        tripA_dist = sum(float(dist_A_local[a,b]) for a,b in zip(tour[:-1], tour[1:]))
        path_global = [trip_A_nodes[i] for i in path_local]
        if path_global[-1] != 0:
            path_global = path_global + [0]
    else:
        selected = sorted([j for j in range(1,n_local) if any((f"x_{i}_{j}" in result.variables_dict and result.variables_dict[f"x_{i}_{j}"]>0.5) for i in range(n_local) if i!=j)])
        if not selected:
            raise RuntimeError("QAOA returned no selected patient edges; aborting.")
        best_perm = None; best_perm_cost = math.inf
        for perm in itertools.permutations(selected):
            tour = [0] + list(perm) + [0]
            cost = sum(float(dist_A_local[a,b]) for a,b in zip(tour[:-1], tour[1:]))
            if cost < best_perm_cost:
                best_perm_cost = cost; best_perm = perm
        tripA_dist = best_perm_cost
        path_global = [trip_A_nodes[i] for i in ([0] + list(best_perm) + [0])]
        dbg("  Fallback selected subset:", [trip_A_nodes[i] for i in selected], "best_perm:", best_perm)

    # Trip B classical exact (2 patients)
    p1, p2 = group_B
    dist_B_option1 = distance_matrix[0,p1] + distance_matrix[p1,p2] + distance_matrix[p2,0]
    dist_B_option2 = distance_matrix[0,p2] + distance_matrix[p2,p1] + distance_matrix[p1,0]
    if dist_B_option1 <= dist_B_option2:
        tripB_dist = float(dist_B_option1); pathB_global = [0, p1, p2, 0]
    else:
        tripB_dist = float(dist_B_option2); pathB_global = [0, p2, p1, 0]

    total = float(tripA_dist) + float(tripB_dist)
    info(f"  Trip A dist: {tripA_dist:.6f}  Trip B dist: {tripB_dist:.6f}  TOTAL: {total:.6f}")

    if total < best["distance"]:
        best.update({
            "distance": total,
            "trip_A_group": [locations[i] for i in group_A],
            "trip_B_group": [locations[i] for i in group_B],
            "trip_A_route": [locations[i] for i in path_global],
            "trip_B_route": [locations[i] for i in pathB_global],
            "trip_A_dist": tripA_dist,
            "trip_B_dist": tripB_dist,
            "qaoa_time": elapsed,
            "qaoa_sampler_constructor": type(sampler).__name__
        })
        info("  >> New best solution recorded.")

# Final results (compact)
info("\n" + "="*50)
info("FINAL BEST SOLUTION (quantum Trip A, noisy simulator):")
info(f" Total distance (hybrid): {best['distance']:.6f}")
info(f" Trip A (3 patients): {best['trip_A_group']}  Route: {' -> '.join(best['trip_A_route'])}  Distance: {best['trip_A_dist']:.6f}")
info(f" Trip B (2 patients): {best['trip_B_group']}  Route: {' -> '.join(best['trip_B_route'])}  Distance: {best['trip_B_dist']:.6f}")
info(f" Sampler: {best.get('qaoa_sampler_constructor')}  QAOA time (s): {best.get('qaoa_time'):.3f}")
info("="*50)
# Out:
# Setup: FakeProvider GenericBackendV2 -> noise model with 12 qubits (for Trip A up to 3 patients).
# Using sampler: SamplerV2
# Running hybrid search (noisy sampler).
#
# [01/10] Trip A patients: ['DT', 'GR', 'R2']
# /usr/local/lib/python3.12/dist-packages/qiskit_optimization/minimum_eigensolvers/qaoa.py:122: UserWarning: Using Sampler V2 (other than StatevectorSampler) without a pass_manager may result in an error. Consider providing a pass_manager for proper circuit transpilation.
#   super().__init__(
#   -> time: 3.301s  raw_obj: 47.044999999998254  eigenval: -2147.30632910156  (loss(first/last/min)=-229.939472+0.000000j/-2096.724571+0.000000j/-2147.306329+0.000000j)
#   Trip A dist: 47.045000  Trip B dist: 25.740000  TOTAL: 72.785000
#   >> New best solution recorded.
#
# [02/10] Trip A patients: ['DT', 'GR', 'R3_2']
# /usr/local/lib/python3.12/dist-packages/qiskit_optimization/minimum_eigensolvers/qaoa.py:122: UserWarning: Using Sampler V2 (other than StatevectorSampler) without a pass_manager may result in an error. Consider providing a pass_manager for proper circuit transpilation.
#   super().__init__(
#   -> time: 2.133s  raw_obj: 35.822000000000116  eigenval: -2137.4271796874987  (loss(first/last/min)=-229.939472+0.000000j/-1982.212479+0.000000j/-2147.306329+0.000000j)
#   Trip A dist: 35.822000  Trip B dist: 28.854000  TOTAL: 64.676000
#   >> New best solution recorded.
#
# [03/10] Trip A patients: ['DT', 'GR', 'IT']
# /usr/local/lib/python3.12/dist-packages/qiskit_optimization/minimum_eigensolvers/qaoa.py:122: UserWarning: Using Sampler V2 (other than StatevectorSampler) without a pass_manager may result in an error. Consider providing a pass_manager for proper circuit transpilation.
#   super().__init__(
#   -> time: 1.792s  raw_obj: 30.736000000000786  eigenval: -1863.477125976563  (loss(first/last/min)=-229.939472+0.000000j/-1783.770570+0.000000j/-2147.306329+0.000000j)
#   Trip A dist: 30.736000  Trip B dist: 26.787000  TOTAL: 57.523000
#   >> New best solution recorded.
#
# [04/10] Trip A patients: ['DT', 'R2', 'R3_2']
# /usr/local/lib/python3.12/dist-packages/qiskit_optimization/minimum_eigensolvers/qaoa.py:122: UserWarning: Using Sampler V2 (other than StatevectorSampler) without a pass_manager may result in an error. Consider providing a pass_manager for proper circuit transpilation.
#   super().__init__(
#   -> time: 1.618s  raw_obj: 38.465000000000146  eigenval: -3456.5502265625  (loss(first/last/min)=-229.939472+0.000000j/-3297.665584+0.000000j/-3456.550227+0.000000j)
#   Trip A dist: 38.465000  Trip B dist: 31.243000  TOTAL: 69.708000
#
# [05/10] Trip A patients: ['DT', 'R2', 'IT']
# /usr/local/lib/python3.12/dist-packages/qiskit_optimization/minimum_eigensolvers/qaoa.py:122: UserWarning: Using Sampler V2 (other than StatevectorSampler) without a pass_manager may result in an error. Consider providing a pass_manager for proper circuit transpilation.
#   super().__init__(
#   -> time: 1.949s  raw_obj: 37.2400000000016  eigenval: -3817.554572265629  (loss(first/last/min)=-229.939472+0.000000j/-3677.047790+0.000000j/-3817.554572+0.000000j)
#   Trip A dist: 37.240000  Trip B dist: 28.963000  TOTAL: 66.203000
#
# [06/10] Trip A patients: ['DT', 'R3_2', 'IT']
# /usr/local/lib/python3.12/dist-packages/qiskit_optimization/minimum_eigensolvers/qaoa.py:122: UserWarning: Using Sampler V2 (other than StatevectorSampler) without a pass_manager may result in an error. Consider providing a pass_manager for proper circuit transpilation.
#   super().__init__(
#   -> time: 2.265s  raw_obj: 34.126000000000204  eigenval: -3376.3309921875043  (loss(first/last/min)=-229.939472+0.000000j/-3339.107128+0.000000j/-3817.554572+0.000000j)
#   Trip A dist: 34.126000  Trip B dist: 35.168000  TOTAL: 69.294000
#
# [07/10] Trip A patients: ['GR', 'R2', 'R3_2']
# /usr/local/lib/python3.12/dist-packages/qiskit_optimization/minimum_eigensolvers/qaoa.py:122: UserWarning: Using Sampler V2 (other than StatevectorSampler) without a pass_manager may result in an error. Consider providing a pass_manager for proper circuit transpilation.
#   super().__init__(
#   -> time: 2.728s  raw_obj: 37.55500000000029  eigenval: -3181.183049804688  (loss(first/last/min)=-229.939472+0.000000j/-2916.133716+0.000000j/-3817.554572+0.000000j)
#   Trip A dist: 37.555000  Trip B dist: 27.327000  TOTAL: 64.882000
#
# [08/10] Trip A patients: ['GR', 'R2', 'IT']
# /usr/local/lib/python3.12/dist-packages/qiskit_optimization/minimum_eigensolvers/qaoa.py:122: UserWarning: Using Sampler V2 (other than StatevectorSampler) without a pass_manager may result in an error. Consider providing a pass_manager for proper circuit transpilation.
#   super().__init__(
#   -> time: 1.948s  raw_obj: 45.60999999999876  eigenval: -2569.248699218751  (loss(first/last/min)=-229.939472+0.000000j/-2447.455988+0.000000j/-3817.554572+0.000000j)
#   Trip A dist: 45.610000  Trip B dist: 25.209000  TOTAL: 70.819000
#
# [09/10] Trip A patients: ['GR', 'R3_2', 'IT']
# /usr/local/lib/python3.12/dist-packages/qiskit_optimization/minimum_eigensolvers/qaoa.py:122: UserWarning: Using Sampler V2 (other than StatevectorSampler) without a pass_manager may result in an error. Consider providing a pass_manager for proper circuit transpilation.
#   super().__init__(
#   -> time: 1.782s  raw_obj: 39.11800000000039  eigenval: -3139.6572382812496  (loss(first/last/min)=-229.939472+0.000000j/-3054.148219+0.000000j/-3817.554572+0.000000j)
#   Trip A dist: 36.820000  Trip B dist: 31.414000  TOTAL: 68.234000
#
# [10/10] Trip A patients: ['R2', 'R3_2', 'IT']
# /usr/local/lib/python3.12/dist-packages/qiskit_optimization/minimum_eigensolvers/qaoa.py:122: UserWarning: Using Sampler V2 (other than StatevectorSampler) without a pass_manager may result in an error. Consider providing a pass_manager for proper circuit transpilation.
#   super().__init__(
#   -> time: 1.919s  raw_obj: 2022.4680000000008  eigenval: -1640.7348603515622  (loss(first/last/min)=-229.939472+0.000000j/-1302.090650+0.000000j/-3817.554572+0.000000j)
#   Trip A dist: 34.332000  Trip B dist: 28.774000  TOTAL: 63.106000
#
# ==================================================
# FINAL BEST SOLUTION (quantum Trip A, noisy simulator):
#  Total distance (hybrid): 57.523000
#  Trip A (3 patients): ['DT', 'GR', 'IT']  Route: H -> DT -> GR -> IT -> H  Distance: 30.736000
#  Trip B (2 patients): ['R2', 'R3_2']  Route: H -> R3_2 -> R2 -> H  Distance: 26.787000
#  Sampler: SamplerV2  QAOA time (s): 1.792
# ==================================================

# %% [markdown]
# ## Noisy Simulation - Brute force callback for when QAOA returns invalid solution (selects 2 pateints only for example)

# %%
import time, itertools, math, traceback
import numpy as np

VERBOSE = False  # set True for detailed debug output

def info(*a, **k): print(*a, **k)
def dbg(*a, **k):
    if VERBOSE: print(*a, **k)

# Qiskit optimization pieces
from qiskit_optimization import QuadraticProgram
from qiskit_optimization.converters import QuadraticProgramToQubo
from qiskit_optimization.algorithms import MinimumEigenOptimizer
from qiskit_optimization.minimum_eigensolvers import QAOA

# Fake provider + Aer noise
from qiskit.providers.fake_provider import GenericBackendV2
from qiskit_aer import AerSimulator
from qiskit_aer.noise import NoiseModel

# primitive sampler detection
PrimitiveSamplerClass = None
for label, importer in [
    ("qiskit.primitives.Sampler", lambda: __import__("qiskit.primitives", fromlist=["Sampler"]).Sampler),
    ("qiskit_aer.primitives.SamplerV2", lambda: __import__("qiskit_aer.primitives", fromlist=["SamplerV2"]).SamplerV2),
    ("qiskit_aer.primitives.Sampler", lambda: __import__("qiskit_aer.primitives", fromlist=["Sampler"]).Sampler),
]:
    try:
        PrimitiveSamplerClass = importer()
        dbg("Primitive sampler via", label)
        break
    except Exception as e:
        dbg("Sampler import failed for", label, "->", type(e).__name__)

# Optimizer selection / SciPy fallback
optimizer = None
try:
    from qiskit.algorithms.optimizers import SPSA
    optimizer = SPSA(maxiter=50)
    dbg("Using SPSA")
except Exception:
    try:
        from qiskit.algorithms.optimizers import COBYLA
        optimizer = COBYLA(maxiter=200)
        dbg("Using COBYLA")
    except Exception:
        from scipy.optimize import minimize as scipy_minimize
        class SciPyOptimizerWrapper:
            def __init__(self, method='COBYLA', options=None):
                self.method = method
                self.options = options or {"maxiter":200}
            def optimize(self, num_vars, objective, initial_point=None):
                def obj_for_scipy(x):
                    val = objective(x)
                    return float(val) if not isinstance(val, (tuple,list)) else float(val[0])
                x0 = initial_point if initial_point is not None else [0.0]*num_vars
                res = scipy_minimize(obj_for_scipy, x0, method=self.method, options=self.options)
                return res.x, float(res.fun), getattr(res, "nfev", None)
            def minimize(self, fun, x0, **kwargs):
                method = kwargs.pop("method", self.method)
                options = kwargs.pop("options", self.options)
                res = scipy_minimize(fun, x0, method=method, options=options, **kwargs)
                return res
        optimizer = SciPyOptimizerWrapper(method='COBYLA', options={"maxiter":100})
        dbg("Using SciPy optimizer wrapper")

# Problem data
distance_matrix = np.array(
      [[ 0.   ,  8.628, 11.496,  9.445, 10.852,  9.672],
       [14.194,  0.   ,  2.361, 10.922,  9.238,  9.43 ],
       [17.785,  7.745,  0.   , 11.808, 10.124, 10.478],
       [11.864, 19.672, 15.661,  0.   , 11.572, 11.538],
       [ 7.343, 12.172, 10.053,  4.071,  0.   ,  5.931],
       [ 9.269,  9.398, 12.266,  7.318,  8.725,  0.   ]]
)
locations = ['H', 'DT', 'GR', 'R2', 'R3_2', 'IT']
patient_indices = [1,2,3,4,5]
penalty = 1000

# Build fake backend & noise model
max_n_local = 4
expected_qubits = max_n_local * (max_n_local - 1)
info(f"Setup: FakeProvider GenericBackendV2 -> noise model with {expected_qubits} qubits.")
fake_backend = GenericBackendV2(num_qubits=expected_qubits)
try:
    from qiskit_aer import QasmSimulator
    try:
        device_for_noise = QasmSimulator.from_backend(fake_backend)
        noise_model = NoiseModel.from_backend(device_for_noise)
    except Exception:
        noise_model = NoiseModel.from_backend(fake_backend)
except Exception:
    noise_model = NoiseModel.from_backend(fake_backend)
dbg("Noise model built from fake backend.")

# Create AerSimulator defensively
sim_seed = 1234
try:
    simulator = AerSimulator(noise_model=noise_model, method='density_matrix', seed_simulator=sim_seed)
    dbg("AerSimulator created with density_matrix + seed")
except Exception:
    try:
        simulator = AerSimulator(noise_model=noise_model, method='density_matrix')
        dbg("AerSimulator created with density_matrix")
    except Exception:
        simulator = AerSimulator(noise_model=noise_model)
        dbg("AerSimulator created (default)")

# Make primitives sampler if possible
sampler = None
if PrimitiveSamplerClass is not None:
    for ctor in (lambda cls=PrimitiveSamplerClass: cls(backend=simulator),
                 lambda cls=PrimitiveSamplerClass: cls(backend=simulator, shots=1024),
                 lambda cls=PrimitiveSamplerClass: cls()):
        try:
            sampler = ctor()
            break
        except Exception as e:
            dbg("Sampler ctor failed:", type(e).__name__, e)

if sampler is None:
    raise RuntimeError("No primitives Sampler found — install qiskit-aer and ensure qiskit.primitives.Sampler or qiskit_aer.primitives.SamplerV2 is available")

info(f"Using sampler: {type(sampler).__name__}")

# Helper functions
def build_tsp_quadratic_program(dist_local, penalty=penalty):
    n = dist_local.shape[0]
    qp = QuadraticProgram(name="TSP_local")
    for i in range(n):
        for j in range(n):
            if i == j: continue
            qp.binary_var(name=f"x_{i}_{j}")
    linear = {f"x_{i}_{j}": float(dist_local[i,j]) for i in range(n) for j in range(n) if i!=j}
    qp.minimize(linear=linear)
    for i in range(n):
        arrive = {f"x_{j}_{i}": 1 for j in range(n) if j!=i}
        qp.linear_constraint(linear=arrive, sense="==", rhs=1, name=f"arrive_{i}")
        depart = {f"x_{i}_{j}": 1 for j in range(n) if j!=i}
        qp.linear_constraint(linear=depart, sense="==", rhs=1, name=f"depart_{i}")
    qubo = QuadraticProgramToQubo(penalty=penalty).convert(qp)
    return qp, qubo

def reconstruct_tour_from_solution(variables_dict):
    path_dict = {}
    for varname, val in variables_dict.items():
        try:
            if float(val) > 0.5:
                parts = varname.split('_')
                if len(parts) >= 3:
                    si = int(parts[1]); sj = int(parts[2])
                    path_dict[si] = sj
        except Exception:
            continue
    path = [0]; cur = 0
    while True:
        nxt = path_dict.get(cur, None)
        if nxt is None: break
        if nxt in path: break
        path.append(nxt); cur = nxt
        if len(path) > 50: break
    if len(path) >= 1 and path[-1] != 0 and len(path) == len(path_dict)+1:
        path.append(0)
    return path

# QAOA callback & loss history (quiet by default)
loss_history = []
def qaoa_callback(eval_count, parameters, mean, std):
    loss_history.append(mean)
    dbg(f"[QAOA cb] Iter {eval_count}: Energy={mean:.6f} std={std}")

# Main hybrid search
best = {"distance": float('inf')}
info("Running hybrid search (noisy sampler).")

for idx, group_A in enumerate(itertools.combinations(patient_indices, 3), start=1):
    patient_names = [locations[i] for i in group_A]
    info(f"\n[{idx:02d}/10] Trip A patients: {patient_names}")

    group_B = tuple(p for p in patient_indices if p not in group_A)
    trip_A_nodes = (0,) + group_A
    dist_A_local = distance_matrix[np.ix_(trip_A_nodes, trip_A_nodes)]
    n_local = dist_A_local.shape[0]

    qp_local, qubo_local = build_tsp_quadratic_program(dist_A_local, penalty=penalty)

    # instantiate QAOA robustly
    qaoa = None
    qaoa_errors = []
    attempts = [
        {"sampler": sampler, "optimizer": optimizer, "reps": 2, "callback": qaoa_callback},
        {"optimizer": optimizer, "sampler": sampler, "reps": 2, "callback": qaoa_callback},
        {"sampler": sampler, "reps": 2, "optimizer": optimizer, "callback": qaoa_callback},
        {"sampler": sampler, "reps": 2, "optimizer": optimizer},
    ]
    for kwargs in attempts:
        try:
            qaoa = QAOA(**kwargs)
            dbg("QAOA created with", {k:v for k,v in kwargs.items() if k not in ('sampler','callback')})
            break
        except Exception as e:
            qaoa_errors.append((kwargs, e))
            dbg("QAOA attempt failed:", type(e).__name__, e)

    if qaoa is None:
        info("QAOA instantiation failed (set VERBOSE=True for details).")
        raise RuntimeError("QAOA could not be instantiated.")

    try:
        meo = MinimumEigenOptimizer(min_eigen_solver=qaoa)
    except TypeError:
        meo = MinimumEigenOptimizer(qaoa)

    t0 = time.time()
    try:
        result = meo.solve(qubo_local)
    except Exception:
        dbg("Exception during solve:"); traceback.print_exc()
        raise
    t1 = time.time()
    elapsed = t1 - t0

    fval = getattr(result, "fval", None)
    solver_result = getattr(result, "min_eigen_solver_result", None)
    eigval = None
    if solver_result is not None:
        eigval = getattr(solver_result, "eigenvalue", None) or getattr(solver_result, "min_eigenvalue", None)

    if loss_history:
        try:
            lh_summary = f"loss(first/last/min)={loss_history[0]:.6f}/{loss_history[-1]:.6f}/{min(loss_history):.6f}"
        except Exception:
            lh_summary = "loss_history present"
    else:
        lh_summary = "no loss_history"

    info(f"  -> time: {elapsed:.3f}s  raw_obj: {fval if fval is not None else 'N/A'}  eigenval: {eigval if eigval is not None else 'N/A'}  ({lh_summary})")

    # Reconstruct path from QAOA result
    path_local = reconstruct_tour_from_solution(result.variables_dict)
    dbg("Extracted local path:", path_local)

    # Build selected set of patient local indices from result edges (exclude 0)
    selected = sorted([j for j in range(1,n_local) if any((f"x_{i}_{j}" in result.variables_dict and result.variables_dict[f"x_{i}_{j}"]>0.5) for i in range(n_local) if i!=j)])
    dbg("Selected local patient indices by QAOA:", selected)

    # If QAOA found a full Hamiltonian cycle, use it.
    if len(path_local) == n_local and path_local[0] == 0:
        tour = path_local + ([0] if path_local[-1] != 0 else [])
        tripA_dist = sum(float(dist_A_local[a,b]) for a,b in zip(tour[:-1], tour[1:]))
        path_global = [trip_A_nodes[i] for i in path_local]
        if path_global[-1] != 0:
            path_global = path_global + [0]
    else:
        # If QAOA selection is incomplete (not exactly n_local-1 patients), force exact solve among full intended set
        if len(selected) != (n_local - 1):
            dbg("QAOA selected", len(selected), "patients but expected", (n_local - 1))
            info("   > QAOA returned infeasible/partial selection — resolving this subproblem exactly (brute-force) for the full intended patient set.")
            # use full set of intended patients: local indices 1..n_local-1
            selected = list(range(1, n_local))

        # Now brute-force best permutation among 'selected' (which is either QAOA-selected full set or enforced full set)
        best_perm = None; best_perm_cost = math.inf
        for perm in itertools.permutations(selected):
            tour = [0] + list(perm) + [0]
            cost = sum(float(dist_A_local[a,b]) for a,b in zip(tour[:-1], tour[1:]))
            if cost < best_perm_cost:
                best_perm_cost = cost; best_perm = perm
        tripA_dist = best_perm_cost
        path_global = [trip_A_nodes[i] for i in ([0] + list(best_perm) + [0])]
        dbg("Resolved with brute-force best_perm:", best_perm, "cost:", best_perm_cost)

    # Trip B classical exact (2 patients)
    p1, p2 = group_B
    dist_B_option1 = distance_matrix[0,p1] + distance_matrix[p1,p2] + distance_matrix[p2,0]
    dist_B_option2 = distance_matrix[0,p2] + distance_matrix[p2,p1] + distance_matrix[p1,0]
    if dist_B_option1 <= dist_B_option2:
        tripB_dist = float(dist_B_option1); pathB_global = [0, p1, p2, 0]
    else:
        tripB_dist = float(dist_B_option2); pathB_global = [0, p2, p1, 0]

    total = float(tripA_dist) + float(tripB_dist)
    info(f"  Trip A dist: {tripA_dist:.6f}  Trip B dist: {tripB_dist:.6f}  TOTAL: {total:.6f}")

    if total < best["distance"]:
        best.update({
            "distance": total,
            "trip_A_group": [locations[i] for i in group_A],
            "trip_B_group": [locations[i] for i in group_B],
            "trip_A_route": [locations[i] for i in path_global],
            "trip_B_route": [locations[i] for i in pathB_global],
            "trip_A_dist": tripA_dist,
            "trip_B_dist": tripB_dist,
            "qaoa_time": elapsed,
            "qaoa_sampler_constructor": type(sampler).__name__
        })
        info("  >> New best solution recorded.")

# Final results (compact)
info("\n" + "="*50)
info("FINAL BEST SOLUTION (quantum Trip A, noisy simulator):")
info(f" Total distance (hybrid): {best['distance']:.6f}")
info(f" Trip A (3 patients): {best['trip_A_group']}  Route: {' -> '.join(best['trip_A_route'])}  Distance: {best['trip_A_dist']:.6f}")
info(f" Trip B (2 patients): {best['trip_B_group']}  Route: {' -> '.join(best['trip_B_route'])}  Distance: {best['trip_B_dist']:.6f}")
info(f" Sampler: {best.get('qaoa_sampler_constructor')}  QAOA time (s): {best.get('qaoa_time'):.3f}")
info("="*50)
# Out:
# Setup: FakeProvider GenericBackendV2 -> noise model with 12 qubits.
# Using sampler: SamplerV2
# Running hybrid search (noisy sampler).
#
# [01/10] Trip A patients: ['DT', 'GR', 'R2']
# /usr/local/lib/python3.12/dist-packages/qiskit_optimization/minimum_eigensolvers/qaoa.py:122: UserWarning: Using Sampler V2 (other than StatevectorSampler) without a pass_manager may result in an error. Consider providing a pass_manager for proper circuit transpilation.
#   super().__init__(
#   -> time: 1.818s  raw_obj: 34.66099999999824  eigenval: -2445.070521484373  (loss(first/last/min)=-2363.797479+0.000000j/-2180.865002+0.000000j/-2445.070521+0.000000j)
#   Trip A dist: 34.661000  Trip B dist: 25.740000  TOTAL: 60.401000
#   >> New best solution recorded.
#
# [02/10] Trip A patients: ['DT', 'GR', 'R3_2']
# /usr/local/lib/python3.12/dist-packages/qiskit_optimization/minimum_eigensolvers/qaoa.py:122: UserWarning: Using Sampler V2 (other than StatevectorSampler) without a pass_manager may result in an error. Consider providing a pass_manager for proper circuit transpilation.
#   super().__init__(
#   -> time: 1.696s  raw_obj: 43.17000000000007  eigenval: -2831.4414521484373  (loss(first/last/min)=-2363.797479+0.000000j/-2705.179550+0.000000j/-2831.441452+0.000000j)
#   Trip A dist: 43.170000  Trip B dist: 28.854000  TOTAL: 72.024000
#
# [03/10] Trip A patients: ['DT', 'GR', 'IT']
# /usr/local/lib/python3.12/dist-packages/qiskit_optimization/minimum_eigensolvers/qaoa.py:122: UserWarning: Using Sampler V2 (other than StatevectorSampler) without a pass_manager may result in an error. Consider providing a pass_manager for proper circuit transpilation.
#   super().__init__(
#   -> time: 2.643s  raw_obj: 29.04699999999866  eigenval: -2374.495783203121  (loss(first/last/min)=-2363.797479+0.000000j/-2342.634669+0.000000j/-2831.441452+0.000000j)
#   Trip A dist: 30.736000  Trip B dist: 26.787000  TOTAL: 57.523000
#   >> New best solution recorded.
#
# [04/10] Trip A patients: ['DT', 'R2', 'R3_2']
# /usr/local/lib/python3.12/dist-packages/qiskit_optimization/minimum_eigensolvers/qaoa.py:122: UserWarning: Using Sampler V2 (other than StatevectorSampler) without a pass_manager may result in an error. Consider providing a pass_manager for proper circuit transpilation.
#   super().__init__(
#   -> time: 2.028s  raw_obj: 2026.893  eigenval: -1972.3481650390615  (loss(first/last/min)=-2363.797479+0.000000j/-1908.653787+0.000000j/-2831.441452+0.000000j)
#    > QAOA returned infeasible/partial selection — resolving this subproblem exactly (brute-force) for the full intended patient set.
#   Trip A dist: 33.801000  Trip B dist: 31.243000  TOTAL: 65.044000
#
# [05/10] Trip A patients: ['DT', 'R2', 'IT']
# /usr/local/lib/python3.12/dist-packages/qiskit_optimization/minimum_eigensolvers/qaoa.py:122: UserWarning: Using Sampler V2 (other than StatevectorSampler) without a pass_manager may result in an error. Consider providing a pass_manager for proper circuit transpilation.
#   super().__init__(
#   -> time: 2.240s  raw_obj: 41.677999999999884  eigenval: -1439.4260400390606  (loss(first/last/min)=-2363.797479+0.000000j/-962.847705+0.000000j/-2831.441452+0.000000j)
#   Trip A dist: 37.240000  Trip B dist: 28.963000  TOTAL: 66.203000
#
# [06/10] Trip A patients: ['DT', 'R3_2', 'IT']
# /usr/local/lib/python3.12/dist-packages/qiskit_optimization/minimum_eigensolvers/qaoa.py:122: UserWarning: Using Sampler V2 (other than StatevectorSampler) without a pass_manager may result in an error. Consider providing a pass_manager for proper circuit transpilation.
#   super().__init__(
#   -> time: 2.144s  raw_obj: 40.375  eigenval: -2130.3932617187506  (loss(first/last/min)=-2363.797479+0.000000j/-2020.090139+0.000000j/-2831.441452+0.000000j)
#   Trip A dist: 40.375000  Trip B dist: 35.168000  TOTAL: 75.543000
#
# [07/10] Trip A patients: ['GR', 'R2', 'R3_2']
# /usr/local/lib/python3.12/dist-packages/qiskit_optimization/minimum_eigensolvers/qaoa.py:122: UserWarning: Using Sampler V2 (other than StatevectorSampler) without a pass_manager may result in an error. Consider providing a pass_manager for proper circuit transpilation.
#   super().__init__(
#   -> time: 2.324s  raw_obj: 44.92399999999907  eigenval: -2979.811476562501  (loss(first/last/min)=-2363.797479+0.000000j/-2848.994083+0.000000j/-2979.811477+0.000000j)
#   Trip A dist: 37.555000  Trip B dist: 27.327000  TOTAL: 64.882000
#
# [08/10] Trip A patients: ['GR', 'R2', 'IT']
# /usr/local/lib/python3.12/dist-packages/qiskit_optimization/minimum_eigensolvers/qaoa.py:122: UserWarning: Using Sampler V2 (other than StatevectorSampler) without a pass_manager may result in an error. Consider providing a pass_manager for proper circuit transpilation.
#   super().__init__(
#   -> time: 1.704s  raw_obj: 44.052999999999884  eigenval: -2600.076539062498  (loss(first/last/min)=-2363.797479+0.000000j/-2295.895585+0.000000j/-2979.811477+0.000000j)
#   Trip A dist: 41.156000  Trip B dist: 25.209000  TOTAL: 66.365000
#
# [09/10] Trip A patients: ['GR', 'R3_2', 'IT']
# /usr/local/lib/python3.12/dist-packages/qiskit_optimization/minimum_eigensolvers/qaoa.py:122: UserWarning: Using Sampler V2 (other than StatevectorSampler) without a pass_manager may result in an error. Consider providing a pass_manager for proper circuit transpilation.
#   super().__init__(
#   -> time: 3.264s  raw_obj: 36.81999999999971  eigenval: -2330.1864902343764  (loss(first/last/min)=-2363.797479+0.000000j/-2287.930192+0.000000j/-2979.811477+0.000000j)
#   Trip A dist: 36.820000  Trip B dist: 31.414000  TOTAL: 68.234000
#
# [10/10] Trip A patients: ['R2', 'R3_2', 'IT']
# /usr/local/lib/python3.12/dist-packages/qiskit_optimization/minimum_eigensolvers/qaoa.py:122: UserWarning: Using Sampler V2 (other than StatevectorSampler) without a pass_manager may result in an error. Consider providing a pass_manager for proper circuit transpilation.
#   super().__init__(
#   -> time: 1.782s  raw_obj: 34.332000000000335  eigenval: -2072.2813564453113  (loss(first/last/min)=-2363.797479+0.000000j/-1950.554135+0.000000j/-2979.811477+0.000000j)
#   Trip A dist: 34.332000  Trip B dist: 28.774000  TOTAL: 63.106000
#
# ==================================================
# FINAL BEST SOLUTION (quantum Trip A, noisy simulator):
#  Total distance (hybrid): 57.523000
#  Trip A (3 patients): ['DT', 'GR', 'IT']  Route: H -> DT -> GR -> IT -> H  Distance: 30.736000
#  Trip B (2 patients): ['R2', 'R3_2']  Route: H -> R3_2 -> R2 -> H  Distance: 26.787000
#  Sampler: SamplerV2  QAOA time (s): 2.643
# ==================================================
